# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import re

import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.graphics.gofplots import ProbPlot
from statsmodels.stats.outliers_influence import OLSInfluence
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.robust.robust_linear_model import RLM
from statsmodels.stats.anova import anova_lm
from statsmodels.stats.multitest import multipletests

import copy
import itertools

from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Load Data

# %%
# Load the processsed data
name = 'CloudResearch-1_24.08.12'
df = pd.read_csv('/work/Processed Data/' + name + '_processed.csv')

# %%
df.columns = df.columns.str.replace(' ', '_').str.replace('-', '_').str.replace('/', '_')

# %%
# Dictionary to rename variables to more readable names
rename_dict = {'Frequency_Score_centered': 'Chatbot Usage Frequency',
 'Session_Length_Score_centered': 'Chatbot Session Length',
 'ULS_8_centered': 'Loneliness (ULS-8)',
 'SUS_Avg_centered': 'System Usability (SUS)',
 'BFI_Extraversion_centered': 'Extraversion (BFI-10)',
 'BFI_Neurotic_centered': 'Neuroticism (BFI-10)',
 'BFI_Agreeableness_centered': 'Agreeableness (BFI-10)',
 'BFI_Conscientious_centered': 'Conscientiousness (BFI-10)',
 'BFI_Openness_centered': 'Openness (BFI-10)',
 'LSNS_Score_centered': 'Socialization (LSNS)',
 'MSPSS_Score_centered': 'Perceived Social Support (MSPSS)',
 'B_RSES_Score_centered': 'Self-Esteem (B-RSES)',
 'AI_Attitudes_Score_centered': 'Attitudes towards AI',
 'C_State_Empathy_centered': 'State Empathy towards Chatbot',
 'C_SEmp_Affective_centered': 'Affective State Empathy towards Chatbot',
 'C_SEmp_Cognitive_centered': 'Cognitive State Empathy towards Chatbot',
 'C_SEmp_Associative_centered': 'Associative State Empathy towards Chatbot',
 'C_Social_Attract_centered': 'Social Attraction towards Chatbot',
 'C_Phys_Attract_centered': 'Physical Attraction towards Chatbot',
 'C_Task_Attract_centered': 'Task Attraction towards Chatbot',
 'C_Homophily_centered': 'Perceived Similarity with Chatbot',
 'C_Attrib_Conf_centered': 'Perceived Chatbot Predictability',
 'HCI_HHI_Expectation_centered': 'Expectations towards Chatbot (HCI/HHI)',
 'HCI_HHI_Trust_centered': 'Trust towards Chatbot (HCI/HHI)',
 'HCI_HHI_Substitution_centered': 'Preference for Chatbot over Humans (HCI/HHI)',
 'HHI_Trust___Unfam_centered': 'Trust in Unfamiliar People (HHI)',
 'HHI_CommIntent___Unfam_centered': 'Willingness to Engage with Unfamiliar People (HHI)',
 'HHI_Trust___Familiar_centered': 'Trust in Familiar People (HHI)',
 'HHI_CommIntent___Familiar_centered': 'Willingness to Engage with Familiar People (HHI)',
 'H_State_Empathy_centered': 'State Empathy towards Close Person',
 'H_SEmp_Affective_centered': 'Affective State Empathy towards Close Person',
 'H_SEmp_Cognitive_centered': 'Cognitive State Empathy towards Close Person',
 'H_SEmp_Associative_centered': 'Associative State Empathy towards Close Person',
 'H_Social_Attract_centered': 'Social Attraction towards towards Close Person',
 'H_Task_Attract_centered': 'Task Attraction towards towards Close Person',
 'H_Homophily_centered': 'Perceived Similarity with Close Person',
 'Age_centered': 'Age',
 'GPIUS2_centered': 'Problematic Use of Chatbot (GPIUS-2)',
 'Relation_Effect_1_centered': 'Chatbot Effect: Less Interaction with People',
 'Relation_Effect_2_centered': 'Chatbot Effect: Shift in Conversation Topics with People',
 'Relation_Effect_3_centered': 'Chatbot Effect: Easier to Talk to People',
 'Relation_Effect_4_centered': 'Chatbot Effect: More Enjoyable to Talk to People',
 'Relation_Effect_5_centered': 'Chatbot Effect: Less Engaging to Talk to People',
 'Relation_Effect_6_centered': 'Chatbot Effect: Less Interest in Talking to People'}

# %% [markdown]
# # Variable Exploration

# %%
# List of variables to include in regression model 
variables = ['Frequency Score', 'Session Length Score', 
             'ULS-8', 'GPIUS2', 'SUS Avg', 'BFI Extraversion', 'BFI Neurotic', 'BFI Agreeableness', 
             'BFI Conscientious', 'BFI Openness', 'LSNS Score', 'MSPSS Score', 'B-RSES Score', 
             'AI Attitudes Score', 'C State Empathy', 'C SEmp Affective', 'C SEmp Cognitive', 
             'C SEmp Associative', 'C Social Attract', 'C Phys Attract', 'C Task Attract', 
             'C Homophily', 'C Attrib Conf', 'HCI-HHI Expectation', 'HCI-HHI Trust', 
             'HCI-HHI Substitution', 'HHI Trust - Unfam', 'HHI CommIntent - Unfam', 
             'HHI Trust - Familiar', 'HHI CommIntent - Familiar', 'H State Empathy', 
             'H SEmp Affective', 'H SEmp Cognitive', 'H SEmp Associative', 'H Social Attract', 
             'H Task Attract', 'H Homophily', 'Age']

# Replace spaces and hyphens in variable names
variables = [var.replace(' ', '_').replace('-', '_') for var in variables]
var_centered = [var + '_centered' for var in variables]
var_viz = [rename_dict.get(var, var) for var in var_centered]

key_variables = ['Frequency_Score_centered', 'Session_Length_Score_centered', 'ULS_8_centered']
key_variables_viz = ['Chatbot Usage Frequency', 'Chatbot Session Length', 'Loneliness (ULS-8)']

print(key_variables)
print(variables)

# Standardize variables
scaler = StandardScaler()
df[var_centered] = scaler.fit_transform(df[variables])
# Out:
# ['Frequency_Score_centered', 'Session_Length_Score_centered', 'ULS_8_centered']
# ['Frequency_Score', 'Session_Length_Score', 'ULS_8', 'GPIUS2', 'SUS_Avg', 'BFI_Extraversion', 'BFI_Neurotic', 'BFI_Agreeableness', 'BFI_Conscientious', 'BFI_Openness', 'LSNS_Score', 'MSPSS_Score', 'B_RSES_Score', 'AI_Attitudes_Score', 'C_State_Empathy', 'C_SEmp_Affective', 'C_SEmp_Cognitive', 'C_SEmp_Associative', 'C_Social_Attract', 'C_Phys_Attract', 'C_Task_Attract', 'C_Homophily', 'C_Attrib_Conf', 'HCI_HHI_Expectation', 'HCI_HHI_Trust', 'HCI_HHI_Substitution', 'HHI_Trust___Unfam', 'HHI_CommIntent___Unfam', 'HHI_Trust___Familiar', 'HHI_CommIntent___Familiar', 'H_State_Empathy', 'H_SEmp_Affective', 'H_SEmp_Cognitive', 'H_SEmp_Associative', 'H_Social_Attract', 'H_Task_Attract', 'H_Homophily', 'Age']

# %%
# Check variables
df[var_centered].describe()
# Out:
#        Frequency_Score_centered  Session_Length_Score_centered  \
# count              4.040000e+02                   4.040000e+02
# mean               5.012492e-16                  -4.396923e-17
# std                1.001240e+00                   1.001240e+00
# min               -3.002056e+00                  -1.014723e+00
# 25%               -4.129963e-01                  -1.014723e+00
# 50%                4.500235e-01                   1.099631e-01
# 75%                4.500235e-01                   1.099631e-01
# max                1.313043e+00                   4.608708e+00
#
#        ULS_8_centered  GPIUS2_centered  SUS_Avg_centered  \
# count    4.040000e+02     4.040000e+02      4.040000e+02
# mean    -1.934646e-16    -1.846708e-16      2.638154e-16
# std      1.001240e+00     1.001240e+00      1.001240e+00
# min     -1.792966e+00    -1.394208e+00     -3.426758e+00
# 25%     -7.777476e-01    -8.794627e-01     -6.925855e-01
# 50%      6.826756e-02    -1.073448e-01     -4.501829e-02
# 75%      7.450797e-01     6.647731e-01      8.184047e-01
# max      2.267907e+00     3.238499e+00      2.082703e+00
#
#        BFI_Extraversion_centered  BFI_Neurotic_centered  \
# count               4.040000e+02           4.040000e+02
# mean                1.121215e-16           1.450985e-16
# std                 1.001240e+00           1.001240e+00
# min                -1.679291e+00          -1.692860e+00
# 25%                -4.634603e-01          -8.052344e-01
# 50%                 1.444552e-01           8.239097e-02
# 75%                 7.523707e-01           6.371569e-01
# max                 3.184033e+00           1.857642e+00
#
#        BFI_Agreeableness_centered  BFI_Conscientious_centered  \
# count                4.040000e+02                4.040000e+02
# mean                 4.836615e-17               -2.341361e-16
# std                  1.001240e+00                1.001240e+00
# min                 -1.450706e+00               -3.095353e+00
# 25%                 -9.623020e-01               -5.093789e-01
# 50%                  1.450706e-02                1.711405e-01
# 75%                  5.029116e-01                7.155561e-01
# max                  2.456530e+00                1.259972e+00
#
#        BFI_Openness_centered  ...  HHI_Trust___Familiar_centered  \
# count           4.040000e+02  ...                   4.040000e+02
# mean           -8.793846e-17  ...                  -2.066554e-16
# std             1.001240e+00  ...                   1.001240e+00
# min            -3.092336e+00  ...                  -3.732899e+00
# 25%            -8.986506e-01  ...                  -5.096210e-01
# 50%             1.981918e-01  ...                   2.961985e-01
# 75%             7.466131e-01  ...                   6.991083e-01
# max             1.295034e+00  ...                   1.102018e+00
#
#        HHI_CommIntent___Familiar_centered  H_State_Empathy_centered  \
# count                        4.040000e+02              4.040000e+02
# mean                         9.893076e-17              5.759969e-16
# std                          1.001240e+00              1.001240e+00
# min                         -3.554573e+00             -5.316461e+00
# 25%                         -4.579746e-01             -4.931431e-01
# 50%                          3.161749e-01              1.767621e-01
# 75%                          7.032497e-01              7.126863e-01
# max                          1.090324e+00              1.114629e+00
#
#        H_SEmp_Affective_centered  H_SEmp_Cognitive_centered  \
# count               4.040000e+02               4.040000e+02
# mean                2.418308e-16               4.308984e-16
# std                 1.001240e+00               1.001240e+00
# min                -4.870686e+00              -5.426415e+00
# 25%                -3.874725e-01              -6.249440e-01
# 50%                -1.387133e-02               1.753012e-01
# 75%                 7.333309e-01               9.755464e-01
# max                 1.106932e+00               9.755464e-01
#
#        H_SEmp_Associative_centered  H_Social_Attract_centered  \
# count                 4.040000e+02               4.040000e+02
# mean                 -2.682123e-16              -2.770061e-16
# std                   1.001240e+00               1.001240e+00
# min                  -4.578349e+00              -3.755138e+00
# 25%                  -3.785693e-01              -8.505747e-01
# 50%                  -2.858761e-02               2.665650e-01
# 75%                   1.021357e+00               9.368489e-01
# max                   1.021357e+00               9.368489e-01
#
#        H_Task_Attract_centered  H_Homophily_centered  Age_centered
# count             4.040000e+02          4.040000e+02  4.040000e+02
# mean             -1.758769e-17         -7.760569e-16  2.374338e-16
# std               1.001240e+00          1.001240e+00  1.001240e+00
# min              -4.051904e+00         -4.128058e+00 -1.663251e+00
# 25%              -7.215720e-01         -5.459321e-01 -6.586860e-01
# 50%               1.665166e-01          1.363775e-01 -2.568602e-01
# 75%               8.325831e-01          6.481097e-01  5.467915e-01
# max               1.054605e+00          1.671574e+00  3.861855e+00
#
# [8 rows x 38 columns]

# %%
# Calculate spearman correlation
correlation_matrix = df[var_centered].corr(method='spearman', min_periods=1)

plt.figure(figsize=(20, 16))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Calculate p-value & significant correlations

# %%
# Function to calculate p-value
def calculate_pvalue(r, n):
    if abs(r) == 1.0:
        return 0.0  # Perfect correlation, p-value is 0
    else:
        t = r * np.sqrt((n-2) / (1-r**2))
        p = 2 * (1 - stats.t.cdf(np.abs(t), n-2))
        return p

# Calculate p-values
n = df[var_centered].shape[0]  # sample size
p_values_matrix = correlation_matrix.applymap(lambda x: calculate_pvalue(x, n))

# %%
# Function to find significant correlations
def find_significant_correlations(correlation_matrix, p_values_matrix, key_variables, var_names, alpha=0.05, latex=False):
    #significant_correlations = []
    for key_var in key_variables:
        print(f"\nSignificant correlations with {key_var}:")
        if latex:
            print(f"\\begin{{itemize}}")
        for var in var_names:
            if var != key_var:
                corr = correlation_matrix.loc[key_var, var]
                p_val = p_values_matrix.loc[key_var, var]
                if p_val < alpha:
                    # significant_correlations.append((key_var, var, corr, p_val))
                    if latex:
                        seq = ["\\item "]
                        if corr < 0:
                            seq.append("\\textcolor{{cyan}}{{")
                        seq.append("{var}: $r = {corr:.4f}, p ")
                        if p_val < 0.001:
                            seq.append("< 0.001$")
                        else:
                            seq.append("{p_val:.3f}$")
                        if corr < 0:
                            seq.append("}}")
                        seqstr = "".join(seq)
                        print(seqstr.format(var=var, corr=corr, p_val=p_val))  
                    else:
                        print(f"{var}: correlation = {corr:.4f}, p-value = {p_val:.4f}")
        if latex:
            print(f"\\end{{itemize}}")
    return #significant_correlation

# Function to visualize significant correlations
def significant_correlation_matrix(correlation_matrix, p_values_matrix, variables_of_interest, p_threshold=0.05, rename_dict=None, title=''):
    # Create a boolean mask for significant correlations
    significant_mask = (p_values_matrix < p_threshold) | (p_values_matrix.T < p_threshold)
    
    # Ensure variables of interest are always included
    #for var in variables_of_interest:
    #    significant_mask[var] = True
    #    significant_mask.loc[var] = True
    
    # Apply the mask to get the significant correlation matrix
    significant_corr_matrix = correlation_matrix.loc[significant_mask.any(axis=1), significant_mask.any(axis=0)]

    # Create a copy for visualization
    viz_matrix = significant_corr_matrix.copy()

    # Rename the index and columns if a rename dictionary is provided
    if rename_dict:
        viz_matrix = viz_matrix.rename(index=rename_dict, columns=rename_dict)
        # Also rename the index and columns of the significant_mask
        significant_mask = significant_mask.rename(index=rename_dict, columns=rename_dict)
    
    # Create a mask for the heatmap to hide insignificant correlations
    heatmap_mask = ~significant_mask.loc[viz_matrix.index, viz_matrix.columns]
    
    # Set diagonal to False (to always show self-correlations)
    np.fill_diagonal(heatmap_mask.values, False)
    
    # Plot the heatmap
    plt.figure(figsize=(20, 16))
    sns.heatmap(viz_matrix, 
                mask=heatmap_mask,
                annot=False, 
                cmap='coolwarm', 
                vmin=-1, 
                vmax=1, 
                center=0,
                square=True,
                linewidths=0.5)
    plt.title(title + ' ' f'Correlation Matrix (p < {p_threshold})')
    plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels
    plt.yticks(rotation=0)  # Ensure y-axis labels are horizontal
    plt.tight_layout()
    plt.show()
    
    return significant_corr_matrix

# %%
# Uncorrected significant correlations
significant_corr = significant_correlation_matrix(correlation_matrix, p_values_matrix, 
                                                key_variables, rename_dict=rename_dict, title='Users: Uncorrected')

# %%
significant_corr
# Out:
#                                     Frequency_Score_centered  \
# Frequency_Score_centered                            1.000000
# Session_Length_Score_centered                       0.349703
# ULS_8_centered                                      0.053062
# GPIUS2_centered                                     0.337375
# SUS_Avg_centered                                    0.245677
# BFI_Extraversion_centered                          -0.041796
# BFI_Neurotic_centered                              -0.087668
# BFI_Agreeableness_centered                         -0.066565
# BFI_Conscientious_centered                          0.151065
# BFI_Openness_centered                               0.101146
# LSNS_Score_centered                                 0.002211
# MSPSS_Score_centered                               -0.004504
# B_RSES_Score_centered                               0.059976
# AI_Attitudes_Score_centered                         0.297640
# C_State_Empathy_centered                            0.320680
# C_SEmp_Affective_centered                           0.247246
# C_SEmp_Cognitive_centered                           0.280460
# C_SEmp_Associative_centered                         0.341607
# C_Social_Attract_centered                           0.223806
# C_Phys_Attract_centered                             0.185603
# C_Task_Attract_centered                             0.165229
# C_Homophily_centered                                0.252542
# C_Attrib_Conf_centered                              0.008802
# HCI_HHI_Expectation_centered                        0.256032
# HCI_HHI_Trust_centered                              0.293100
# HCI_HHI_Substitution_centered                       0.208399
# HHI_Trust___Unfam_centered                          0.009432
# HHI_CommIntent___Unfam_centered                     0.045936
# HHI_Trust___Familiar_centered                       0.010857
# HHI_CommIntent___Familiar_centered                  0.049274
# H_State_Empathy_centered                           -0.041000
# H_SEmp_Affective_centered                          -0.028668
# H_SEmp_Cognitive_centered                          -0.043250
# H_SEmp_Associative_centered                        -0.041517
# H_Social_Attract_centered                          -0.087303
# H_Task_Attract_centered                            -0.067526
# H_Homophily_centered                               -0.042669
# Age_centered                                        0.023190
#
#                                     Session_Length_Score_centered  \
# Frequency_Score_centered                                 0.349703
# Session_Length_Score_centered                            1.000000
# ULS_8_centered                                           0.101290
# GPIUS2_centered                                          0.254942
# SUS_Avg_centered                                         0.196177
# BFI_Extraversion_centered                                0.001691
# BFI_Neurotic_centered                                   -0.064720
# BFI_Agreeableness_centered                              -0.037076
# BFI_Conscientious_centered                               0.097211
# BFI_Openness_centered                                    0.069448
# LSNS_Score_centered                                     -0.051296
# MSPSS_Score_centered                                    -0.009842
# B_RSES_Score_centered                                    0.042737
# AI_Attitudes_Score_centered                              0.233102
# C_State_Empathy_centered                                 0.301641
# C_SEmp_Affective_centered                                0.247524
# C_SEmp_Cognitive_centered                                0.253949
# C_SEmp_Associative_centered                              0.307335
# C_Social_Attract_centered                                0.255266
# C_Phys_Attract_centered                                  0.243840
# C_Task_Attract_centered                                  0.178674
# C_Homophily_centered                                     0.221331
# C_Attrib_Conf_centered                                   0.017842
# HCI_HHI_Expectation_centered                             0.206915
# HCI_HHI_Trust_centered                                   0.193751
# HCI_HHI_Substitution_centered                            0.168408
# HHI_Trust___Unfam_centered                              -0.030620
# HHI_CommIntent___Unfam_centered                         -0.023655
# HHI_Trust___Familiar_centered                            0.000063
# HHI_CommIntent___Familiar_centered                       0.021847
# H_State_Empathy_centered                                -0.008844
# H_SEmp_Affective_centered                                0.008382
# H_SEmp_Cognitive_centered                               -0.011901
# H_SEmp_Associative_centered                             -0.007592
# H_Social_Attract_centered                               -0.098565
# H_Task_Attract_centered                                 -0.001611
# H_Homophily_centered                                     0.001582
# Age_centered                                            -0.007058
#
#                                     ULS_8_centered  GPIUS2_centered  \
# Frequency_Score_centered                  0.053062         0.337375
# Session_Length_Score_centered             0.101290         0.254942
# ULS_8_centered                            1.000000         0.364928
# GPIUS2_centered                           0.364928         1.000000
# SUS_Avg_centered                         -0.010558         0.120706
# BFI_Extraversion_centered                -0.187643         0.067080
# BFI_Neurotic_centered                     0.526362         0.128189
# BFI_Agreeableness_centered                0.333155         0.049280
# BFI_Conscientious_centered               -0.335101        -0.078084
# BFI_Openness_centered                     0.030479        -0.089400
# LSNS_Score_centered                      -0.505519        -0.144413
# MSPSS_Score_centered                     -0.679021        -0.186994
# B_RSES_Score_centered                    -0.638009        -0.174541
# AI_Attitudes_Score_centered               0.061542         0.454518
# C_State_Empathy_centered                  0.125121         0.582109
# C_SEmp_Affective_centered                 0.087559         0.572713
# C_SEmp_Cognitive_centered                 0.119466         0.449881
# C_SEmp_Associative_centered               0.111851         0.528066
# C_Social_Attract_centered                 0.165760         0.503757
# C_Phys_Attract_centered                   0.120979         0.476912
# C_Task_Attract_centered                   0.046315         0.155005
# C_Homophily_centered                      0.136417         0.543510
# C_Attrib_Conf_centered                   -0.298149        -0.151261
# HCI_HHI_Expectation_centered              0.028868         0.429420
# HCI_HHI_Trust_centered                    0.060564         0.457969
# HCI_HHI_Substitution_centered             0.213790         0.627546
# HHI_Trust___Unfam_centered               -0.204474         0.035685
# HHI_CommIntent___Unfam_centered          -0.253566         0.018978
# HHI_Trust___Familiar_centered            -0.513223        -0.228022
# HHI_CommIntent___Familiar_centered       -0.549545        -0.191284
# H_State_Empathy_centered                 -0.382060        -0.236923
# H_SEmp_Affective_centered                -0.372514        -0.165849
# H_SEmp_Cognitive_centered                -0.337741        -0.245579
# H_SEmp_Associative_centered              -0.338239        -0.243781
# H_Social_Attract_centered                -0.204699        -0.306120
# H_Task_Attract_centered                  -0.275497        -0.275870
# H_Homophily_centered                     -0.267005        -0.217170
# Age_centered                             -0.038339        -0.059455
#
#                                     SUS_Avg_centered  \
# Frequency_Score_centered                    0.245677
# Session_Length_Score_centered               0.196177
# ULS_8_centered                             -0.010558
# GPIUS2_centered                             0.120706
# SUS_Avg_centered                            1.000000
# BFI_Extraversion_centered                  -0.099349
# BFI_Neurotic_centered                      -0.076619
# BFI_Agreeableness_centered                 -0.126955
# BFI_Conscientious_centered                  0.260121
# BFI_Openness_centered                       0.169220
# LSNS_Score_centered                         0.017095
# MSPSS_Score_centered                        0.147184
# B_RSES_Score_centered                       0.108987
# AI_Attitudes_Score_centered                 0.442781
# C_State_Empathy_centered                    0.402429
# C_SEmp_Affective_centered                   0.255081
# C_SEmp_Cognitive_centered                   0.430978
# C_SEmp_Associative_centered                 0.442492
# C_Social_Attract_centered                   0.418715
# C_Phys_Attract_centered                     0.165372
# C_Task_Attract_centered                     0.582105
# C_Homophily_centered                        0.336035
# C_Attrib_Conf_centered                      0.369427
# HCI_HHI_Expectation_centered                0.442348
# HCI_HHI_Trust_centered                      0.528899
# HCI_HHI_Substitution_centered               0.206819
# HHI_Trust___Unfam_centered                 -0.062278
# HHI_CommIntent___Unfam_centered            -0.039330
# HHI_Trust___Familiar_centered               0.202316
# HHI_CommIntent___Familiar_centered          0.192936
# H_State_Empathy_centered                    0.295926
# H_SEmp_Affective_centered                   0.257970
# H_SEmp_Cognitive_centered                   0.283069
# H_SEmp_Associative_centered                 0.284274
# H_Social_Attract_centered                   0.325439
# H_Task_Attract_centered                     0.364965
# H_Homophily_centered                        0.328709
# Age_centered                                0.033189
#
#                                     BFI_Extraversion_centered  \
# Frequency_Score_centered                            -0.041796
# Session_Length_Score_centered                        0.001691
# ULS_8_centered                                      -0.187643
# GPIUS2_centered                                      0.067080
# SUS_Avg_centered                                    -0.099349
# BFI_Extraversion_centered                            1.000000
# BFI_Neurotic_centered                               -0.254179
# BFI_Agreeableness_centered                          -0.150658
# BFI_Conscientious_centered                           0.020180
# BFI_Openness_centered                               -0.550609
# LSNS_Score_centered                                  0.198529
# MSPSS_Score_centered                                 0.221685
# B_RSES_Score_centered                                0.216281
# AI_Attitudes_Score_centered                          0.147886
# C_State_Empathy_centered                             0.102810
# C_SEmp_Affective_centered                            0.135285
# C_SEmp_Cognitive_centered                            0.069727
# C_SEmp_Associative_centered                          0.080294
# C_Social_Attract_centered                            0.078816
# C_Phys_Attract_centered                              0.070350
# C_Task_Attract_centered                              0.026513
# C_Homophily_centered                                 0.107201
# C_Attrib_Conf_centered                               0.031400
# HCI_HHI_Expectation_centered                         0.045779
# HCI_HHI_Trust_centered                               0.108608
# HCI_HHI_Substitution_centered                        0.068008
# HHI_Trust___Unfam_centered                           0.110025
# HHI_CommIntent___Unfam_centered                      0.178148
# HHI_Trust___Familiar_centered                        0.197774
# HHI_CommIntent___Familiar_centered                   0.227257
# H_State_Empathy_centered                             0.052289
# H_SEmp_Affective_centered                            0.090671
# H_SEmp_Cognitive_centered                            0.066078
# H_SEmp_Associative_centered                         -0.008222
# H_Social_Attract_centered                            0.032446
# H_Task_Attract_centered                              0.042576
# H_Homophily_centered                                 0.018794
# Age_centered                                        -0.014567
#
#                                     BFI_Neurotic_centered  \
# Frequency_Score_centered                        -0.087668
# Session_Length_Score_centered                   -0.064720
# ULS_8_centered                                   0.526362
# GPIUS2_centered                                  0.128189
# SUS_Avg_centered                                -0.076619
# BFI_Extraversion_centered                       -0.254179
# BFI_Neurotic_centered                            1.000000
# BFI_Agreeableness_centered                       0.376191
# BFI_Conscientious_centered                      -0.416604
# BFI_Openness_centered                           -0.111191
# LSNS_Score_centered                             -0.335898
# MSPSS_Score_centered                            -0.432896
# B_RSES_Score_centered                           -0.521888
# AI_Attitudes_Score_centered                     -0.161491
# C_State_Empathy_centered                        -0.100156
# C_SEmp_Affective_centered                       -0.133549
# C_SEmp_Cognitive_centered                       -0.058999
# C_SEmp_Associative_centered                     -0.090534
# C_Social_Attract_centered                       -0.049100
# C_Phys_Attract_centered                          0.041797
# C_Task_Attract_centered                         -0.054975
# C_Homophily_centered                            -0.080866
# C_Attrib_Conf_centered                          -0.205733
# HCI_HHI_Expectation_centered                    -0.093640
# HCI_HHI_Trust_centered                          -0.100300
# HCI_HHI_Substitution_centered                    0.053777
# HHI_Trust___Unfam_centered                      -0.204195
# HHI_CommIntent___Unfam_centered                 -0.441248
# HHI_Trust___Familiar_centered                   -0.307848
# HHI_CommIntent___Familiar_centered              -0.416751
# H_State_Empathy_centered                        -0.255964
# H_SEmp_Affective_centered                       -0.252384
# H_SEmp_Cognitive_centered                       -0.212861
# H_SEmp_Associative_centered                     -0.237139
# H_Social_Attract_centered                       -0.084161
# H_Task_Attract_centered                         -0.131258
# H_Homophily_centered                            -0.144394
# Age_centered                                    -0.054842
#
#                                     BFI_Agreeableness_centered  \
# Frequency_Score_centered                             -0.066565
# Session_Length_Score_centered                        -0.037076
# ULS_8_centered                                        0.333155
# GPIUS2_centered                                       0.049280
# SUS_Avg_centered                                     -0.126955
# BFI_Extraversion_centered                            -0.150658
# BFI_Neurotic_centered                                 0.376191
# BFI_Agreeableness_centered                            1.000000
# BFI_Conscientious_centered                           -0.273598
# BFI_Openness_centered                                -0.021767
# LSNS_Score_centered                                  -0.262181
# MSPSS_Score_centered                                 -0.421326
# B_RSES_Score_centered                                -0.334794
# AI_Attitudes_Score_centered                          -0.161493
# C_State_Empathy_centered                             -0.152848
# C_SEmp_Affective_centered                            -0.156704
# C_SEmp_Cognitive_centered                            -0.126909
# C_SEmp_Associative_centered                          -0.125106
# C_Social_Attract_centered                            -0.134201
# C_Phys_Attract_centered                              -0.056668
# C_Task_Attract_centered                              -0.077497
# C_Homophily_centered                                 -0.129696
# C_Attrib_Conf_centered                               -0.213753
# HCI_HHI_Expectation_centered                         -0.151521
# HCI_HHI_Trust_centered                               -0.137817
# HCI_HHI_Substitution_centered                        -0.024707
# HHI_Trust___Unfam_centered                           -0.364149
# HHI_CommIntent___Unfam_centered                      -0.259107
# HHI_Trust___Familiar_centered                        -0.437893
# HHI_CommIntent___Familiar_centered                   -0.395762
# H_State_Empathy_centered                             -0.252521
# H_SEmp_Affective_centered                            -0.287701
# H_SEmp_Cognitive_centered                            -0.205769
# H_SEmp_Associative_centered                          -0.198034
# H_Social_Attract_centered                            -0.118710
# H_Task_Attract_centered                              -0.184144
# H_Homophily_centered                                 -0.176825
# Age_centered                                         -0.007753
#
#                                     BFI_Conscientious_centered  \
# Frequency_Score_centered                              0.151065
# Session_Length_Score_centered                         0.097211
# ULS_8_centered                                       -0.335101
# GPIUS2_centered                                      -0.078084
# SUS_Avg_centered                                      0.260121
# BFI_Extraversion_centered                             0.020180
# BFI_Neurotic_centered                                -0.416604
# BFI_Agreeableness_centered                           -0.273598
# BFI_Conscientious_centered                            1.000000
# BFI_Openness_centered                                 0.089713
# LSNS_Score_centered                                   0.206515
# MSPSS_Score_centered                                  0.327361
# B_RSES_Score_centered                                 0.384891
# AI_Attitudes_Score_centered                           0.129313
# C_State_Empathy_centered                              0.088027
# C_SEmp_Affective_centered                             0.100719
# C_SEmp_Cognitive_centered                             0.089018
# C_SEmp_Associative_centered                           0.081586
# C_Social_Attract_centered                             0.096197
# C_Phys_Attract_centered                              -0.025507
# C_Task_Attract_centered                               0.189017
# C_Homophily_centered                                  0.112407
# C_Attrib_Conf_centered                                0.252855
# HCI_HHI_Expectation_centered                          0.122184
# HCI_HHI_Trust_centered                                0.167644
# HCI_HHI_Substitution_centered                         0.002828
# HHI_Trust___Unfam_centered                            0.069258
# HHI_CommIntent___Unfam_centered                       0.131619
# HHI_Trust___Familiar_centered                         0.286713
# HHI_CommIntent___Familiar_centered                    0.331015
# H_State_Empathy_centered                              0.300502
# H_SEmp_Affective_centered                             0.289812
# H_SEmp_Cognitive_centered                             0.271795
# H_SEmp_Associative_centered                           0.277312
# H_Social_Attract_centered                             0.136418
# H_Task_Attract_centered                               0.199524
# H_Homophily_centered                                  0.239981
# Age_centered                                          0.122018
#
#                                     BFI_Openness_centered  ...  \
# Frequency_Score_centered                         0.101146  ...
# Session_Length_Score_centered                    0.069448  ...
# ULS_8_centered                                   0.030479  ...
# GPIUS2_centered                                 -0.089400  ...
# SUS_Avg_centered                                 0.169220  ...
# BFI_Extraversion_centered                       -0.550609  ...
# BFI_Neurotic_centered                           -0.111191  ...
# BFI_Agreeableness_centered                      -0.021767  ...
# BFI_Conscientious_centered                       0.089713  ...
# BFI_Openness_centered                            1.000000  ...
# LSNS_Score_centered                             -0.018030  ...
# MSPSS_Score_centered                            -0.037166  ...
# B_RSES_Score_centered                           -0.012177  ...
# AI_Attitudes_Score_centered                     -0.106565  ...
# C_State_Empathy_centered                        -0.022179  ...
# C_SEmp_Affective_centered                       -0.066071  ...
# C_SEmp_Cognitive_centered                       -0.005212  ...
# C_SEmp_Associative_centered                      0.017100  ...
# C_Social_Attract_centered                       -0.064411  ...
# C_Phys_Attract_centered                         -0.058401  ...
# C_Task_Attract_centered                          0.041159  ...
# C_Homophily_centered                            -0.049856  ...
# C_Attrib_Conf_centered                           0.150031  ...
# HCI_HHI_Expectation_centered                     0.006618  ...
# HCI_HHI_Trust_centered                          -0.033901  ...
# HCI_HHI_Substitution_centered                   -0.169665  ...
# HHI_Trust___Unfam_centered                       0.031265  ...
# HHI_CommIntent___Unfam_centered                  0.120491  ...
# HHI_Trust___Familiar_centered                    0.020672  ...
# HHI_CommIntent___Familiar_centered               0.022502  ...
# H_State_Empathy_centered                         0.146385  ...
# H_SEmp_Affective_centered                        0.116215  ...
# H_SEmp_Cognitive_centered                        0.094137  ...
# H_SEmp_Associative_centered                      0.192699  ...
# H_Social_Attract_centered                        0.188079  ...
# H_Task_Attract_centered                          0.136517  ...
# H_Homophily_centered                             0.186466  ...
# Age_centered                                     0.075641  ...
#
#                                     HHI_Trust___Familiar_centered  \
# Frequency_Score_centered                                 0.010857
# Session_Length_Score_centered                            0.000063
# ULS_8_centered                                          -0.513223
# GPIUS2_centered                                         -0.228022
# SUS_Avg_centered                                         0.202316
# BFI_Extraversion_centered                                0.197774
# BFI_Neurotic_centered                                   -0.307848
# BFI_Agreeableness_centered                              -0.437893
# BFI_Conscientious_centered                               0.286713
# BFI_Openness_centered                                    0.020672
# LSNS_Score_centered                                      0.483868
# MSPSS_Score_centered                                     0.630803
# B_RSES_Score_centered                                    0.427748
# AI_Attitudes_Score_centered                              0.052191
# C_State_Empathy_centered                                 0.008370
# C_SEmp_Affective_centered                               -0.059471
# C_SEmp_Cognitive_centered                                0.049788
# C_SEmp_Associative_centered                              0.057420
# C_Social_Attract_centered                                0.009546
# C_Phys_Attract_centered                                 -0.122332
# C_Task_Attract_centered                                  0.137663
# C_Homophily_centered                                    -0.010075
# C_Attrib_Conf_centered                                   0.438660
# HCI_HHI_Expectation_centered                             0.109170
# HCI_HHI_Trust_centered                                   0.105472
# HCI_HHI_Substitution_centered                           -0.177075
# HHI_Trust___Unfam_centered                               0.261294
# HHI_CommIntent___Unfam_centered                          0.234411
# HHI_Trust___Familiar_centered                            1.000000
# HHI_CommIntent___Familiar_centered                       0.798285
# H_State_Empathy_centered                                 0.544526
# H_SEmp_Affective_centered                                0.501926
# H_SEmp_Cognitive_centered                                0.508840
# H_SEmp_Associative_centered                              0.482493
# H_Social_Attract_centered                                0.431367
# H_Task_Attract_centered                                  0.470343
# H_Homophily_centered                                     0.463119
# Age_centered                                             0.052249
#
#                                     HHI_CommIntent___Familiar_centered  \
# Frequency_Score_centered                                      0.049274
# Session_Length_Score_centered                                 0.021847
# ULS_8_centered                                               -0.549545
# GPIUS2_centered                                              -0.191284
# SUS_Avg_centered                                              0.192936
# BFI_Extraversion_centered                                     0.227257
# BFI_Neurotic_centered                                        -0.416751
# BFI_Agreeableness_centered                                   -0.395762
# BFI_Conscientious_centered                                    0.331015
# BFI_Openness_centered                                         0.022502
# LSNS_Score_centered                                           0.512255
# MSPSS_Score_centered                                          0.692075
# B_RSES_Score_centered                                         0.548848
# AI_Attitudes_Score_centered                                   0.106924
# C_State_Empathy_centered                                      0.048550
# C_SEmp_Affective_centered                                     0.008259
# C_SEmp_Cognitive_centered                                     0.073870
# C_SEmp_Associative_centered                                   0.078771
# C_Social_Attract_centered                                     0.024013
# C_Phys_Attract_centered                                      -0.074838
# C_Task_Attract_centered                                       0.111576
# C_Homophily_centered                                          0.061180
# C_Attrib_Conf_centered                                        0.399674
# HCI_HHI_Expectation_centered                                  0.135704
# HCI_HHI_Trust_centered                                        0.128914
# HCI_HHI_Substitution_centered                                -0.127624
# HHI_Trust___Unfam_centered                                    0.242205
# HHI_CommIntent___Unfam_centered                               0.337281
# HHI_Trust___Familiar_centered                                 0.798285
# HHI_CommIntent___Familiar_centered                            1.000000
# H_State_Empathy_centered                                      0.524953
# H_SEmp_Affective_centered                                     0.496092
# H_SEmp_Cognitive_centered                                     0.484746
# H_SEmp_Associative_centered                                   0.465403
# H_Social_Attract_centered                                     0.344165
# H_Task_Attract_centered                                       0.399189
# H_Homophily_centered                                          0.432590
# Age_centered                                                  0.084551
#
#                                     H_State_Empathy_centered  \
# Frequency_Score_centered                           -0.041000
# Session_Length_Score_centered                      -0.008844
# ULS_8_centered                                     -0.382060
# GPIUS2_centered                                    -0.236923
# SUS_Avg_centered                                    0.295926
# BFI_Extraversion_centered                           0.052289
# BFI_Neurotic_centered                              -0.255964
# BFI_Agreeableness_centered                         -0.252521
# BFI_Conscientious_centered                          0.300502
# BFI_Openness_centered                               0.146385
# LSNS_Score_centered                                 0.308985
# MSPSS_Score_centered                                0.476791
# B_RSES_Score_centered                               0.300025
# AI_Attitudes_Score_centered                         0.065162
# C_State_Empathy_centered                            0.002022
# C_SEmp_Affective_centered                          -0.068003
# C_SEmp_Cognitive_centered                           0.060686
# C_SEmp_Associative_centered                         0.061659
# C_Social_Attract_centered                           0.030193
# C_Phys_Attract_centered                            -0.131786
# C_Task_Attract_centered                             0.195054
# C_Homophily_centered                               -0.039958
# C_Attrib_Conf_centered                              0.583320
# HCI_HHI_Expectation_centered                        0.071457
# HCI_HHI_Trust_centered                              0.126583
# HCI_HHI_Substitution_centered                      -0.157798
# HHI_Trust___Unfam_centered                          0.062460
# HHI_CommIntent___Unfam_centered                     0.161544
# HHI_Trust___Familiar_centered                       0.544526
# HHI_CommIntent___Familiar_centered                  0.524953
# H_State_Empathy_centered                            1.000000
# H_SEmp_Affective_centered                           0.894770
# H_SEmp_Cognitive_centered                           0.921612
# H_SEmp_Associative_centered                         0.923609
# H_Social_Attract_centered                           0.598424
# H_Task_Attract_centered                             0.592443
# H_Homophily_centered                                0.647336
# Age_centered                                        0.068442
#
#                                     H_SEmp_Affective_centered  \
# Frequency_Score_centered                            -0.028668
# Session_Length_Score_centered                        0.008382
# ULS_8_centered                                      -0.372514
# GPIUS2_centered                                     -0.165849
# SUS_Avg_centered                                     0.257970
# BFI_Extraversion_centered                            0.090671
# BFI_Neurotic_centered                               -0.252384
# BFI_Agreeableness_centered                          -0.287701
# BFI_Conscientious_centered                           0.289812
# BFI_Openness_centered                                0.116215
# LSNS_Score_centered                                  0.285103
# MSPSS_Score_centered                                 0.477982
# B_RSES_Score_centered                                0.304153
# AI_Attitudes_Score_centered                          0.102753
# C_State_Empathy_centered                             0.039766
# C_SEmp_Affective_centered                           -0.003123
# C_SEmp_Cognitive_centered                            0.078049
# C_SEmp_Associative_centered                          0.072528
# C_Social_Attract_centered                            0.071896
# C_Phys_Attract_centered                             -0.085830
# C_Task_Attract_centered                              0.206347
# C_Homophily_centered                                -0.000992
# C_Attrib_Conf_centered                               0.496450
# HCI_HHI_Expectation_centered                         0.100778
# HCI_HHI_Trust_centered                               0.143030
# HCI_HHI_Substitution_centered                       -0.085136
# HHI_Trust___Unfam_centered                           0.092870
# HHI_CommIntent___Unfam_centered                      0.179810
# HHI_Trust___Familiar_centered                        0.501926
# HHI_CommIntent___Familiar_centered                   0.496092
# H_State_Empathy_centered                             0.894770
# H_SEmp_Affective_centered                            1.000000
# H_SEmp_Cognitive_centered                            0.736083
# H_SEmp_Associative_centered                          0.725538
# H_Social_Attract_centered                            0.502352
# H_Task_Attract_centered                              0.525333
# H_Homophily_centered                                 0.596413
# Age_centered                                         0.011081
#
#                                     H_SEmp_Cognitive_centered  \
# Frequency_Score_centered                            -0.043250
# Session_Length_Score_centered                       -0.011901
# ULS_8_centered                                      -0.337741
# GPIUS2_centered                                     -0.245579
# SUS_Avg_centered                                     0.283069
# BFI_Extraversion_centered                            0.066078
# BFI_Neurotic_centered                               -0.212861
# BFI_Agreeableness_centered                          -0.205769
# BFI_Conscientious_centered                           0.271795
# BFI_Openness_centered                                0.094137
# LSNS_Score_centered                                  0.290300
# MSPSS_Score_centered                                 0.415309
# B_RSES_Score_centered                                0.266204
# AI_Attitudes_Score_centered                          0.013311
# C_State_Empathy_centered                            -0.017149
# C_SEmp_Affective_centered                           -0.088410
# C_SEmp_Cognitive_centered                            0.043007
# C_SEmp_Associative_centered                          0.048487
# C_Social_Attract_centered                            0.018808
# C_Phys_Attract_centered                             -0.116196
# C_Task_Attract_centered                              0.150422
# C_Homophily_centered                                -0.046985
# C_Attrib_Conf_centered                               0.552195
# HCI_HHI_Expectation_centered                         0.040815
# HCI_HHI_Trust_centered                               0.102048
# HCI_HHI_Substitution_centered                       -0.160258
# HHI_Trust___Unfam_centered                           0.017976
# HHI_CommIntent___Unfam_centered                      0.128466
# HHI_Trust___Familiar_centered                        0.508840
# HHI_CommIntent___Familiar_centered                   0.484746
# H_State_Empathy_centered                             0.921612
# H_SEmp_Affective_centered                            0.736083
# H_SEmp_Cognitive_centered                            1.000000
# H_SEmp_Associative_centered                          0.817340
# H_Social_Attract_centered                            0.586807
# H_Task_Attract_centered                              0.570998
# H_Homophily_centered                                 0.598940
# Age_centered                                         0.076240
#
#                                     H_SEmp_Associative_centered  \
# Frequency_Score_centered                              -0.041517
# Session_Length_Score_centered                         -0.007592
# ULS_8_centered                                        -0.338239
# GPIUS2_centered                                       -0.243781
# SUS_Avg_centered                                       0.284274
# BFI_Extraversion_centered                             -0.008222
# BFI_Neurotic_centered                                 -0.237139
# BFI_Agreeableness_centered                            -0.198034
# BFI_Conscientious_centered                             0.277312
# BFI_Openness_centered                                  0.192699
# LSNS_Score_centered                                    0.277752
# MSPSS_Score_centered                                   0.410595
# B_RSES_Score_centered                                  0.264062
# AI_Attitudes_Score_centered                            0.043803
# C_State_Empathy_centered                              -0.017837
# C_SEmp_Affective_centered                             -0.107067
# C_SEmp_Cognitive_centered                              0.056758
# C_SEmp_Associative_centered                            0.050216
# C_Social_Attract_centered                              0.006175
# C_Phys_Attract_centered                               -0.150451
# C_Task_Attract_centered                                0.189920
# C_Homophily_centered                                  -0.062888
# C_Attrib_Conf_centered                                 0.551677
# HCI_HHI_Expectation_centered                           0.058302
# HCI_HHI_Trust_centered                                 0.114682
# HCI_HHI_Substitution_centered                         -0.190585
# HHI_Trust___Unfam_centered                             0.036021
# HHI_CommIntent___Unfam_centered                        0.135637
# HHI_Trust___Familiar_centered                          0.482493
# HHI_CommIntent___Familiar_centered                     0.465403
# H_State_Empathy_centered                               0.923609
# H_SEmp_Affective_centered                              0.725538
# H_SEmp_Cognitive_centered                              0.817340
# H_SEmp_Associative_centered                            1.000000
# H_Social_Attract_centered                              0.565541
# H_Task_Attract_centered                                0.553436
# H_Homophily_centered                                   0.587568
# Age_centered                                           0.084358
#
#                                     H_Social_Attract_centered  \
# Frequency_Score_centered                            -0.087303
# Session_Length_Score_centered                       -0.098565
# ULS_8_centered                                      -0.204699
# GPIUS2_centered                                     -0.306120
# SUS_Avg_centered                                     0.325439
# BFI_Extraversion_centered                            0.032446
# BFI_Neurotic_centered                               -0.084161
# BFI_Agreeableness_centered                          -0.118710
# BFI_Conscientious_centered                           0.136418
# BFI_Openness_centered                                0.188079
# LSNS_Score_centered                                  0.174995
# MSPSS_Score_centered                                 0.204393
# B_RSES_Score_centered                                0.137196
# AI_Attitudes_Score_centered                         -0.084514
# C_State_Empathy_centered                            -0.102884
# C_SEmp_Affective_centered                           -0.205805
# C_SEmp_Cognitive_centered                            0.010209
# C_SEmp_Associative_centered                         -0.047990
# C_Social_Attract_centered                           -0.014444
# C_Phys_Attract_centered                             -0.195072
# C_Task_Attract_centered                              0.252054
# C_Homophily_centered                                -0.098412
# C_Attrib_Conf_centered                               0.479248
# HCI_HHI_Expectation_centered                         0.034067
# HCI_HHI_Trust_centered                               0.041648
# HCI_HHI_Substitution_centered                       -0.263440
# HHI_Trust___Unfam_centered                          -0.040579
# HHI_CommIntent___Unfam_centered                      0.045276
# HHI_Trust___Familiar_centered                        0.431367
# HHI_CommIntent___Familiar_centered                   0.344165
# H_State_Empathy_centered                             0.598424
# H_SEmp_Affective_centered                            0.502352
# H_SEmp_Cognitive_centered                            0.586807
# H_SEmp_Associative_centered                          0.565541
# H_Social_Attract_centered                            1.000000
# H_Task_Attract_centered                              0.659027
# H_Homophily_centered                                 0.561159
# Age_centered                                        -0.035569
#
#                                     H_Task_Attract_centered  \
# Frequency_Score_centered                          -0.067526
# Session_Length_Score_centered                     -0.001611
# ULS_8_centered                                    -0.275497
# GPIUS2_centered                                   -0.275870
# SUS_Avg_centered                                   0.364965
# BFI_Extraversion_centered                          0.042576
# BFI_Neurotic_centered                             -0.131258
# BFI_Agreeableness_centered                        -0.184144
# BFI_Conscientious_centered                         0.199524
# BFI_Openness_centered                              0.136517
# LSNS_Score_centered                                0.166605
# MSPSS_Score_centered                               0.337947
# B_RSES_Score_centered                              0.251140
# AI_Attitudes_Score_centered                       -0.011881
# C_State_Empathy_centered                          -0.020859
# C_SEmp_Affective_centered                         -0.129519
# C_SEmp_Cognitive_centered                          0.077906
# C_SEmp_Associative_centered                        0.028729
# C_Social_Attract_centered                          0.023537
# C_Phys_Attract_centered                           -0.104661
# C_Task_Attract_centered                            0.271347
# C_Homophily_centered                              -0.039217
# C_Attrib_Conf_centered                             0.474156
# HCI_HHI_Expectation_centered                       0.070720
# HCI_HHI_Trust_centered                             0.115397
# HCI_HHI_Substitution_centered                     -0.206547
# HHI_Trust___Unfam_centered                         0.009688
# HHI_CommIntent___Unfam_centered                    0.068960
# HHI_Trust___Familiar_centered                      0.470343
# HHI_CommIntent___Familiar_centered                 0.399189
# H_State_Empathy_centered                           0.592443
# H_SEmp_Affective_centered                          0.525333
# H_SEmp_Cognitive_centered                          0.570998
# H_SEmp_Associative_centered                        0.553436
# H_Social_Attract_centered                          0.659027
# H_Task_Attract_centered                            1.000000
# H_Homophily_centered                               0.542217
# Age_centered                                       0.052278
#
#                                     H_Homophily_centered  Age_centered
# Frequency_Score_centered                       -0.042669      0.023190
# Session_Length_Score_centered                   0.001582     -0.007058
# ULS_8_centered                                 -0.267005     -0.038339
# GPIUS2_centered                                -0.217170     -0.059455
# SUS_Avg_centered                                0.328709      0.033189
# BFI_Extraversion_centered                       0.018794     -0.014567
# BFI_Neurotic_centered                          -0.144394     -0.054842
# BFI_Agreeableness_centered                     -0.176825     -0.007753
# BFI_Conscientious_centered                      0.239981      0.122018
# BFI_Openness_centered                           0.186466      0.075641
# LSNS_Score_centered                             0.276755     -0.054982
# MSPSS_Score_centered                            0.386681      0.022291
# B_RSES_Score_centered                           0.265924      0.019373
# AI_Attitudes_Score_centered                     0.027532      0.022455
# C_State_Empathy_centered                       -0.001955      0.036189
# C_SEmp_Affective_centered                      -0.077460      0.018642
# C_SEmp_Cognitive_centered                       0.072850      0.012439
# C_SEmp_Associative_centered                     0.042591      0.078236
# C_Social_Attract_centered                      -0.009708     -0.025342
# C_Phys_Attract_centered                        -0.120170     -0.051976
# C_Task_Attract_centered                         0.232885      0.007397
# C_Homophily_centered                            0.025860      0.018494
# C_Attrib_Conf_centered                          0.619111      0.123141
# HCI_HHI_Expectation_centered                    0.076134      0.020234
# HCI_HHI_Trust_centered                          0.149033      0.032723
# HCI_HHI_Substitution_centered                  -0.171578      0.038563
# HHI_Trust___Unfam_centered                      0.019490      0.054876
# HHI_CommIntent___Unfam_centered                 0.054178     -0.076884
# HHI_Trust___Familiar_centered                   0.463119      0.052249
# HHI_CommIntent___Familiar_centered              0.432590      0.084551
# H_State_Empathy_centered                        0.647336      0.068442
# H_SEmp_Affective_centered                       0.596413      0.011081
# H_SEmp_Cognitive_centered                       0.598940      0.076240
# H_SEmp_Associative_centered                     0.587568      0.084358
# H_Social_Attract_centered                       0.561159     -0.035569
# H_Task_Attract_centered                         0.542217      0.052278
# H_Homophily_centered                            1.000000      0.033198
# Age_centered                                    0.033198      1.000000
#
# [38 rows x 38 columns]

# %%
p_values_matrix
# Out:
#                                     Frequency_Score_centered  \
# Frequency_Score_centered                        0.000000e+00
# Session_Length_Score_centered                   4.589662e-13
# ULS_8_centered                                  2.873425e-01
# GPIUS2_centered                                 3.274714e-12
# SUS_Avg_centered                                5.745737e-07
# BFI_Extraversion_centered                       4.021171e-01
# BFI_Neurotic_centered                           7.840158e-02
# BFI_Agreeableness_centered                      1.817876e-01
# BFI_Conscientious_centered                      2.331007e-03
# BFI_Openness_centered                           4.216147e-02
# LSNS_Score_centered                             9.646702e-01
# MSPSS_Score_centered                            9.280832e-01
# B_RSES_Score_centered                           2.290377e-01
# AI_Attitudes_Score_centered                     1.042151e-09
# C_State_Empathy_centered                        4.091261e-11
# C_SEmp_Affective_centered                       4.840363e-07
# C_SEmp_Cognitive_centered                       9.739244e-09
# C_SEmp_Associative_centered                     1.684430e-12
# C_Social_Attract_centered                       5.565768e-06
# C_Phys_Attract_centered                         1.756705e-04
# C_Task_Attract_centered                         8.569387e-04
# C_Homophily_centered                            2.690688e-07
# C_Attrib_Conf_centered                          8.600033e-01
# HCI_HHI_Expectation_centered                    1.814089e-07
# HCI_HHI_Trust_centered                          1.908969e-09
# HCI_HHI_Substitution_centered                   2.418972e-05
# HHI_Trust___Unfam_centered                      8.500914e-01
# HHI_CommIntent___Unfam_centered                 3.570890e-01
# HHI_Trust___Familiar_centered                   8.277843e-01
# HHI_CommIntent___Familiar_centered              3.231918e-01
# H_State_Empathy_centered                        4.111488e-01
# H_SEmp_Affective_centered                       5.655903e-01
# H_SEmp_Cognitive_centered                       3.859257e-01
# H_SEmp_Associative_centered                     4.052682e-01
# H_Social_Attract_centered                       7.965648e-02
# H_Task_Attract_centered                         1.755430e-01
# H_Homophily_centered                            3.923422e-01
# Age_centered                                    6.421201e-01
#
#                                     Session_Length_Score_centered  \
# Frequency_Score_centered                             4.589662e-13
# Session_Length_Score_centered                        0.000000e+00
# ULS_8_centered                                       4.186856e-02
# GPIUS2_centered                                      2.052956e-07
# SUS_Avg_centered                                     7.201397e-05
# BFI_Extraversion_centered                            9.729755e-01
# BFI_Neurotic_centered                                1.942208e-01
# BFI_Agreeableness_centered                           4.573811e-01
# BFI_Conscientious_centered                           5.088019e-02
# BFI_Openness_centered                                1.635462e-01
# LSNS_Score_centered                                  3.037021e-01
# MSPSS_Score_centered                                 8.436681e-01
# B_RSES_Score_centered                                3.915963e-01
# AI_Attitudes_Score_centered                          2.177842e-06
# C_State_Empathy_centered                             6.060261e-10
# C_SEmp_Affective_centered                            4.695204e-07
# C_SEmp_Cognitive_centered                            2.296929e-07
# C_SEmp_Associative_centered                          2.761518e-10
# C_Social_Attract_centered                            1.978944e-07
# C_Phys_Attract_centered                              7.012245e-07
# C_Task_Attract_centered                              3.070752e-04
# C_Homophily_centered                                 7.097665e-06
# C_Attrib_Conf_centered                               7.206891e-01
# HCI_HHI_Expectation_centered                         2.771150e-05
# HCI_HHI_Trust_centered                               8.873764e-05
# HCI_HHI_Substitution_centered                        6.768925e-04
# HHI_Trust___Unfam_centered                           5.394258e-01
# HHI_CommIntent___Unfam_centered                      6.354660e-01
# HHI_Trust___Familiar_centered                        9.989936e-01
# HHI_CommIntent___Familiar_centered                   6.615239e-01
# H_State_Empathy_centered                             8.593458e-01
# H_SEmp_Affective_centered                            8.666192e-01
# H_SEmp_Cognitive_centered                            8.115078e-01
# H_SEmp_Associative_centered                          8.790839e-01
# H_Social_Attract_centered                            4.772526e-02
# H_Task_Attract_centered                              9.742415e-01
# H_Homophily_centered                                 9.747072e-01
# Age_centered                                         8.875405e-01
#
#                                     ULS_8_centered  GPIUS2_centered  \
# Frequency_Score_centered              2.873425e-01     3.274714e-12
# Session_Length_Score_centered         4.186856e-02     2.052956e-07
# ULS_8_centered                        0.000000e+00     3.597123e-14
# GPIUS2_centered                       3.597123e-14     0.000000e+00
# SUS_Avg_centered                      8.324452e-01     1.520264e-02
# BFI_Extraversion_centered             1.484539e-04     1.784238e-01
# BFI_Neurotic_centered                 0.000000e+00     9.902198e-03
# BFI_Agreeableness_centered            6.290968e-12     3.231319e-01
# BFI_Conscientious_centered            4.660938e-12     1.171155e-01
# BFI_Openness_centered                 5.412953e-01     7.266108e-02
# LSNS_Score_centered                   0.000000e+00     3.626570e-03
# MSPSS_Score_centered                  0.000000e+00     1.566446e-04
# B_RSES_Score_centered                 0.000000e+00     4.243718e-04
# AI_Attitudes_Score_centered           2.170844e-01     0.000000e+00
# C_State_Empathy_centered              1.183564e-02     0.000000e+00
# C_SEmp_Affective_centered             7.877665e-02     0.000000e+00
# C_SEmp_Cognitive_centered             1.628763e-02     0.000000e+00
# C_SEmp_Associative_centered           2.455926e-02     0.000000e+00
# C_Social_Attract_centered             8.240591e-04     0.000000e+00
# C_Phys_Attract_centered               1.497196e-02     0.000000e+00
# C_Task_Attract_centered               3.531278e-01     1.779160e-03
# C_Homophily_centered                  6.027047e-03     0.000000e+00
# C_Attrib_Conf_centered                9.732202e-10     2.300277e-03
# HCI_HHI_Expectation_centered          5.628864e-01     0.000000e+00
# HCI_HHI_Trust_centered                2.244910e-01     0.000000e+00
# HCI_HHI_Substitution_centered         1.464127e-05     0.000000e+00
# HHI_Trust___Unfam_centered            3.458256e-05     4.744392e-01
# HHI_CommIntent___Unfam_centered       2.398090e-07     7.037174e-01
# HHI_Trust___Familiar_centered         0.000000e+00     3.654672e-06
# HHI_CommIntent___Familiar_centered    0.000000e+00     1.094476e-04
# H_State_Empathy_centered              1.776357e-15     1.464107e-06
# H_SEmp_Affective_centered             9.547918e-15     8.186652e-04
# H_SEmp_Cognitive_centered             3.093081e-12     5.807289e-07
# H_SEmp_Associative_centered           2.861489e-12     7.057683e-07
# H_Social_Attract_centered             3.388941e-05     3.270213e-10
# H_Task_Attract_centered               1.806649e-08     1.725427e-08
# H_Homophily_centered                  5.055531e-08     1.061699e-05
# Age_centered                          4.421889e-01     2.331118e-01
#
#                                     SUS_Avg_centered  \
# Frequency_Score_centered                5.745737e-07
# Session_Length_Score_centered           7.201397e-05
# ULS_8_centered                          8.324452e-01
# GPIUS2_centered                         1.520264e-02
# SUS_Avg_centered                        0.000000e+00
# BFI_Extraversion_centered               4.597283e-02
# BFI_Neurotic_centered                   1.241667e-01
# BFI_Agreeableness_centered              1.064314e-02
# BFI_Conscientious_centered              1.134480e-07
# BFI_Openness_centered                   6.368815e-04
# LSNS_Score_centered                     7.319193e-01
# MSPSS_Score_centered                    3.023237e-03
# B_RSES_Score_centered                   2.849888e-02
# AI_Attitudes_Score_centered             0.000000e+00
# C_State_Empathy_centered                0.000000e+00
# C_SEmp_Affective_centered               2.020958e-07
# C_SEmp_Cognitive_centered               0.000000e+00
# C_SEmp_Associative_centered             0.000000e+00
# C_Social_Attract_centered               0.000000e+00
# C_Phys_Attract_centered                 8.480073e-04
# C_Task_Attract_centered                 0.000000e+00
# C_Homophily_centered                    4.033662e-12
# C_Attrib_Conf_centered                  1.643130e-14
# HCI_HHI_Expectation_centered            0.000000e+00
# HCI_HHI_Trust_centered                  0.000000e+00
# HCI_HHI_Substitution_centered           2.795479e-05
# HHI_Trust___Unfam_centered              2.116278e-01
# HHI_CommIntent___Unfam_centered         4.304709e-01
# HHI_Trust___Familiar_centered           4.197404e-05
# HHI_CommIntent___Familiar_centered      9.513645e-05
# H_State_Empathy_centered                1.311353e-09
# H_SEmp_Affective_centered               1.453679e-07
# H_SEmp_Cognitive_centered               7.003144e-09
# H_SEmp_Associative_centered             6.006719e-09
# H_Social_Attract_centered               2.023137e-11
# H_Task_Attract_centered                 3.574918e-14
# H_Homophily_centered                    1.238054e-11
# Age_centered                            5.059218e-01
#
#                                     BFI_Extraversion_centered  \
# Frequency_Score_centered                         4.021171e-01
# Session_Length_Score_centered                    9.729755e-01
# ULS_8_centered                                   1.484539e-04
# GPIUS2_centered                                  1.784238e-01
# SUS_Avg_centered                                 4.597283e-02
# BFI_Extraversion_centered                        0.000000e+00
# BFI_Neurotic_centered                            2.238087e-07
# BFI_Agreeableness_centered                       2.396098e-03
# BFI_Conscientious_centered                       6.859226e-01
# BFI_Openness_centered                            0.000000e+00
# LSNS_Score_centered                              5.867558e-05
# MSPSS_Score_centered                             6.856780e-06
# B_RSES_Score_centered                            1.155859e-05
# AI_Attitudes_Score_centered                      2.885664e-03
# C_State_Empathy_centered                         3.887303e-02
# C_SEmp_Affective_centered                        6.463186e-03
# C_SEmp_Cognitive_centered                        1.618584e-01
# C_SEmp_Associative_centered                      1.070716e-01
# C_Social_Attract_centered                        1.137083e-01
# C_Phys_Attract_centered                          1.581302e-01
# C_Task_Attract_centered                          5.951746e-01
# C_Homophily_centered                             3.122015e-02
# C_Attrib_Conf_centered                           5.291253e-01
# HCI_HHI_Expectation_centered                     3.587394e-01
# HCI_HHI_Trust_centered                           2.905817e-02
# HCI_HHI_Substitution_centered                    1.724753e-01
# HHI_Trust___Unfam_centered                       2.701276e-02
# HHI_CommIntent___Unfam_centered                  3.201016e-04
# HHI_Trust___Familiar_centered                    6.267569e-05
# HHI_CommIntent___Familiar_centered               3.946709e-06
# H_State_Empathy_centered                         2.944239e-01
# H_SEmp_Affective_centered                        6.867220e-02
# H_SEmp_Cognitive_centered                        1.850125e-01
# H_SEmp_Associative_centered                      8.691475e-01
# H_Social_Attract_centered                        5.154898e-01
# H_Task_Attract_centered                          3.933831e-01
# H_Homophily_centered                             7.064590e-01
# Age_centered                                     7.703568e-01
#
#                                     BFI_Neurotic_centered  \
# Frequency_Score_centered                     7.840158e-02
# Session_Length_Score_centered                1.942208e-01
# ULS_8_centered                               0.000000e+00
# GPIUS2_centered                              9.902198e-03
# SUS_Avg_centered                             1.241667e-01
# BFI_Extraversion_centered                    2.238087e-07
# BFI_Neurotic_centered                        0.000000e+00
# BFI_Agreeableness_centered                   5.107026e-15
# BFI_Conscientious_centered                   0.000000e+00
# BFI_Openness_centered                        2.542193e-02
# LSNS_Score_centered                          4.120038e-12
# MSPSS_Score_centered                         0.000000e+00
# B_RSES_Score_centered                        0.000000e+00
# AI_Attitudes_Score_centered                  1.124852e-03
# C_State_Empathy_centered                     4.422659e-02
# C_SEmp_Affective_centered                    7.187289e-03
# C_SEmp_Cognitive_centered                    2.367173e-01
# C_SEmp_Associative_centered                  6.909381e-02
# C_Social_Attract_centered                    3.249022e-01
# C_Phys_Attract_centered                      4.021058e-01
# C_Task_Attract_centered                      2.702883e-01
# C_Homophily_centered                         1.045858e-01
# C_Attrib_Conf_centered                       3.085942e-05
# HCI_HHI_Expectation_centered                 6.004874e-02
# HCI_HHI_Trust_centered                       4.392138e-02
# HCI_HHI_Substitution_centered                2.808875e-01
# HHI_Trust___Unfam_centered                   3.546582e-05
# HHI_CommIntent___Unfam_centered              0.000000e+00
# HHI_Trust___Familiar_centered                2.570557e-10
# HHI_CommIntent___Familiar_centered           0.000000e+00
# H_State_Empathy_centered                     1.828142e-07
# H_SEmp_Affective_centered                    2.738707e-07
# H_SEmp_Cognitive_centered                    1.597863e-05
# H_SEmp_Associative_centered                  1.431227e-06
# H_Social_Attract_centered                    9.114697e-02
# H_Task_Attract_centered                      8.253785e-03
# H_Homophily_centered                         3.631202e-03
# Age_centered                                 2.714555e-01
#
#                                     BFI_Agreeableness_centered  \
# Frequency_Score_centered                          1.817876e-01
# Session_Length_Score_centered                     4.573811e-01
# ULS_8_centered                                    6.290968e-12
# GPIUS2_centered                                   3.231319e-01
# SUS_Avg_centered                                  1.064314e-02
# BFI_Extraversion_centered                         2.396098e-03
# BFI_Neurotic_centered                             5.107026e-15
# BFI_Agreeableness_centered                        0.000000e+00
# BFI_Conscientious_centered                        2.281006e-08
# BFI_Openness_centered                             6.626893e-01
# LSNS_Score_centered                               8.928805e-08
# MSPSS_Score_centered                              0.000000e+00
# B_RSES_Score_centered                             4.887646e-12
# AI_Attitudes_Score_centered                       1.124704e-03
# C_State_Empathy_centered                          2.064377e-03
# C_SEmp_Affective_centered                         1.580441e-03
# C_SEmp_Cognitive_centered                         1.067162e-02
# C_SEmp_Associative_centered                       1.184579e-02
# C_Social_Attract_centered                         6.907363e-03
# C_Phys_Attract_centered                           2.557898e-01
# C_Task_Attract_centered                           1.199009e-01
# C_Homophily_centered                              9.059163e-03
# C_Attrib_Conf_centered                            1.469213e-05
# HCI_HHI_Expectation_centered                      2.260009e-03
# HCI_HHI_Trust_centered                            5.524253e-03
# HCI_HHI_Substitution_centered                     6.205050e-01
# HHI_Trust___Unfam_centered                        4.107825e-14
# HHI_CommIntent___Unfam_centered                   1.275580e-07
# HHI_Trust___Familiar_centered                     0.000000e+00
# HHI_CommIntent___Familiar_centered                0.000000e+00
# H_State_Empathy_centered                          2.696962e-07
# H_SEmp_Affective_centered                         3.867249e-09
# H_SEmp_Cognitive_centered                         3.075986e-05
# H_SEmp_Associative_centered                       6.127185e-05
# H_Social_Attract_centered                         1.698228e-02
# H_Task_Attract_centered                           1.979179e-04
# H_Homophily_centered                              3.552147e-04
# Age_centered                                      8.765496e-01
#
#                                     BFI_Conscientious_centered  \
# Frequency_Score_centered                          2.331007e-03
# Session_Length_Score_centered                     5.088019e-02
# ULS_8_centered                                    4.660938e-12
# GPIUS2_centered                                   1.171155e-01
# SUS_Avg_centered                                  1.134480e-07
# BFI_Extraversion_centered                         6.859226e-01
# BFI_Neurotic_centered                             0.000000e+00
# BFI_Agreeableness_centered                        2.281006e-08
# BFI_Conscientious_centered                        0.000000e+00
# BFI_Openness_centered                             7.166175e-02
# LSNS_Score_centered                               2.874028e-05
# MSPSS_Score_centered                              1.517031e-11
# B_RSES_Score_centered                             1.110223e-15
# AI_Attitudes_Score_centered                       9.266924e-03
# C_State_Empathy_centered                          7.718202e-02
# C_SEmp_Affective_centered                         4.304104e-02
# C_SEmp_Cognitive_centered                         7.389652e-02
# C_SEmp_Associative_centered                       1.015251e-01
# C_Social_Attract_centered                         5.335723e-02
# C_Phys_Attract_centered                           6.092249e-01
# C_Task_Attract_centered                           1.324131e-04
# C_Homophily_centered                              2.385143e-02
# C_Attrib_Conf_centered                            2.597707e-07
# HCI_HHI_Expectation_centered                      1.399189e-02
# HCI_HHI_Trust_centered                            7.166080e-04
# HCI_HHI_Substitution_centered                     9.548113e-01
# HHI_Trust___Unfam_centered                        1.647051e-01
# HHI_CommIntent___Unfam_centered                   8.076732e-03
# HHI_Trust___Familiar_centered                     4.393161e-09
# HHI_CommIntent___Familiar_centered                8.726353e-12
# H_State_Empathy_centered                          7.077787e-10
# H_SEmp_Affective_centered                         2.939370e-09
# H_SEmp_Cognitive_centered                         2.841594e-08
# H_SEmp_Associative_centered                       1.443278e-08
# H_Social_Attract_centered                         6.026689e-03
# H_Task_Attract_centered                           5.376366e-05
# H_Homophily_centered                              1.060282e-06
# Age_centered                                      1.412376e-02
#
#                                     BFI_Openness_centered  ...  \
# Frequency_Score_centered                         0.042161  ...
# Session_Length_Score_centered                    0.163546  ...
# ULS_8_centered                                   0.541295  ...
# GPIUS2_centered                                  0.072661  ...
# SUS_Avg_centered                                 0.000637  ...
# BFI_Extraversion_centered                        0.000000  ...
# BFI_Neurotic_centered                            0.025422  ...
# BFI_Agreeableness_centered                       0.662689  ...
# BFI_Conscientious_centered                       0.071662  ...
# BFI_Openness_centered                            0.000000  ...
# LSNS_Score_centered                              0.717868  ...
# MSPSS_Score_centered                             0.456284  ...
# B_RSES_Score_centered                            0.807230  ...
# AI_Attitudes_Score_centered                      0.032243  ...
# C_State_Empathy_centered                         0.656707  ...
# C_SEmp_Affective_centered                        0.185059  ...
# C_SEmp_Cognitive_centered                        0.916820  ...
# C_SEmp_Associative_centered                      0.731849  ...
# C_Social_Attract_centered                        0.196367  ...
# C_Phys_Attract_centered                          0.241517  ...
# C_Task_Attract_centered                          0.409333  ...
# C_Homophily_centered                             0.317498  ...
# C_Attrib_Conf_centered                           0.002500  ...
# HCI_HHI_Expectation_centered                     0.894509  ...
# HCI_HHI_Trust_centered                           0.496834  ...
# HCI_HHI_Substitution_centered                    0.000616  ...
# HHI_Trust___Unfam_centered                       0.530911  ...
# HHI_CommIntent___Unfam_centered                  0.015386  ...
# HHI_Trust___Familiar_centered                    0.678680  ...
# HHI_CommIntent___Familiar_centered               0.652035  ...
# H_State_Empathy_centered                         0.003187  ...
# H_SEmp_Affective_centered                        0.019461  ...
# H_SEmp_Cognitive_centered                        0.058695  ...
# H_SEmp_Associative_centered                      0.000097  ...
# H_Social_Attract_centered                        0.000143  ...
# H_Task_Attract_centered                          0.005990  ...
# H_Homophily_centered                             0.000164  ...
# Age_centered                                     0.129056  ...
#
#                                     HHI_Trust___Familiar_centered  \
# Frequency_Score_centered                             8.277843e-01
# Session_Length_Score_centered                        9.989936e-01
# ULS_8_centered                                       0.000000e+00
# GPIUS2_centered                                      3.654672e-06
# SUS_Avg_centered                                     4.197404e-05
# BFI_Extraversion_centered                            6.267569e-05
# BFI_Neurotic_centered                                2.570557e-10
# BFI_Agreeableness_centered                           0.000000e+00
# BFI_Conscientious_centered                           4.393161e-09
# BFI_Openness_centered                                6.786803e-01
# LSNS_Score_centered                                  0.000000e+00
# MSPSS_Score_centered                                 0.000000e+00
# B_RSES_Score_centered                                0.000000e+00
# AI_Attitudes_Score_centered                          2.953353e-01
# C_State_Empathy_centered                             8.668054e-01
# C_SEmp_Affective_centered                            2.329847e-01
# C_SEmp_Cognitive_centered                            3.181593e-01
# C_SEmp_Associative_centered                          2.495264e-01
# C_Social_Attract_centered                            8.483029e-01
# C_Phys_Attract_centered                              1.387515e-02
# C_Task_Attract_centered                              5.577587e-03
# C_Homophily_centered                                 8.400115e-01
# C_Attrib_Conf_centered                               0.000000e+00
# HCI_HHI_Expectation_centered                         2.823143e-02
# HCI_HHI_Trust_centered                               3.406393e-02
# HCI_HHI_Substitution_centered                        3.483153e-04
# HHI_Trust___Unfam_centered                           9.901638e-08
# HHI_CommIntent___Unfam_centered                      1.902341e-06
# HHI_Trust___Familiar_centered                        0.000000e+00
# HHI_CommIntent___Familiar_centered                   0.000000e+00
# H_State_Empathy_centered                             0.000000e+00
# H_SEmp_Affective_centered                            0.000000e+00
# H_SEmp_Cognitive_centered                            0.000000e+00
# H_SEmp_Associative_centered                          0.000000e+00
# H_Social_Attract_centered                            0.000000e+00
# H_Task_Attract_centered                              0.000000e+00
# H_Homophily_centered                                 0.000000e+00
# Age_centered                                         2.947970e-01
#
#                                     HHI_CommIntent___Familiar_centered  \
# Frequency_Score_centered                                  3.231918e-01
# Session_Length_Score_centered                             6.615239e-01
# ULS_8_centered                                            0.000000e+00
# GPIUS2_centered                                           1.094476e-04
# SUS_Avg_centered                                          9.513645e-05
# BFI_Extraversion_centered                                 3.946709e-06
# BFI_Neurotic_centered                                     0.000000e+00
# BFI_Agreeableness_centered                                0.000000e+00
# BFI_Conscientious_centered                                8.726353e-12
# BFI_Openness_centered                                     6.520352e-01
# LSNS_Score_centered                                       0.000000e+00
# MSPSS_Score_centered                                      0.000000e+00
# B_RSES_Score_centered                                     0.000000e+00
# AI_Attitudes_Score_centered                               3.166225e-02
# C_State_Empathy_centered                                  3.303554e-01
# C_SEmp_Affective_centered                                 8.685591e-01
# C_SEmp_Cognitive_centered                                 1.382898e-01
# C_SEmp_Associative_centered                               1.139185e-01
# C_Social_Attract_centered                                 6.303600e-01
# C_Phys_Attract_centered                                   1.331836e-01
# C_Task_Attract_centered                                   2.491623e-02
# C_Homophily_centered                                      2.198092e-01
# C_Attrib_Conf_centered                                    0.000000e+00
# HCI_HHI_Expectation_centered                              6.298545e-03
# HCI_HHI_Trust_centered                                    9.488320e-03
# HCI_HHI_Substitution_centered                             1.023535e-02
# HHI_Trust___Unfam_centered                                8.361993e-07
# HHI_CommIntent___Unfam_centered                           3.322898e-12
# HHI_Trust___Familiar_centered                             0.000000e+00
# HHI_CommIntent___Familiar_centered                        0.000000e+00
# H_State_Empathy_centered                                  0.000000e+00
# H_SEmp_Affective_centered                                 0.000000e+00
# H_SEmp_Cognitive_centered                                 0.000000e+00
# H_SEmp_Associative_centered                               0.000000e+00
# H_Social_Attract_centered                                 1.121547e-12
# H_Task_Attract_centered                                   0.000000e+00
# H_Homophily_centered                                      0.000000e+00
# Age_centered                                              8.965209e-02
#
#                                     H_State_Empathy_centered  \
# Frequency_Score_centered                        4.111488e-01
# Session_Length_Score_centered                   8.593458e-01
# ULS_8_centered                                  1.776357e-15
# GPIUS2_centered                                 1.464107e-06
# SUS_Avg_centered                                1.311353e-09
# BFI_Extraversion_centered                       2.944239e-01
# BFI_Neurotic_centered                           1.828142e-07
# BFI_Agreeableness_centered                      2.696962e-07
# BFI_Conscientious_centered                      7.077787e-10
# BFI_Openness_centered                           3.187234e-03
# LSNS_Score_centered                             2.191944e-10
# MSPSS_Score_centered                            0.000000e+00
# B_RSES_Score_centered                           7.551590e-10
# AI_Attitudes_Score_centered                     1.911888e-01
# C_State_Empathy_centered                        9.676813e-01
# C_SEmp_Affective_centered                       1.725072e-01
# C_SEmp_Cognitive_centered                       2.235601e-01
# C_SEmp_Associative_centered                     2.162124e-01
# C_Social_Attract_centered                       5.450984e-01
# C_Phys_Attract_centered                         7.996203e-03
# C_Task_Attract_centered                         7.934965e-05
# C_Homophily_centered                            4.231502e-01
# C_Attrib_Conf_centered                          0.000000e+00
# HCI_HHI_Expectation_centered                    1.516730e-01
# HCI_HHI_Trust_centered                          1.087634e-02
# HCI_HHI_Substitution_centered                   1.463457e-03
# HHI_Trust___Unfam_centered                      2.102914e-01
# HHI_CommIntent___Unfam_centered                 1.120541e-03
# HHI_Trust___Familiar_centered                   0.000000e+00
# HHI_CommIntent___Familiar_centered              0.000000e+00
# H_State_Empathy_centered                        0.000000e+00
# H_SEmp_Affective_centered                       0.000000e+00
# H_SEmp_Cognitive_centered                       0.000000e+00
# H_SEmp_Associative_centered                     0.000000e+00
# H_Social_Attract_centered                       0.000000e+00
# H_Task_Attract_centered                         0.000000e+00
# H_Homophily_centered                            0.000000e+00
# Age_centered                                    1.697472e-01
#
#                                     H_SEmp_Affective_centered  \
# Frequency_Score_centered                         5.655903e-01
# Session_Length_Score_centered                    8.666192e-01
# ULS_8_centered                                   9.547918e-15
# GPIUS2_centered                                  8.186652e-04
# SUS_Avg_centered                                 1.453679e-07
# BFI_Extraversion_centered                        6.867220e-02
# BFI_Neurotic_centered                            2.738707e-07
# BFI_Agreeableness_centered                       3.867249e-09
# BFI_Conscientious_centered                       2.939370e-09
# BFI_Openness_centered                            1.946123e-02
# LSNS_Score_centered                              5.402983e-09
# MSPSS_Score_centered                             0.000000e+00
# B_RSES_Score_centered                            4.293237e-10
# AI_Attitudes_Score_centered                      3.898261e-02
# C_State_Empathy_centered                         4.253833e-01
# C_SEmp_Affective_centered                        9.501078e-01
# C_SEmp_Cognitive_centered                        1.172775e-01
# C_SEmp_Associative_centered                      1.456154e-01
# C_Social_Attract_centered                        1.491657e-01
# C_Phys_Attract_centered                          8.488828e-02
# C_Task_Attract_centered                          2.918314e-05
# C_Homophily_centered                             9.841369e-01
# C_Attrib_Conf_centered                           0.000000e+00
# HCI_HHI_Expectation_centered                     4.291840e-02
# HCI_HHI_Trust_centered                           3.966825e-03
# HCI_HHI_Substitution_centered                    8.744944e-02
# HHI_Trust___Unfam_centered                       6.219478e-02
# HHI_CommIntent___Unfam_centered                  2.806027e-04
# HHI_Trust___Familiar_centered                    0.000000e+00
# HHI_CommIntent___Familiar_centered               0.000000e+00
# H_State_Empathy_centered                         0.000000e+00
# H_SEmp_Affective_centered                        0.000000e+00
# H_SEmp_Cognitive_centered                        0.000000e+00
# H_SEmp_Associative_centered                      0.000000e+00
# H_Social_Attract_centered                        0.000000e+00
# H_Task_Attract_centered                          0.000000e+00
# H_Homophily_centered                             0.000000e+00
# Age_centered                                     8.242842e-01
#
#                                     H_SEmp_Cognitive_centered  \
# Frequency_Score_centered                         3.859257e-01
# Session_Length_Score_centered                    8.115078e-01
# ULS_8_centered                                   3.093081e-12
# GPIUS2_centered                                  5.807289e-07
# SUS_Avg_centered                                 7.003144e-09
# BFI_Extraversion_centered                        1.850125e-01
# BFI_Neurotic_centered                            1.597863e-05
# BFI_Agreeableness_centered                       3.075986e-05
# BFI_Conscientious_centered                       2.841594e-08
# BFI_Openness_centered                            5.869505e-02
# LSNS_Score_centered                              2.757798e-09
# MSPSS_Score_centered                             0.000000e+00
# B_RSES_Score_centered                            5.560616e-08
# AI_Attitudes_Score_centered                      7.896774e-01
# C_State_Empathy_centered                         7.311176e-01
# C_SEmp_Affective_centered                        7.590006e-02
# C_SEmp_Cognitive_centered                        3.886033e-01
# C_SEmp_Associative_centered                      3.309833e-01
# C_Social_Attract_centered                        7.062473e-01
# C_Phys_Attract_centered                          1.948122e-02
# C_Task_Attract_centered                          2.434638e-03
# C_Homophily_centered                             3.462006e-01
# C_Attrib_Conf_centered                           0.000000e+00
# HCI_HHI_Expectation_centered                     4.132572e-01
# HCI_HHI_Trust_centered                           4.035082e-02
# HCI_HHI_Substitution_centered                    1.228886e-03
# HHI_Trust___Unfam_centered                       7.186784e-01
# HHI_CommIntent___Unfam_centered                  9.742060e-03
# HHI_Trust___Familiar_centered                    0.000000e+00
# HHI_CommIntent___Familiar_centered               0.000000e+00
# H_State_Empathy_centered                         0.000000e+00
# H_SEmp_Affective_centered                        0.000000e+00
# H_SEmp_Cognitive_centered                        0.000000e+00
# H_SEmp_Associative_centered                      0.000000e+00
# H_Social_Attract_centered                        0.000000e+00
# H_Task_Attract_centered                          0.000000e+00
# H_Homophily_centered                             0.000000e+00
# Age_centered                                     1.260475e-01
#
#                                     H_SEmp_Associative_centered  \
# Frequency_Score_centered                           4.052682e-01
# Session_Length_Score_centered                      8.790839e-01
# ULS_8_centered                                     2.861489e-12
# GPIUS2_centered                                    7.057683e-07
# SUS_Avg_centered                                   6.006719e-09
# BFI_Extraversion_centered                          8.691475e-01
# BFI_Neurotic_centered                              1.431227e-06
# BFI_Agreeableness_centered                         6.127185e-05
# BFI_Conscientious_centered                         1.443278e-08
# BFI_Openness_centered                              9.707090e-05
# LSNS_Score_centered                                1.366441e-08
# MSPSS_Score_centered                               0.000000e+00
# B_RSES_Score_centered                              7.162421e-08
# AI_Attitudes_Score_centered                        3.798730e-01
# C_State_Empathy_centered                           7.207590e-01
# C_SEmp_Affective_centered                          3.143327e-02
# C_SEmp_Cognitive_centered                          2.550362e-01
# C_SEmp_Associative_centered                        3.140173e-01
# C_Social_Attract_centered                          9.015321e-01
# C_Phys_Attract_centered                            2.429913e-03
# C_Task_Attract_centered                            1.227695e-04
# C_Homophily_centered                               2.071747e-01
# C_Attrib_Conf_centered                             0.000000e+00
# HCI_HHI_Expectation_centered                       2.423134e-01
# HCI_HHI_Trust_centered                             2.113621e-02
# HCI_HHI_Substitution_centered                      1.160948e-04
# HHI_Trust___Unfam_centered                         4.702865e-01
# HHI_CommIntent___Unfam_centered                    6.324586e-03
# HHI_Trust___Familiar_centered                      0.000000e+00
# HHI_CommIntent___Familiar_centered                 0.000000e+00
# H_State_Empathy_centered                           0.000000e+00
# H_SEmp_Affective_centered                          0.000000e+00
# H_SEmp_Cognitive_centered                          0.000000e+00
# H_SEmp_Associative_centered                        0.000000e+00
# H_Social_Attract_centered                          0.000000e+00
# H_Task_Attract_centered                            0.000000e+00
# H_Homophily_centered                               0.000000e+00
# Age_centered                                       9.038888e-02
#
#                                     H_Social_Attract_centered  \
# Frequency_Score_centered                         7.965648e-02
# Session_Length_Score_centered                    4.772526e-02
# ULS_8_centered                                   3.388941e-05
# GPIUS2_centered                                  3.270213e-10
# SUS_Avg_centered                                 2.023137e-11
# BFI_Extraversion_centered                        5.154898e-01
# BFI_Neurotic_centered                            9.114697e-02
# BFI_Agreeableness_centered                       1.698228e-02
# BFI_Conscientious_centered                       6.026689e-03
# BFI_Openness_centered                            1.431741e-04
# LSNS_Score_centered                              4.097001e-04
# MSPSS_Score_centered                             3.483641e-05
# B_RSES_Score_centered                            5.742597e-03
# AI_Attitudes_Score_centered                      8.979323e-02
# C_State_Empathy_centered                         3.873264e-02
# C_SEmp_Affective_centered                        3.065869e-05
# C_SEmp_Cognitive_centered                        8.379070e-01
# C_SEmp_Associative_centered                      3.359715e-01
# C_Social_Attract_centered                        7.722446e-01
# C_Phys_Attract_centered                          7.922348e-05
# C_Task_Attract_centered                          2.841845e-07
# C_Homophily_centered                             4.807270e-02
# C_Attrib_Conf_centered                           0.000000e+00
# HCI_HHI_Expectation_centered                     4.947210e-01
# HCI_HHI_Trust_centered                           4.037842e-01
# HCI_HHI_Substitution_centered                    7.705864e-08
# HHI_Trust___Unfam_centered                       4.159630e-01
# HHI_CommIntent___Unfam_centered                  3.640415e-01
# HHI_Trust___Familiar_centered                    0.000000e+00
# HHI_CommIntent___Familiar_centered               1.121547e-12
# H_State_Empathy_centered                         0.000000e+00
# H_SEmp_Affective_centered                        0.000000e+00
# H_SEmp_Cognitive_centered                        0.000000e+00
# H_SEmp_Associative_centered                      0.000000e+00
# H_Social_Attract_centered                        0.000000e+00
# H_Task_Attract_centered                          0.000000e+00
# H_Homophily_centered                             0.000000e+00
# Age_centered                                     4.758796e-01
#
#                                     H_Task_Attract_centered  \
# Frequency_Score_centered                       1.755430e-01
# Session_Length_Score_centered                  9.742415e-01
# ULS_8_centered                                 1.806649e-08
# GPIUS2_centered                                1.725427e-08
# SUS_Avg_centered                               3.574918e-14
# BFI_Extraversion_centered                      3.933831e-01
# BFI_Neurotic_centered                          8.253785e-03
# BFI_Agreeableness_centered                     1.979179e-04
# BFI_Conscientious_centered                     5.376366e-05
# BFI_Openness_centered                          5.990077e-03
# LSNS_Score_centered                            7.741842e-04
# MSPSS_Score_centered                           2.994938e-12
# B_RSES_Score_centered                          3.147267e-07
# AI_Attitudes_Score_centered                    8.118171e-01
# C_State_Empathy_centered                       6.759365e-01
# C_SEmp_Affective_centered                      9.154968e-03
# C_SEmp_Cognitive_centered                      1.179556e-01
# C_SEmp_Associative_centered                    5.647643e-01
# C_Social_Attract_centered                      6.371499e-01
# C_Phys_Attract_centered                        3.547288e-02
# C_Task_Attract_centered                        3.000298e-08
# C_Homophily_centered                           4.318064e-01
# C_Attrib_Conf_centered                         0.000000e+00
# HCI_HHI_Expectation_centered                   1.559473e-01
# HCI_HHI_Trust_centered                         2.034011e-02
# HCI_HHI_Substitution_centered                  2.865758e-05
# HHI_Trust___Unfam_centered                     8.460790e-01
# HHI_CommIntent___Unfam_centered                1.665337e-01
# HHI_Trust___Familiar_centered                  0.000000e+00
# HHI_CommIntent___Familiar_centered             0.000000e+00
# H_State_Empathy_centered                       0.000000e+00
# H_SEmp_Affective_centered                      0.000000e+00
# H_SEmp_Cognitive_centered                      0.000000e+00
# H_SEmp_Associative_centered                    0.000000e+00
# H_Social_Attract_centered                      0.000000e+00
# H_Task_Attract_centered                        0.000000e+00
# H_Homophily_centered                           0.000000e+00
# Age_centered                                   2.945311e-01
#
#                                     H_Homophily_centered  Age_centered
# Frequency_Score_centered                    3.923422e-01      0.642120
# Session_Length_Score_centered               9.747072e-01      0.887540
# ULS_8_centered                              5.055531e-08      0.442189
# GPIUS2_centered                             1.061699e-05      0.233112
# SUS_Avg_centered                            1.238054e-11      0.505922
# BFI_Extraversion_centered                   7.064590e-01      0.770357
# BFI_Neurotic_centered                       3.631202e-03      0.271456
# BFI_Agreeableness_centered                  3.552147e-04      0.876550
# BFI_Conscientious_centered                  1.060282e-06      0.014124
# BFI_Openness_centered                       1.636284e-04      0.129056
# LSNS_Score_centered                         1.546485e-08      0.270228
# MSPSS_Score_centered                        6.661338e-16      0.655078
# B_RSES_Score_centered                       5.748716e-08      0.697847
# AI_Attitudes_Score_centered                 5.811014e-01      0.652706
# C_State_Empathy_centered                    9.687560e-01      0.468223
# C_SEmp_Affective_centered                   1.200792e-01      0.708728
# C_SEmp_Cognitive_centered                   1.438309e-01      0.803162
# C_SEmp_Associative_centered                 3.932194e-01      0.116402
# C_Social_Attract_centered                   8.457695e-01      0.611539
# C_Phys_Attract_centered                     1.566340e-02      0.297330
# C_Task_Attract_centered                     2.227207e-06      0.882172
# C_Homophily_centered                        6.042865e-01      0.710938
# C_Attrib_Conf_centered                      0.000000e+00      0.013254
# HCI_HHI_Expectation_centered                1.265734e-01      0.685126
# HCI_HHI_Trust_centered                      2.673034e-03      0.511911
# HCI_HHI_Substitution_centered               5.327769e-04      0.439523
# HHI_Trust___Unfam_centered                  6.961211e-01      0.271159
# HHI_CommIntent___Unfam_centered             2.773046e-01      0.122867
# HHI_Trust___Familiar_centered               0.000000e+00      0.294797
# HHI_CommIntent___Familiar_centered          0.000000e+00      0.089652
# H_State_Empathy_centered                    0.000000e+00      0.169747
# H_SEmp_Affective_centered                   0.000000e+00      0.824284
# H_SEmp_Cognitive_centered                   0.000000e+00      0.126047
# H_SEmp_Associative_centered                 0.000000e+00      0.090389
# H_Social_Attract_centered                   0.000000e+00      0.475880
# H_Task_Attract_centered                     0.000000e+00      0.294531
# H_Homophily_centered                        0.000000e+00      0.505805
# Age_centered                                5.058046e-01      0.000000
#
# [38 rows x 38 columns]

# %% [markdown]
# # Apply Benjamini Hochberg correction

# %%
def apply_benjamini_hochberg(correlation_matrix, p_values_matrix, alpha=0.05):
    # Flatten the p-values matrix
    p_values_flat = p_values_matrix.values.flatten()
    
    # Apply Benjamini-Hochberg correction
    rejected, p_values_corrected, _, _ = multipletests(p_values_flat, alpha=alpha, method='fdr_bh')
    
    # Reshape the corrected p-values back into a matrix
    p_values_corrected_matrix = p_values_corrected.reshape(p_values_matrix.shape)
    
    # Create a DataFrame with the corrected p-values
    p_values_corrected_df = pd.DataFrame(p_values_corrected_matrix, 
                                         index=p_values_matrix.index, 
                                         columns=p_values_matrix.columns)
    
    # Create a mask for significant correlations
    significant_mask = p_values_corrected_df < alpha
    
    # Apply the mask to the correlation matrix
    correlation_matrix_significant = correlation_matrix.where(significant_mask)
    
    return correlation_matrix_significant, p_values_corrected_df

# Significant correlations after BH correction
correlation_matrix_significant, p_values_corrected = apply_benjamini_hochberg(correlation_matrix, p_values_matrix)

# Print the number of significant correlations
print(f"Number of significant correlations before BH correction: {significant_corr.notna().sum().sum() // 2}")
print(f"Number of significant correlations after BH correction: {correlation_matrix_significant.notna().sum().sum() // 2}")
# Out:
# Number of significant correlations before BH correction: 722
# Number of significant correlations after BH correction: 421

# %%
p_values_corrected
# Out:
#                                     Frequency_Score_centered  \
# Frequency_Score_centered                        0.000000e+00
# Session_Length_Score_centered                   1.820734e-12
# ULS_8_centered                                  3.744788e-01
# GPIUS2_centered                                 1.250975e-11
# SUS_Avg_centered                                1.571372e-06
# BFI_Extraversion_centered                       4.929177e-01
# BFI_Neurotic_centered                           1.209529e-01
# BFI_Agreeableness_centered                      2.509573e-01
# BFI_Conscientious_centered                      4.767670e-03
# BFI_Openness_centered                           6.949904e-02
# LSNS_Score_centered                             9.782189e-01
# MSPSS_Score_centered                            9.464351e-01
# B_RSES_Score_centered                           3.073703e-01
# AI_Attitudes_Score_centered                     3.549214e-09
# C_State_Empathy_centered                        1.476945e-10
# C_SEmp_Affective_centered                       1.333871e-06
# C_SEmp_Cognitive_centered                       3.139167e-08
# C_SEmp_Associative_centered                     6.573831e-12
# C_Social_Attract_centered                       1.445498e-05
# C_Phys_Attract_centered                         3.963567e-04
# C_Task_Attract_centered                         1.819735e-03
# C_Homophily_centered                            7.576679e-07
# C_Attrib_Conf_centered                          8.947009e-01
# HCI_HHI_Expectation_centered                    5.302723e-07
# HCI_HHI_Trust_centered                          6.410584e-09
# HCI_HHI_Substitution_centered                   6.085359e-05
# HHI_Trust___Unfam_centered                      8.895159e-01
# HHI_CommIntent___Unfam_centered                 4.476011e-01
# HHI_Trust___Familiar_centered                   8.776216e-01
# HHI_CommIntent___Familiar_centered              4.115423e-01
# H_State_Empathy_centered                        4.997465e-01
# H_SEmp_Affective_centered                       6.502487e-01
# H_SEmp_Cognitive_centered                       4.795841e-01
# H_SEmp_Associative_centered                     4.950993e-01
# H_Social_Attract_centered                       1.223659e-01
# H_Task_Attract_centered                         2.432670e-01
# H_Homophily_centered                            4.846802e-01
# Age_centered                                    7.221351e-01
#
#                                     Session_Length_Score_centered  \
# Frequency_Score_centered                             1.820734e-12
# Session_Length_Score_centered                        0.000000e+00
# ULS_8_centered                                       6.917414e-02
# GPIUS2_centered                                      5.905314e-07
# SUS_Avg_centered                                     1.699153e-04
# BFI_Extraversion_centered                            9.801373e-01
# BFI_Neurotic_centered                                2.660862e-01
# BFI_Agreeableness_centered                           5.440348e-01
# BFI_Conscientious_centered                           8.199888e-02
# BFI_Openness_centered                                2.297283e-01
# LSNS_Score_centered                                  3.908608e-01
# MSPSS_Score_centered                                 8.878910e-01
# B_RSES_Score_centered                                4.846802e-01
# AI_Attitudes_Score_centered                          5.738694e-06
# C_State_Empathy_centered                             2.113772e-09
# C_SEmp_Affective_centered                            1.298826e-06
# C_SEmp_Cognitive_centered                            6.554874e-07
# C_SEmp_Associative_centered                          9.773607e-10
# C_Social_Attract_centered                            5.738143e-07
# C_Phys_Attract_centered                              1.903324e-06
# C_Task_Attract_centered                              6.864035e-04
# C_Homophily_centered                                 1.823671e-05
# C_Attrib_Conf_centered                               7.801919e-01
# HCI_HHI_Expectation_centered                         6.947120e-05
# HCI_HHI_Trust_centered                               2.073417e-04
# HCI_HHI_Substitution_centered                        1.472037e-03
# HHI_Trust___Unfam_centered                           6.251452e-01
# HHI_CommIntent___Unfam_centered                      7.180087e-01
# HHI_Trust___Familiar_centered                        9.989936e-01
# HHI_CommIntent___Familiar_centered                   7.359326e-01
# H_State_Empathy_centered                             8.947009e-01
# H_SEmp_Affective_centered                            8.990322e-01
# H_SEmp_Cognitive_centered                            8.632282e-01
# H_SEmp_Associative_centered                          9.067122e-01
# H_Social_Attract_centered                            7.725927e-02
# H_Task_Attract_centered                              9.801373e-01
# H_Homophily_centered                                 9.801373e-01
# Age_centered                                         9.115280e-01
#
#                                     ULS_8_centered  GPIUS2_centered  \
# Frequency_Score_centered              3.744788e-01     1.250975e-11
# Session_Length_Score_centered         6.917414e-02     5.905314e-07
# ULS_8_centered                        0.000000e+00     1.467301e-13
# GPIUS2_centered                       1.467301e-13     0.000000e+00
# SUS_Avg_centered                      8.812689e-01     2.737234e-02
# BFI_Extraversion_centered             3.381189e-04     2.467854e-01
# BFI_Neurotic_centered                 0.000000e+00     1.842625e-02
# BFI_Agreeableness_centered            2.329271e-11     4.115423e-01
# BFI_Conscientious_centered            1.743626e-11     1.728048e-01
# BFI_Openness_centered                 6.263065e-01     1.133073e-01
# LSNS_Score_centered                   0.000000e+00     7.202550e-03
# MSPSS_Score_centered                  0.000000e+00     3.556522e-04
# B_RSES_Score_centered                 0.000000e+00     9.341355e-04
# AI_Attitudes_Score_centered           2.940618e-01     0.000000e+00
# C_State_Empathy_centered              2.165231e-02     0.000000e+00
# C_SEmp_Affective_centered             1.212724e-01     0.000000e+00
# C_SEmp_Cognitive_centered             2.910808e-02     0.000000e+00
# C_SEmp_Associative_centered           4.293411e-02     0.000000e+00
# C_Social_Attract_centered             1.760268e-03     0.000000e+00
# C_Phys_Attract_centered               2.702440e-02     0.000000e+00
# C_Task_Attract_centered               4.434057e-01     3.701884e-03
# C_Homophily_centered                  1.172919e-02     0.000000e+00
# C_Attrib_Conf_centered                3.330166e-09     4.718182e-03
# HCI_HHI_Expectation_centered          6.492076e-01     0.000000e+00
# HCI_HHI_Trust_centered                3.018296e-01     0.000000e+00
# HCI_HHI_Substitution_centered         3.722007e-05     0.000000e+00
# HHI_Trust___Unfam_centered            8.406938e-05     5.606303e-01
# HHI_CommIntent___Unfam_centered       6.816618e-07     7.721641e-01
# HHI_Trust___Familiar_centered         0.000000e+00     9.560409e-06
# HHI_CommIntent___Familiar_centered    0.000000e+00     2.532730e-04
# H_State_Empathy_centered              7.456568e-15     3.886342e-06
# H_SEmp_Affective_centered             3.961837e-14     1.753936e-03
# H_SEmp_Cognitive_centered             1.187875e-11     1.582212e-06
# H_SEmp_Associative_centered           1.110750e-11     1.908482e-06
# H_Social_Attract_centered             8.266269e-05     1.151753e-09
# H_Task_Attract_centered               5.696072e-08     5.463852e-08
# H_Homophily_centered                  1.566564e-07     2.718251e-05
# Age_centered                          5.277032e-01     3.116792e-01
#
#                                     SUS_Avg_centered  \
# Frequency_Score_centered                1.571372e-06
# Session_Length_Score_centered           1.699153e-04
# ULS_8_centered                          8.812689e-01
# GPIUS2_centered                         2.737234e-02
# SUS_Avg_centered                        0.000000e+00
# BFI_Extraversion_centered               7.475762e-02
# BFI_Neurotic_centered                   1.811078e-01
# BFI_Agreeableness_centered              1.965305e-02
# BFI_Conscientious_centered              3.361500e-07
# BFI_Openness_centered                   1.389210e-03
# LSNS_Score_centered                     7.887249e-01
# MSPSS_Score_centered                    6.046473e-03
# B_RSES_Score_centered                   4.899093e-02
# AI_Attitudes_Score_centered             0.000000e+00
# C_State_Empathy_centered                0.000000e+00
# C_SEmp_Affective_centered               5.836528e-07
# C_SEmp_Cognitive_centered               0.000000e+00
# C_SEmp_Associative_centered             0.000000e+00
# C_Social_Attract_centered               0.000000e+00
# C_Phys_Attract_centered                 1.806081e-03
# C_Task_Attract_centered                 0.000000e+00
# C_Homophily_centered                    1.524767e-11
# C_Attrib_Conf_centered                  6.779085e-14
# HCI_HHI_Expectation_centered            0.000000e+00
# HCI_HHI_Trust_centered                  0.000000e+00
# HCI_HHI_Substitution_centered           6.983861e-05
# HHI_Trust___Unfam_centered              2.877501e-01
# HHI_CommIntent___Unfam_centered         5.171381e-01
# HHI_Trust___Familiar_centered           1.006819e-04
# HHI_CommIntent___Familiar_centered      2.215759e-04
# H_State_Empathy_centered                4.445057e-09
# H_SEmp_Affective_centered               4.266487e-07
# H_SEmp_Cognitive_centered               2.267386e-08
# H_SEmp_Associative_centered             1.953536e-08
# H_Social_Attract_centered               7.340226e-11
# H_Task_Attract_centered                 1.466529e-13
# H_Homophily_centered                    4.537437e-11
# Age_centered                            5.910607e-01
#
#                                     BFI_Extraversion_centered  \
# Frequency_Score_centered                         4.929177e-01
# Session_Length_Score_centered                    9.801373e-01
# ULS_8_centered                                   3.381189e-04
# GPIUS2_centered                                  2.467854e-01
# SUS_Avg_centered                                 7.475762e-02
# BFI_Extraversion_centered                        0.000000e+00
# BFI_Neurotic_centered                            6.412297e-07
# BFI_Agreeableness_centered                       4.886957e-03
# BFI_Conscientious_centered                       7.560857e-01
# BFI_Openness_centered                            0.000000e+00
# LSNS_Score_centered                              1.398144e-04
# MSPSS_Score_centered                             1.768070e-05
# B_RSES_Score_centered                            2.948871e-05
# AI_Attitudes_Score_centered                      5.803481e-03
# C_State_Empathy_centered                         6.511910e-02
# C_SEmp_Affective_centered                        1.244379e-02
# C_SEmp_Cognitive_centered                        2.278008e-01
# C_SEmp_Associative_centered                      1.603853e-01
# C_Social_Attract_centered                        1.688895e-01
# C_Phys_Attract_centered                          2.234247e-01
# C_Task_Attract_centered                          6.810080e-01
# C_Homophily_centered                             5.341456e-02
# C_Attrib_Conf_centered                           6.151827e-01
# HCI_HHI_Expectation_centered                     4.488905e-01
# HCI_HHI_Trust_centered                           4.983373e-02
# HCI_HHI_Substitution_centered                    2.395196e-01
# HHI_Trust___Unfam_centered                       4.665840e-02
# HHI_CommIntent___Unfam_centered                  7.133129e-04
# HHI_Trust___Familiar_centered                    1.483667e-04
# HHI_CommIntent___Familiar_centered               1.028709e-05
# H_State_Empathy_centered                         3.821246e-01
# H_SEmp_Affective_centered                        1.077855e-01
# H_SEmp_Cognitive_centered                        2.544995e-01
# H_SEmp_Associative_centered                      8.990322e-01
# H_Social_Attract_centered                        6.002962e-01
# H_Task_Attract_centered                          4.846802e-01
# H_Homophily_centered                             7.728233e-01
# Age_centered                                     8.289085e-01
#
#                                     BFI_Neurotic_centered  \
# Frequency_Score_centered                     1.209529e-01
# Session_Length_Score_centered                2.660862e-01
# ULS_8_centered                               0.000000e+00
# GPIUS2_centered                              1.842625e-02
# SUS_Avg_centered                             1.811078e-01
# BFI_Extraversion_centered                    6.412297e-07
# BFI_Neurotic_centered                        0.000000e+00
# BFI_Agreeableness_centered                   2.131372e-14
# BFI_Conscientious_centered                   0.000000e+00
# BFI_Openness_centered                        4.422804e-02
# LSNS_Score_centered                          1.549306e-11
# MSPSS_Score_centered                         0.000000e+00
# B_RSES_Score_centered                        0.000000e+00
# AI_Attitudes_Score_centered                  2.367764e-03
# C_State_Empathy_centered                     7.224343e-02
# C_SEmp_Affective_centered                    1.372810e-02
# C_SEmp_Cognitive_centered                    3.153319e-01
# C_SEmp_Associative_centered                  1.082120e-01
# C_Social_Attract_centered                    4.129919e-01
# C_Phys_Attract_centered                      4.929177e-01
# C_Task_Attract_centered                      3.554612e-01
# C_Homophily_centered                         1.573145e-01
# C_Attrib_Conf_centered                       7.552713e-05
# HCI_HHI_Expectation_centered                 9.570683e-02
# HCI_HHI_Trust_centered                       7.190757e-02
# HCI_HHI_Substitution_centered                3.667284e-01
# HHI_Trust___Unfam_centered                   8.535440e-05
# HHI_CommIntent___Unfam_centered              0.000000e+00
# HHI_Trust___Familiar_centered                9.142573e-10
# HHI_CommIntent___Familiar_centered           0.000000e+00
# H_State_Empathy_centered                     5.322253e-07
# H_SEmp_Affective_centered                    7.664133e-07
# H_SEmp_Cognitive_centered                    4.033766e-05
# H_SEmp_Associative_centered                  3.827206e-06
# H_Social_Attract_centered                    1.379625e-01
# H_Task_Attract_centered                      1.564103e-02
# H_Homophily_centered                         7.202550e-03
# Age_centered                                 3.557003e-01
#
#                                     BFI_Agreeableness_centered  \
# Frequency_Score_centered                          2.509573e-01
# Session_Length_Score_centered                     5.440348e-01
# ULS_8_centered                                    2.329271e-11
# GPIUS2_centered                                   4.115423e-01
# SUS_Avg_centered                                  1.965305e-02
# BFI_Extraversion_centered                         4.886957e-03
# BFI_Neurotic_centered                             2.131372e-14
# BFI_Agreeableness_centered                        0.000000e+00
# BFI_Conscientious_centered                        7.160376e-08
# BFI_Openness_centered                             7.360949e-01
# LSNS_Score_centered                               2.674937e-07
# MSPSS_Score_centered                              0.000000e+00
# B_RSES_Score_centered                             1.819010e-11
# AI_Attitudes_Score_centered                       2.367764e-03
# C_State_Empathy_centered                          4.271311e-03
# C_SEmp_Affective_centered                         3.297915e-03
# C_SEmp_Cognitive_centered                         1.965538e-02
# C_SEmp_Associative_centered                       2.165231e-02
# C_Social_Attract_centered                         1.322842e-02
# C_Phys_Attract_centered                           3.376238e-01
# C_Task_Attract_centered                           1.758564e-01
# C_Homophily_centered                              1.712229e-02
# C_Attrib_Conf_centered                            3.722007e-05
# HCI_HHI_Expectation_centered                      4.648794e-03
# HCI_HHI_Trust_centered                            1.089757e-02
# HCI_HHI_Substitution_centered                     7.055191e-01
# HHI_Trust___Unfam_centered                        1.666208e-13
# HHI_CommIntent___Unfam_centered                   3.759056e-07
# HHI_Trust___Familiar_centered                     0.000000e+00
# HHI_CommIntent___Familiar_centered                0.000000e+00
# H_State_Empathy_centered                          7.576679e-07
# H_SEmp_Affective_centered                         1.274956e-08
# H_SEmp_Cognitive_centered                         7.552713e-05
# H_SEmp_Associative_centered                       1.455206e-04
# H_Social_Attract_centered                         3.027458e-02
# H_Task_Attract_centered                           4.451611e-04
# H_Homophily_centered                              7.867024e-04
# Age_centered                                      9.053917e-01
#
#                                     BFI_Conscientious_centered  \
# Frequency_Score_centered                          4.767670e-03
# Session_Length_Score_centered                     8.199888e-02
# ULS_8_centered                                    1.743626e-11
# GPIUS2_centered                                   1.728048e-01
# SUS_Avg_centered                                  3.361500e-07
# BFI_Extraversion_centered                         7.560857e-01
# BFI_Neurotic_centered                             0.000000e+00
# BFI_Agreeableness_centered                        7.160376e-08
# BFI_Conscientious_centered                        0.000000e+00
# BFI_Openness_centered                             1.119909e-01
# LSNS_Score_centered                               7.130751e-05
# MSPSS_Score_centered                              5.531800e-11
# B_RSES_Score_centered                             4.687608e-15
# AI_Attitudes_Score_centered                       1.737849e-02
# C_State_Empathy_centered                          1.193264e-01
# C_SEmp_Affective_centered                         7.062643e-02
# C_SEmp_Cognitive_centered                         1.149855e-01
# C_SEmp_Associative_centered                       1.530294e-01
# C_Social_Attract_centered                         8.579937e-02
# C_Phys_Attract_centered                           6.948821e-01
# C_Task_Attract_centered                           3.034991e-04
# C_Homophily_centered                              4.179789e-02
# C_Attrib_Conf_centered                            7.355075e-07
# HCI_HHI_Expectation_centered                      2.538228e-02
# HCI_HHI_Trust_centered                            1.553727e-03
# HCI_HHI_Substitution_centered                     9.709489e-01
# HHI_Trust___Unfam_centered                        2.309070e-01
# HHI_CommIntent___Unfam_centered                   1.534579e-02
# HHI_Trust___Familiar_centered                     1.441755e-08
# HHI_CommIntent___Familiar_centered                3.214503e-11
# H_State_Empathy_centered                          2.456809e-09
# H_SEmp_Affective_centered                         9.734978e-09
# H_SEmp_Cognitive_centered                         8.881519e-08
# H_SEmp_Associative_centered                       4.610825e-08
# H_Social_Attract_centered                         1.172919e-02
# H_Task_Attract_centered                           1.285343e-04
# H_Homophily_centered                              2.845814e-06
# Age_centered                                      2.555728e-02
#
#                                     BFI_Openness_centered  ...  \
# Frequency_Score_centered                         0.069499  ...
# Session_Length_Score_centered                    0.229728  ...
# ULS_8_centered                                   0.626306  ...
# GPIUS2_centered                                  0.113307  ...
# SUS_Avg_centered                                 0.001389  ...
# BFI_Extraversion_centered                        0.000000  ...
# BFI_Neurotic_centered                            0.044228  ...
# BFI_Agreeableness_centered                       0.736095  ...
# BFI_Conscientious_centered                       0.111991  ...
# BFI_Openness_centered                            0.000000  ...
# LSNS_Score_centered                              0.780192  ...
# MSPSS_Score_centered                             0.543625  ...
# B_RSES_Score_centered                            0.860886  ...
# AI_Attitudes_Score_centered                      0.054646  ...
# C_State_Empathy_centered                         0.731702  ...
# C_SEmp_Affective_centered                        0.254500  ...
# C_SEmp_Cognitive_centered                        0.937598  ...
# C_SEmp_Associative_centered                      0.788725  ...
# C_Social_Attract_centered                        0.268516  ...
# C_Phys_Attract_centered                          0.321133  ...
# C_Task_Attract_centered                          0.498379  ...
# C_Homophily_centered                             0.406442  ...
# C_Attrib_Conf_centered                           0.005056  ...
# HCI_HHI_Expectation_centered                     0.917379  ...
# HCI_HHI_Trust_centered                           0.582328  ...
# HCI_HHI_Substitution_centered                    0.001348  ...
# HHI_Trust___Unfam_centered                       0.616266  ...
# HHI_CommIntent___Unfam_centered                  0.027633  ...
# HHI_Trust___Familiar_centered                    0.750394  ...
# HHI_CommIntent___Familiar_centered               0.729494  ...
# H_State_Empathy_centered                         0.006357  ...
# H_SEmp_Affective_centered                        0.034559  ...
# H_SEmp_Cognitive_centered                        0.093756  ...
# H_SEmp_Associative_centered                      0.000225  ...
# H_Social_Attract_centered                        0.000327  ...
# H_Task_Attract_centered                          0.011720  ...
# H_Homophily_centered                             0.000370  ...
# Age_centered                                     0.186358  ...
#
#                                     HHI_Trust___Familiar_centered  \
# Frequency_Score_centered                             8.776216e-01
# Session_Length_Score_centered                        9.989936e-01
# ULS_8_centered                                       0.000000e+00
# GPIUS2_centered                                      9.560409e-06
# SUS_Avg_centered                                     1.006819e-04
# BFI_Extraversion_centered                            1.483667e-04
# BFI_Neurotic_centered                                9.142573e-10
# BFI_Agreeableness_centered                           0.000000e+00
# BFI_Conscientious_centered                           1.441755e-08
# BFI_Openness_centered                                7.503939e-01
# LSNS_Score_centered                                  0.000000e+00
# MSPSS_Score_centered                                 0.000000e+00
# B_RSES_Score_centered                                0.000000e+00
# AI_Attitudes_Score_centered                          3.821364e-01
# C_State_Empathy_centered                             8.990322e-01
# C_SEmp_Affective_centered                            3.116792e-01
# C_SEmp_Cognitive_centered                            4.065682e-01
# C_SEmp_Associative_centered                          3.305652e-01
# C_Social_Attract_centered                            8.889328e-01
# C_Phys_Attract_centered                              2.523390e-02
# C_Task_Attract_centered                              1.097280e-02
# C_Homophily_centered                                 8.853844e-01
# C_Attrib_Conf_centered                               0.000000e+00
# HCI_HHI_Expectation_centered                         4.864700e-02
# HCI_HHI_Trust_centered                               5.759755e-02
# HCI_HHI_Substitution_centered                        7.737959e-04
# HHI_Trust___Unfam_centered                           2.954125e-07
# HHI_CommIntent___Unfam_centered                      5.031099e-06
# HHI_Trust___Familiar_centered                        0.000000e+00
# HHI_CommIntent___Familiar_centered                   0.000000e+00
# H_State_Empathy_centered                             0.000000e+00
# H_SEmp_Affective_centered                            0.000000e+00
# H_SEmp_Cognitive_centered                            0.000000e+00
# H_SEmp_Associative_centered                          0.000000e+00
# H_Social_Attract_centered                            0.000000e+00
# H_Task_Attract_centered                              0.000000e+00
# H_Homophily_centered                                 0.000000e+00
# Age_centered                                         3.821246e-01
#
#                                     HHI_CommIntent___Familiar_centered  \
# Frequency_Score_centered                                  4.115423e-01
# Session_Length_Score_centered                             7.359326e-01
# ULS_8_centered                                            0.000000e+00
# GPIUS2_centered                                           2.532730e-04
# SUS_Avg_centered                                          2.215759e-04
# BFI_Extraversion_centered                                 1.028709e-05
# BFI_Neurotic_centered                                     0.000000e+00
# BFI_Agreeableness_centered                                0.000000e+00
# BFI_Conscientious_centered                                3.214503e-11
# BFI_Openness_centered                                     7.294944e-01
# LSNS_Score_centered                                       0.000000e+00
# MSPSS_Score_centered                                      0.000000e+00
# B_RSES_Score_centered                                     0.000000e+00
# AI_Attitudes_Score_centered                               5.391543e-02
# C_State_Empathy_centered                                  4.191855e-01
# C_SEmp_Affective_centered                                 8.990322e-01
# C_SEmp_Cognitive_centered                                 1.988948e-01
# C_SEmp_Associative_centered                               1.688895e-01
# C_Social_Attract_centered                                 7.155973e-01
# C_Phys_Attract_centered                                   1.919332e-01
# C_Task_Attract_centered                                   4.345294e-02
# C_Homophily_centered                                      2.966397e-01
# C_Attrib_Conf_centered                                    0.000000e+00
# HCI_HHI_Expectation_centered                              1.219182e-02
# HCI_HHI_Trust_centered                                    1.774758e-02
# HCI_HHI_Substitution_centered                             1.894852e-02
# HHI_Trust___Unfam_centered                                2.252746e-06
# HHI_CommIntent___Unfam_centered                           1.262701e-11
# HHI_Trust___Familiar_centered                             0.000000e+00
# HHI_CommIntent___Familiar_centered                        0.000000e+00
# H_State_Empathy_centered                                  0.000000e+00
# H_SEmp_Affective_centered                                 0.000000e+00
# H_SEmp_Cognitive_centered                                 0.000000e+00
# H_SEmp_Associative_centered                               0.000000e+00
# H_Social_Attract_centered                                 4.400854e-12
# H_Task_Attract_centered                                   0.000000e+00
# H_Homophily_centered                                      0.000000e+00
# Age_centered                                              1.364857e-01
#
#                                     H_State_Empathy_centered  \
# Frequency_Score_centered                        4.997465e-01
# Session_Length_Score_centered                   8.947009e-01
# ULS_8_centered                                  7.456568e-15
# GPIUS2_centered                                 3.886342e-06
# SUS_Avg_centered                                4.445057e-09
# BFI_Extraversion_centered                       3.821246e-01
# BFI_Neurotic_centered                           5.322253e-07
# BFI_Agreeableness_centered                      7.576679e-07
# BFI_Conscientious_centered                      2.456809e-09
# BFI_Openness_centered                           6.356858e-03
# LSNS_Score_centered                             7.834574e-10
# MSPSS_Score_centered                            0.000000e+00
# B_RSES_Score_centered                           2.608731e-09
# AI_Attitudes_Score_centered                     2.624302e-01
# C_State_Empathy_centered                        9.796104e-01
# C_SEmp_Affective_centered                       2.395196e-01
# C_SEmp_Cognitive_centered                       3.011388e-01
# C_SEmp_Associative_centered                     2.934311e-01
# C_Social_Attract_centered                       6.296977e-01
# C_Phys_Attract_centered                         1.523287e-02
# C_Task_Attract_centered                         1.860080e-04
# C_Homophily_centered                            5.108938e-01
# C_Attrib_Conf_centered                          0.000000e+00
# HCI_HHI_Expectation_centered                    2.151432e-01
# HCI_HHI_Trust_centered                          1.998146e-02
# HCI_HHI_Substitution_centered                   3.062655e-03
# HHI_Trust___Unfam_centered                      2.864725e-01
# HHI_CommIntent___Unfam_centered                 2.367764e-03
# HHI_Trust___Familiar_centered                   0.000000e+00
# HHI_CommIntent___Familiar_centered              0.000000e+00
# H_State_Empathy_centered                        0.000000e+00
# H_SEmp_Affective_centered                       0.000000e+00
# H_SEmp_Cognitive_centered                       0.000000e+00
# H_SEmp_Associative_centered                     0.000000e+00
# H_Social_Attract_centered                       0.000000e+00
# H_Task_Attract_centered                         0.000000e+00
# H_Homophily_centered                            0.000000e+00
# Age_centered                                    2.367751e-01
#
#                                     H_SEmp_Affective_centered  \
# Frequency_Score_centered                         6.502487e-01
# Session_Length_Score_centered                    8.990322e-01
# ULS_8_centered                                   3.961837e-14
# GPIUS2_centered                                  1.753936e-03
# SUS_Avg_centered                                 4.266487e-07
# BFI_Extraversion_centered                        1.077855e-01
# BFI_Neurotic_centered                            7.664133e-07
# BFI_Agreeableness_centered                       1.274956e-08
# BFI_Conscientious_centered                       9.734978e-09
# BFI_Openness_centered                            3.455882e-02
# LSNS_Score_centered                              1.765137e-08
# MSPSS_Score_centered                             0.000000e+00
# B_RSES_Score_centered                            1.504717e-09
# AI_Attitudes_Score_centered                      6.515149e-02
# C_State_Empathy_centered                         5.127325e-01
# C_SEmp_Affective_centered                        9.675287e-01
# C_SEmp_Cognitive_centered                        1.728048e-01
# C_SEmp_Associative_centered                      2.073656e-01
# C_Social_Attract_centered                        2.120032e-01
# C_Phys_Attract_centered                          1.298503e-01
# C_Task_Attract_centered                          7.215831e-05
# C_Homophily_centered                             9.868706e-01
# C_Attrib_Conf_centered                           0.000000e+00
# HCI_HHI_Expectation_centered                     7.058562e-02
# HCI_HHI_Trust_centered                           7.846706e-03
# HCI_HHI_Substitution_centered                    1.334852e-01
# HHI_Trust___Unfam_centered                       9.847507e-02
# HHI_CommIntent___Unfam_centered                  6.291775e-04
# HHI_Trust___Familiar_centered                    0.000000e+00
# HHI_CommIntent___Familiar_centered               0.000000e+00
# H_State_Empathy_centered                         0.000000e+00
# H_SEmp_Affective_centered                        0.000000e+00
# H_SEmp_Cognitive_centered                        0.000000e+00
# H_SEmp_Associative_centered                      0.000000e+00
# H_Social_Attract_centered                        0.000000e+00
# H_Task_Attract_centered                          0.000000e+00
# H_Homophily_centered                             0.000000e+00
# Age_centered                                     8.751958e-01
#
#                                     H_SEmp_Cognitive_centered  \
# Frequency_Score_centered                         4.795841e-01
# Session_Length_Score_centered                    8.632282e-01
# ULS_8_centered                                   1.187875e-11
# GPIUS2_centered                                  1.582212e-06
# SUS_Avg_centered                                 2.267386e-08
# BFI_Extraversion_centered                        2.544995e-01
# BFI_Neurotic_centered                            4.033766e-05
# BFI_Agreeableness_centered                       7.552713e-05
# BFI_Conscientious_centered                       8.881519e-08
# BFI_Openness_centered                            9.375626e-02
# LSNS_Score_centered                              9.175716e-09
# MSPSS_Score_centered                             0.000000e+00
# B_RSES_Score_centered                            1.701172e-07
# AI_Attitudes_Score_centered                      8.459155e-01
# C_State_Empathy_centered                         7.887249e-01
# C_SEmp_Affective_centered                        1.178491e-01
# C_SEmp_Cognitive_centered                        4.820818e-01
# C_SEmp_Associative_centered                      4.192455e-01
# C_Social_Attract_centered                        7.728233e-01
# C_Phys_Attract_centered                          3.455882e-02
# C_Task_Attract_centered                          4.937666e-03
# C_Homophily_centered                             4.354648e-01
# C_Attrib_Conf_centered                           0.000000e+00
# HCI_HHI_Expectation_centered                     5.014650e-01
# HCI_HHI_Trust_centered                           6.697308e-02
# HCI_HHI_Substitution_centered                    2.579232e-03
# HHI_Trust___Unfam_centered                       7.801919e-01
# HHI_CommIntent___Unfam_centered                  1.817511e-02
# HHI_Trust___Familiar_centered                    0.000000e+00
# HHI_CommIntent___Familiar_centered               0.000000e+00
# H_State_Empathy_centered                         0.000000e+00
# H_SEmp_Affective_centered                        0.000000e+00
# H_SEmp_Cognitive_centered                        0.000000e+00
# H_SEmp_Associative_centered                      0.000000e+00
# H_Social_Attract_centered                        0.000000e+00
# H_Task_Attract_centered                          0.000000e+00
# H_Homophily_centered                             0.000000e+00
# Age_centered                                     1.830382e-01
#
#                                     H_SEmp_Associative_centered  \
# Frequency_Score_centered                           4.950993e-01
# Session_Length_Score_centered                      9.067122e-01
# ULS_8_centered                                     1.110750e-11
# GPIUS2_centered                                    1.908482e-06
# SUS_Avg_centered                                   1.953536e-08
# BFI_Extraversion_centered                          8.990322e-01
# BFI_Neurotic_centered                              3.827206e-06
# BFI_Agreeableness_centered                         1.455206e-04
# BFI_Conscientious_centered                         4.610825e-08
# BFI_Openness_centered                              2.253543e-04
# LSNS_Score_centered                                4.384756e-08
# MSPSS_Score_centered                               0.000000e+00
# B_RSES_Score_centered                              2.172802e-07
# AI_Attitudes_Score_centered                        4.728765e-01
# C_State_Empathy_centered                           7.801919e-01
# C_SEmp_Affective_centered                          5.365206e-02
# C_SEmp_Cognitive_centered                          3.372457e-01
# C_SEmp_Associative_centered                        4.034173e-01
# C_Social_Attract_centered                          9.232712e-01
# C_Phys_Attract_centered                            4.937666e-03
# C_Task_Attract_centered                            2.822916e-04
# C_Homophily_centered                               2.827601e-01
# C_Attrib_Conf_centered                             0.000000e+00
# HCI_HHI_Expectation_centered                       3.215997e-01
# HCI_HHI_Trust_centered                             3.722035e-02
# HCI_HHI_Substitution_centered                      2.677970e-04
# HHI_Trust___Unfam_centered                         5.566342e-01
# HHI_CommIntent___Unfam_centered                    1.220949e-02
# HHI_Trust___Familiar_centered                      0.000000e+00
# HHI_CommIntent___Familiar_centered                 0.000000e+00
# H_State_Empathy_centered                           0.000000e+00
# H_SEmp_Affective_centered                          0.000000e+00
# H_SEmp_Cognitive_centered                          0.000000e+00
# H_SEmp_Associative_centered                        0.000000e+00
# H_Social_Attract_centered                          0.000000e+00
# H_Task_Attract_centered                            0.000000e+00
# H_Homophily_centered                               0.000000e+00
# Age_centered                                       1.371025e-01
#
#                                     H_Social_Attract_centered  \
# Frequency_Score_centered                         1.223659e-01
# Session_Length_Score_centered                    7.725927e-02
# ULS_8_centered                                   8.266269e-05
# GPIUS2_centered                                  1.151753e-09
# SUS_Avg_centered                                 7.340226e-11
# BFI_Extraversion_centered                        6.002962e-01
# BFI_Neurotic_centered                            1.379625e-01
# BFI_Agreeableness_centered                       3.027458e-02
# BFI_Conscientious_centered                       1.172919e-02
# BFI_Openness_centered                            3.271256e-04
# LSNS_Score_centered                              9.045979e-04
# MSPSS_Score_centered                             8.440231e-05
# B_RSES_Score_centered                            1.126673e-02
# AI_Attitudes_Score_centered                      1.364857e-01
# C_State_Empathy_centered                         6.503481e-02
# C_SEmp_Affective_centered                        7.552713e-05
# C_SEmp_Cognitive_centered                        8.853844e-01
# C_SEmp_Associative_centered                      4.240760e-01
# C_Social_Attract_centered                        8.297033e-01
# C_Phys_Attract_centered                          1.860080e-04
# C_Task_Attract_centered                          7.922054e-07
# C_Homophily_centered                             7.764763e-02
# C_Attrib_Conf_centered                           0.000000e+00
# HCI_HHI_Expectation_centered                     5.807944e-01
# HCI_HHI_Trust_centered                           4.941223e-01
# HCI_HHI_Substitution_centered                    2.318181e-07
# HHI_Trust___Unfam_centered                       5.039014e-01
# HHI_CommIntent___Unfam_centered                  4.547370e-01
# HHI_Trust___Familiar_centered                    0.000000e+00
# HHI_CommIntent___Familiar_centered               4.400854e-12
# H_State_Empathy_centered                         0.000000e+00
# H_SEmp_Affective_centered                        0.000000e+00
# H_SEmp_Cognitive_centered                        0.000000e+00
# H_SEmp_Associative_centered                      0.000000e+00
# H_Social_Attract_centered                        0.000000e+00
# H_Task_Attract_centered                          0.000000e+00
# H_Homophily_centered                             0.000000e+00
# Age_centered                                     5.614135e-01
#
#                                     H_Task_Attract_centered  \
# Frequency_Score_centered                       2.432670e-01
# Session_Length_Score_centered                  9.801373e-01
# ULS_8_centered                                 5.696072e-08
# GPIUS2_centered                                5.463852e-08
# SUS_Avg_centered                               1.466529e-13
# BFI_Extraversion_centered                      4.846802e-01
# BFI_Neurotic_centered                          1.564103e-02
# BFI_Agreeableness_centered                     4.451611e-04
# BFI_Conscientious_centered                     1.285343e-04
# BFI_Openness_centered                          1.172042e-02
# LSNS_Score_centered                            1.673536e-03
# MSPSS_Score_centered                           1.156334e-11
# B_RSES_Score_centered                          8.739718e-07
# AI_Attitudes_Score_centered                    8.632282e-01
# C_State_Empathy_centered                       7.485064e-01
# C_SEmp_Affective_centered                      1.721325e-02
# C_SEmp_Cognitive_centered                      1.734499e-01
# C_SEmp_Associative_centered                    6.502487e-01
# C_Social_Attract_centered                      7.187847e-01
# C_Phys_Attract_centered                        5.970028e-02
# C_Task_Attract_centered                        9.337136e-08
# C_Homophily_centered                           5.178808e-01
# C_Attrib_Conf_centered                         0.000000e+00
# HCI_HHI_Expectation_centered                   2.207724e-01
# HCI_HHI_Trust_centered                         3.590602e-02
# HCI_HHI_Substitution_centered                  7.130751e-05
# HHI_Trust___Unfam_centered                     8.878910e-01
# HHI_CommIntent___Unfam_centered                2.330180e-01
# HHI_Trust___Familiar_centered                  0.000000e+00
# HHI_CommIntent___Familiar_centered             0.000000e+00
# H_State_Empathy_centered                       0.000000e+00
# H_SEmp_Affective_centered                      0.000000e+00
# H_SEmp_Cognitive_centered                      0.000000e+00
# H_SEmp_Associative_centered                    0.000000e+00
# H_Social_Attract_centered                      0.000000e+00
# H_Task_Attract_centered                        0.000000e+00
# H_Homophily_centered                           0.000000e+00
# Age_centered                                   3.821246e-01
#
#                                     H_Homophily_centered  Age_centered
# Frequency_Score_centered                    4.846802e-01      0.722135
# Session_Length_Score_centered               9.801373e-01      0.911528
# ULS_8_centered                              1.566564e-07      0.527703
# GPIUS2_centered                             2.718251e-05      0.311679
# SUS_Avg_centered                            4.537437e-11      0.591061
# BFI_Extraversion_centered                   7.728233e-01      0.828909
# BFI_Neurotic_centered                       7.202550e-03      0.355700
# BFI_Agreeableness_centered                  7.867024e-04      0.905392
# BFI_Conscientious_centered                  2.845814e-06      0.025557
# BFI_Openness_centered                       3.703440e-04      0.186358
# LSNS_Score_centered                         4.918776e-08      0.355461
# MSPSS_Score_centered                        2.845850e-15      0.731015
# B_RSES_Score_centered                       1.751296e-07      0.766889
# AI_Attitudes_Score_centered                 6.659607e-01      0.729494
# C_State_Empathy_centered                    9.796104e-01      0.555102
# C_SEmp_Affective_centered                   1.758564e-01      0.774133
# C_SEmp_Cognitive_centered                   2.056355e-01      0.857815
# C_SEmp_Associative_centered                 4.846802e-01      0.172217
# C_Social_Attract_centered                   8.878910e-01      0.696422
# C_Phys_Attract_centered                     2.806197e-02      0.384030
# C_Task_Attract_centered                     5.847431e-06      0.907305
# C_Homophily_centered                        6.903399e-01      0.775374
# C_Attrib_Conf_centered                      0.000000e+00      0.024165
# HCI_HHI_Expectation_centered                1.831383e-01      0.756086
# HCI_HHI_Trust_centered                      5.390868e-03      0.597091
# HCI_HHI_Substitution_centered               1.169194e-03      0.526261
# HHI_Trust___Unfam_centered                  7.661577e-01      0.355700
# HHI_CommIntent___Unfam_centered             3.627064e-01      0.179575
# HHI_Trust___Familiar_centered               0.000000e+00      0.382125
# HHI_CommIntent___Familiar_centered          0.000000e+00      0.136486
# H_State_Empathy_centered                    0.000000e+00      0.236775
# H_SEmp_Affective_centered                   0.000000e+00      0.875196
# H_SEmp_Cognitive_centered                   0.000000e+00      0.183038
# H_SEmp_Associative_centered                 0.000000e+00      0.137102
# H_Social_Attract_centered                   0.000000e+00      0.561414
# H_Task_Attract_centered                     0.000000e+00      0.382125
# H_Homophily_centered                        0.000000e+00      0.591061
# Age_centered                                5.910607e-01      0.000000
#
# [38 rows x 38 columns]

# %% [markdown]
# # Visualizing the Corrected Correlation

# %%
significant_corr = significant_correlation_matrix(correlation_matrix_significant, p_values_corrected, key_variables, rename_dict=rename_dict, title='Companion Chatbot Users: Benjamini-Hochberg Corrected')

# %%
viz_sig = correlation_matrix_significant.copy().rename(index=rename_dict, columns=rename_dict)
p_corr_viz = p_values_corrected.copy().rename(index=rename_dict, columns=rename_dict)

# Print significant correlations
find_significant_correlations(viz_sig, p_corr_viz, key_variables_viz, var_viz)
# Out:
# Significant correlations with Chatbot Usage Frequency:
# Chatbot Session Length: correlation = 0.3497, p-value = 0.0000
# Problematic Use of Chatbot (GPIUS-2): correlation = 0.3374, p-value = 0.0000
# System Usability (SUS): correlation = 0.2457, p-value = 0.0000
# Conscientiousness (BFI-10): correlation = 0.1511, p-value = 0.0048
# Attitudes towards AI: correlation = 0.2976, p-value = 0.0000
# State Empathy towards Chatbot: correlation = 0.3207, p-value = 0.0000
# Affective State Empathy towards Chatbot: correlation = 0.2472, p-value = 0.0000
# Cognitive State Empathy towards Chatbot: correlation = 0.2805, p-value = 0.0000
# Associative State Empathy towards Chatbot: correlation = 0.3416, p-value = 0.0000
# Social Attraction towards Chatbot: correlation = 0.2238, p-value = 0.0000
# Physical Attraction towards Chatbot: correlation = 0.1856, p-value = 0.0004
# Task Attraction towards Chatbot: correlation = 0.1652, p-value = 0.0018
# Perceived Similarity with Chatbot: correlation = 0.2525, p-value = 0.0000
# Expectations towards Chatbot (HCI/HHI): correlation = 0.2560, p-value = 0.0000
# Trust towards Chatbot (HCI/HHI): correlation = 0.2931, p-value = 0.0000
# Preference for Chatbot over Humans (HCI/HHI): correlation = 0.2084, p-value = 0.0001
#
# Significant correlations with Chatbot Session Length:
# Chatbot Usage Frequency: correlation = 0.3497, p-value = 0.0000
# Problematic Use of Chatbot (GPIUS-2): correlation = 0.2549, p-value = 0.0000
# System Usability (SUS): correlation = 0.1962, p-value = 0.0002
# Attitudes towards AI: correlation = 0.2331, p-value = 0.0000
# State Empathy towards Chatbot: correlation = 0.3016, p-value = 0.0000
# Affective State Empathy towards Chatbot: correlation = 0.2475, p-value = 0.0000
# Cognitive State Empathy towards Chatbot: correlation = 0.2539, p-value = 0.0000
# Associative State Empathy towards Chatbot: correlation = 0.3073, p-value = 0.0000
# Social Attraction towards Chatbot: correlation = 0.2553, p-value = 0.0000
# Physical Attraction towards Chatbot: correlation = 0.2438, p-value = 0.0000
# Task Attraction towards Chatbot: correlation = 0.1787, p-value = 0.0007
# Perceived Similarity with Chatbot: correlation = 0.2213, p-value = 0.0000
# Expectations towards Chatbot (HCI/HHI): correlation = 0.2069, p-value = 0.0001
# Trust towards Chatbot (HCI/HHI): correlation = 0.1938, p-value = 0.0002
# Preference for Chatbot over Humans (HCI/HHI): correlation = 0.1684, p-value = 0.0015
#
# Significant correlations with Loneliness (ULS-8):
# Problematic Use of Chatbot (GPIUS-2): correlation = 0.3649, p-value = 0.0000
# Extraversion (BFI-10): correlation = -0.1876, p-value = 0.0003
# Neuroticism (BFI-10): correlation = 0.5264, p-value = 0.0000
# Agreeableness (BFI-10): correlation = 0.3332, p-value = 0.0000
# Conscientiousness (BFI-10): correlation = -0.3351, p-value = 0.0000
# Socialization (LSNS): correlation = -0.5055, p-value = 0.0000
# Perceived Social Support (MSPSS): correlation = -0.6790, p-value = 0.0000
# Self-Esteem (B-RSES): correlation = -0.6380, p-value = 0.0000
# State Empathy towards Chatbot: correlation = 0.1251, p-value = 0.0217
# Cognitive State Empathy towards Chatbot: correlation = 0.1195, p-value = 0.0291
# Associative State Empathy towards Chatbot: correlation = 0.1119, p-value = 0.0429
# Social Attraction towards Chatbot: correlation = 0.1658, p-value = 0.0018
# Physical Attraction towards Chatbot: correlation = 0.1210, p-value = 0.0270
# Perceived Similarity with Chatbot: correlation = 0.1364, p-value = 0.0117
# Perceived Chatbot Predictability: correlation = -0.2981, p-value = 0.0000
# Preference for Chatbot over Humans (HCI/HHI): correlation = 0.2138, p-value = 0.0000
# Trust in Unfamiliar People (HHI): correlation = -0.2045, p-value = 0.0001
# Willingness to Engage with Unfamiliar People (HHI): correlation = -0.2536, p-value = 0.0000
# Trust in Familiar People (HHI): correlation = -0.5132, p-value = 0.0000
# Willingness to Engage with Familiar People (HHI): correlation = -0.5495, p-value = 0.0000
# State Empathy towards Close Person: correlation = -0.3821, p-value = 0.0000
# Affective State Empathy towards Close Person: correlation = -0.3725, p-value = 0.0000
# Cognitive State Empathy towards Close Person: correlation = -0.3377, p-value = 0.0000
# Associative State Empathy towards Close Person: correlation = -0.3382, p-value = 0.0000
# Social Attraction towards towards Close Person: correlation = -0.2047, p-value = 0.0001
# Task Attraction towards towards Close Person: correlation = -0.2755, p-value = 0.0000
# Perceived Similarity with Close Person: correlation = -0.2670, p-value = 0.0000

# %% [markdown]
# # Mediation Analysis

# %%
# identify potential mediators

def identify_potential_mediators(correlation_matrix, p_values_matrix, x, y, threshold=0.05):
    potential_mediators = []
    for column in correlation_matrix.columns:
        if column not in [x, y]:
            p_value_x = p_values_matrix.loc[x, column]
            p_value_y = p_values_matrix.loc[y, column]
            if p_value_x < threshold and p_value_y < threshold:
                potential_mediators.append(column)
    return potential_mediators

x = 'Session_Length_Score_centered'
y = 'ULS_8_centered'
mediators = identify_potential_mediators(correlation_matrix, p_values_corrected, x, y)

print(f"Potential mediators: {mediators}")
print(len(mediators))
# Out:
# Potential mediators: ['GPIUS2_centered', 'C_State_Empathy_centered', 'C_SEmp_Cognitive_centered', 'C_SEmp_Associative_centered', 'C_Social_Attract_centered', 'C_Phys_Attract_centered', 'C_Homophily_centered', 'HCI_HHI_Substitution_centered']
# 8

# %%
# identify potential mediators

def identify_potential_mediators(correlation_matrix, p_values_matrix, x, y, threshold=0.05):
    potential_mediators = []
    for column in correlation_matrix.columns:
        if column not in [x, y]:
            p_value_x = p_values_matrix.loc[x, column]
            p_value_y = p_values_matrix.loc[y, column]
            if p_value_x < threshold and p_value_y < threshold:
                potential_mediators.append(column)
    return potential_mediators

x = 'Frequency_Score_centered'
y = 'ULS_8_centered'
mediators_f = identify_potential_mediators(correlation_matrix, p_values_corrected, x, y)

print(f"Potential mediators: {mediators}")
print(len(mediators))
# Out:
# Potential mediators: ['GPIUS2_centered', 'C_State_Empathy_centered', 'C_SEmp_Cognitive_centered', 'C_SEmp_Associative_centered', 'C_Social_Attract_centered', 'C_Phys_Attract_centered', 'C_Homophily_centered', 'HCI_HHI_Substitution_centered']
# 8

# %%
def sanitize_variable_name(name):
    # Replace spaces with underscores
    name = name.replace(' ', '_')
    # If the name starts with a number, add 'x' prefix
    if name[0].isdigit():
        name = 'x' + name
    # If the name contains numbers (not at the start), wrap in Q()
    if any(char.isdigit() for char in name[1:]):
        name = f"Q('{name}')"
    return name

def create_formula(y, x_vars):
    y = sanitize_variable_name(y)
    x_vars = [sanitize_variable_name(x) for x in x_vars]
    return f"{y} ~ {' + '.join(x_vars)}"

def mediation_analysis(df, x, y, m):
    # Step 1: Regress Y on X
    formula_yx = create_formula(y, [x])
    model_yx = smf.ols(formula_yx, data=df).fit()
    c = model_yx.params[sanitize_variable_name(x)]
    
    # Step 2: Regress M on X
    formula_mx = create_formula(m, [x])
    model_mx = smf.ols(formula_mx, data=df).fit()
    a = model_mx.params[sanitize_variable_name(x)]
    
    # Step 3: Regress Y on both X and M
    formula_yxm = create_formula(y, [x, m])
    model_yxm = smf.ols(formula_yxm, data=df).fit()
    c_prime = model_yxm.params[sanitize_variable_name(x)]
    b = model_yxm.params[sanitize_variable_name(m)]
    
    # Calculate the indirect effect
    indirect_effect = a * b
    
    # Sobel test
    def sobel_test(a, b, sea, seb):
        z_value = a*b / np.sqrt(b**2 * sea**2 + a**2 * seb**2)
        p_value = 2 * (1 - stats.norm.cdf(abs(z_value)))
        return z_value, p_value
    
    z, p = sobel_test(a, b, model_mx.bse[sanitize_variable_name(x)], model_yxm.bse[sanitize_variable_name(m)])
    
    return {
        'mediator': m,
        'total_effect': c,
        'direct_effect': c_prime,
        'indirect_effect': indirect_effect,
        'a_path': a,
        'b_path': b,
        'sobel_z': z,
        'sobel_p': p
    }

# Conduct mediation analysis for each potential mediator
results = []
for mediator in mediators:
    result = mediation_analysis(df, x, y, mediator)
    results.append(result)
    print(f"\nMediation analysis for {mediator}:")
    for key, value in result.items():
        print(f"{key}: {value}")

# Create a summary dataframe
summary_df = pd.DataFrame(results)
summary_df = summary_df.sort_values('sobel_p')  # Sort by p-value of Sobel test

print("\nSummary of mediation analyses:")
summary_df
# Out:
# Mediation analysis for GPIUS2_centered:
# mediator: GPIUS2_centered
# total_effect: 0.0918826167741797
# direct_effect: 0.00727963804617919
# indirect_effect: 0.08460297872800046
# a_path: 0.24412705250658018
# b_path: 0.34655306677132836
# sobel_z: 4.129149637293982
# sobel_p: 3.641073860571886e-05
#
# Mediation analysis for C_State_Empathy_centered:
# mediator: C_State_Empathy_centered
# total_effect: 0.0918826167741797
# direct_effect: 0.0609997619099777
# indirect_effect: 0.030882854864202
# a_path: 0.2933342224535628
# b_path: 0.10528214064450325
# sobel_z: 1.9316227345701464
# sobel_p: 0.05340608768640975
#
# Mediation analysis for C_SEmp_Cognitive_centered:
# mediator: C_SEmp_Cognitive_centered
# total_effect: 0.0918826167741797
# direct_effect: 0.06476470105315636
# indirect_effect: 0.027117915721023362
# a_path: 0.2304171302411776
# b_path: 0.11769053669160379
# sobel_z: 2.0833179288225816
# sobel_p: 0.037222253566912
#
# Mediation analysis for C_SEmp_Associative_centered:
# mediator: C_SEmp_Associative_centered
# total_effect: 0.0918826167741797
# direct_effect: 0.061410417020094164
# indirect_effect: 0.030472199754085477
# a_path: 0.290475705981657
# b_path: 0.10490446920889741
# sobel_z: 1.9248678642825379
# sobel_p: 0.05424589115238754
#
# Mediation analysis for C_Social_Attract_centered:
# mediator: C_Social_Attract_centered
# total_effect: 0.0918826167741797
# direct_effect: 0.05390144929965016
# indirect_effect: 0.037981167474529516
# a_path: 0.24261937295727598
# b_path: 0.15654630960248092
# sobel_z: 2.630776427992985
# sobel_p: 0.008519005779377142
#
# Mediation analysis for C_Phys_Attract_centered:
# mediator: C_Phys_Attract_centered
# total_effect: 0.0918826167741797
# direct_effect: 0.04841223578282492
# indirect_effect: 0.043470380991354925
# a_path: 0.2946687893150607
# b_path: 0.14752285470205082
# sobel_z: 2.5985762402210244
# sobel_p: 0.00936112548150847
#
# Mediation analysis for C_Homophily_centered:
# mediator: C_Homophily_centered
# total_effect: 0.0918826167741797
# direct_effect: 0.0662341967936373
# indirect_effect: 0.02564841998054236
# a_path: 0.21062152508858709
# b_path: 0.12177492290854258
# sobel_z: 2.105468449811082
# sobel_p: 0.035250550879770914
#
# Mediation analysis for HCI_HHI_Substitution_centered:
# mediator: HCI_HHI_Substitution_centered
# total_effect: 0.0918826167741797
# direct_effect: 0.05920288183798824
# indirect_effect: 0.03267973493619142
# a_path: 0.15238317319793993
# b_path: 0.21445763498927595
# sobel_z: 2.522263470010854
# sobel_p: 0.011660233762347927
#
# Summary of mediation analyses:
#                         mediator  total_effect  direct_effect  \
# 0                GPIUS2_centered      0.091883       0.007280
# 4      C_Social_Attract_centered      0.091883       0.053901
# 5        C_Phys_Attract_centered      0.091883       0.048412
# 7  HCI_HHI_Substitution_centered      0.091883       0.059203
# 6           C_Homophily_centered      0.091883       0.066234
# 2      C_SEmp_Cognitive_centered      0.091883       0.064765
# 1       C_State_Empathy_centered      0.091883       0.061000
# 3    C_SEmp_Associative_centered      0.091883       0.061410
#
#    indirect_effect    a_path    b_path   sobel_z   sobel_p
# 0         0.084603  0.244127  0.346553  4.129150  0.000036
# 4         0.037981  0.242619  0.156546  2.630776  0.008519
# 5         0.043470  0.294669  0.147523  2.598576  0.009361
# 7         0.032680  0.152383  0.214458  2.522263  0.011660
# 6         0.025648  0.210622  0.121775  2.105468  0.035251
# 2         0.027118  0.230417  0.117691  2.083318  0.037222
# 1         0.030883  0.293334  0.105282  1.931623  0.053406
# 3         0.030472  0.290476  0.104904  1.924868  0.054246

# %%
# Choose mediators with p-value < 0.05
filtered_mediators = summary_df[summary_df['sobel_p'] < 0.05]['mediator'].tolist()

print(filtered_mediators)
# Out:
# ['GPIUS2_centered', 'C_Social_Attract_centered', 'C_Phys_Attract_centered', 'HCI_HHI_Substitution_centered', 'C_Homophily_centered', 'C_SEmp_Cognitive_centered']

# %%
# Save the summary dataframe to a CSV file
fname = '/work/Output Data/' + name + '_mediation_analysis_summary_users.csv'
summary_df.to_csv(fname, index=False)
print("\nSummary saved to " + fname)
# Out:
# Summary saved to /work/Output Data/CloudResearch-1_24.08.12_mediation_analysis_summary_users.csv

# %% [markdown]
# # Moderation Analysis

# %%
def identify_potential_moderators(correlation_matrix, p_values_matrix, target_var, threshold=0.3, p_value_threshold=0.05):
    potential_moderators = []
    for column in correlation_matrix.columns:
        if column != target_var:
            corr = abs(correlation_matrix.loc[target_var, column])
            p_value = p_values_matrix.loc[target_var, column]
            if corr >= threshold and p_value <= p_value_threshold:
                potential_moderators.append((column, corr, p_value))
    
    # Sort by correlation strength (descending)
    potential_moderators.sort(key=lambda x: x[1], reverse=True)
    
    return potential_moderators

# Usage
target_var = 'ULS_8_centered' 
moderators = identify_potential_moderators(correlation_matrix, p_values_corrected, target_var)

print("Potential moderators (variable, correlation, p-value):")
for mod in moderators:
    print(f"{mod[0]}: correlation = {mod[1]:.4f}, p-value = {mod[2]:.4f}")
# Out:
# Potential moderators (variable, correlation, p-value):
# MSPSS_Score_centered: correlation = 0.6790, p-value = 0.0000
# B_RSES_Score_centered: correlation = 0.6380, p-value = 0.0000
# HHI_CommIntent___Familiar_centered: correlation = 0.5495, p-value = 0.0000
# BFI_Neurotic_centered: correlation = 0.5264, p-value = 0.0000
# HHI_Trust___Familiar_centered: correlation = 0.5132, p-value = 0.0000
# LSNS_Score_centered: correlation = 0.5055, p-value = 0.0000
# H_State_Empathy_centered: correlation = 0.3821, p-value = 0.0000
# H_SEmp_Affective_centered: correlation = 0.3725, p-value = 0.0000
# GPIUS2_centered: correlation = 0.3649, p-value = 0.0000
# H_SEmp_Associative_centered: correlation = 0.3382, p-value = 0.0000
# H_SEmp_Cognitive_centered: correlation = 0.3377, p-value = 0.0000
# BFI_Conscientious_centered: correlation = 0.3351, p-value = 0.0000
# BFI_Agreeableness_centered: correlation = 0.3332, p-value = 0.0000

# %%
def moderation_analysis(df, x, y, moderator):
    # Create interaction term
    df['Interaction'] = df[x] * df[moderator]
    
    # Create formula
    formula = f"{y} ~ {x} + {moderator} + Interaction"
    
    # Fit the model
    model = smf.ols(formula, data=df).fit()
    
    # Extract key statistics
    coef = model.params['Interaction']
    p_value = model.pvalues['Interaction']
    r_squared = model.rsquared
    
    return {
        'moderator': moderator,
        'interaction_coef': coef,
        'interaction_p_value': p_value,
        'r_squared': r_squared
    }

def run_moderation_analyses(df, x, y, moderators):
    results = []
    for moderator in moderators:
        result = moderation_analysis(df, x, y, moderator[0])
        results.append(result)
    
    return pd.DataFrame(results)

x = 'Session_Length_Score_centered'
y = 'ULS_8_centered'

moderation_results = run_moderation_analyses(df, x, y, moderators)
print("Moderation Analysis Results:")
moderation_results
# Out:
# Moderation Analysis Results:
#                              moderator  interaction_coef  interaction_p_value  \
# 0                 MSPSS_Score_centered          0.011129             0.713491
# 1                B_RSES_Score_centered          0.021356             0.501731
# 2   HHI_CommIntent___Familiar_centered          0.054524             0.097132
# 3                BFI_Neurotic_centered         -0.033828             0.452506
# 4        HHI_Trust___Familiar_centered          0.051542             0.124990
# 5                  LSNS_Score_centered          0.012754             0.753437
# 6             H_State_Empathy_centered          0.030583             0.497235
# 7            H_SEmp_Affective_centered          0.033224             0.452196
# 8                      GPIUS2_centered          0.073424             0.119727
# 9          H_SEmp_Associative_centered          0.026410             0.558972
# 10           H_SEmp_Cognitive_centered          0.071834             0.110247
# 11          BFI_Conscientious_centered         -0.067870             0.177599
# 12          BFI_Agreeableness_centered          0.059995             0.189262
#
#     r_squared
# 0    0.490539
# 1    0.433489
# 2    0.325756
# 3    0.305429
# 4    0.289122
# 5    0.265483
# 6    0.179006
# 7    0.168875
# 8    0.126692
# 9    0.149340
# 10   0.154117
# 11   0.148894
# 12   0.139308

# %%
# moderators with p-value < 0.05
filtered_moderators = moderation_results[moderation_results['interaction_p_value'] < 0.05]['moderator'].tolist()

if len(filtered_moderators) == 0:
    print("No moderators pass the p-value threshold. Including most significant moderator.")
    # Include most significant moderator
    filtered_moderators = [moderation_results['moderator'].tolist()[-1]]

print(filtered_moderators)
# Out:
# No moderators pass the p-value threshold. Including most significant moderator.
# ['BFI_Agreeableness_centered']

# %%
# Save the moderation results to a CSV file
fname = '/work/Output Data/' + name + '_moderation_analysis_summary_users.csv'
moderation_results.to_csv(fname, index=False)
print("\nSummary saved to " + fname)
# Out:
# Summary saved to /work/Output Data/CloudResearch-1_24.08.12_moderation_analysis_summary_users.csv

# %% [markdown]
# # Identify Confounders

# %%
# Identify potential confounders
def identify_potential_confounders(correlation_matrix, p_values_matrix, x, y, corr_threshold=0.0, p_value_threshold=0.05):
    potential_confounders = []
    for column in correlation_matrix.columns:
        if column not in [x, y]:
            corr_x = abs(correlation_matrix.loc[x, column])
            corr_y = abs(correlation_matrix.loc[y, column])
            p_value_x = p_values_matrix.loc[x, column]
            p_value_y = p_values_matrix.loc[y, column]
            if (corr_x >= corr_threshold and p_value_x <= p_value_threshold) and \
               (corr_y >= corr_threshold and p_value_y <= p_value_threshold):
                potential_confounders.append((column, corr_x, p_value_x, corr_y, p_value_y))
    
    # Sort by sum of correlations (descending)
    potential_confounders.sort(key=lambda x: x[1] + x[3], reverse=True)
    
    return potential_confounders

confounders = identify_potential_confounders(correlation_matrix, p_values_corrected, x, y)
print("\nPotential confounders (variable, correlation with X, correlation with Y):")
for conf in confounders:
    print(f"{conf[0]}: corr with {x} = {conf[1]:.4f}, corr with {y} = {conf[3]:.4f}")
# Out:
# Potential confounders (variable, correlation with X, correlation with Y):
# GPIUS2_centered: corr with Session_Length_Score_centered = 0.2549, corr with ULS_8_centered = 0.3649
# C_State_Empathy_centered: corr with Session_Length_Score_centered = 0.3016, corr with ULS_8_centered = 0.1251
# C_Social_Attract_centered: corr with Session_Length_Score_centered = 0.2553, corr with ULS_8_centered = 0.1658
# C_SEmp_Associative_centered: corr with Session_Length_Score_centered = 0.3073, corr with ULS_8_centered = 0.1119
# HCI_HHI_Substitution_centered: corr with Session_Length_Score_centered = 0.1684, corr with ULS_8_centered = 0.2138
# C_SEmp_Cognitive_centered: corr with Session_Length_Score_centered = 0.2539, corr with ULS_8_centered = 0.1195
# C_Phys_Attract_centered: corr with Session_Length_Score_centered = 0.2438, corr with ULS_8_centered = 0.1210
# C_Homophily_centered: corr with Session_Length_Score_centered = 0.2213, corr with ULS_8_centered = 0.1364

# %%
confounders_f = identify_potential_confounders(correlation_matrix, p_values_corrected, 'Frequency_Score_centered', y)
print("\nPotential confounders (variable, correlation with X, correlation with Y):")
for conf in confounders_f:
    print(f"{conf[0]}: corr with {x} = {conf[1]:.4f}, corr with {y} = {conf[3]:.4f}")
# Out:
# Potential confounders (variable, correlation with X, correlation with Y):
# GPIUS2_centered: corr with Frequency_Score_centered = 0.3374, corr with ULS_8_centered = 0.3649
# BFI_Conscientious_centered: corr with Frequency_Score_centered = 0.1511, corr with ULS_8_centered = 0.3351
# C_SEmp_Associative_centered: corr with Frequency_Score_centered = 0.3416, corr with ULS_8_centered = 0.1119
# C_State_Empathy_centered: corr with Frequency_Score_centered = 0.3207, corr with ULS_8_centered = 0.1251
# HCI_HHI_Substitution_centered: corr with Frequency_Score_centered = 0.2084, corr with ULS_8_centered = 0.2138
# C_SEmp_Cognitive_centered: corr with Frequency_Score_centered = 0.2805, corr with ULS_8_centered = 0.1195
# C_Social_Attract_centered: corr with Frequency_Score_centered = 0.2238, corr with ULS_8_centered = 0.1658
# C_Homophily_centered: corr with Frequency_Score_centered = 0.2525, corr with ULS_8_centered = 0.1364
# C_Phys_Attract_centered: corr with Frequency_Score_centered = 0.1856, corr with ULS_8_centered = 0.1210

# %%
confounders_list = [conf[0] for conf in confounders]

print(confounders_list)
# Out:
# ['GPIUS2_centered', 'C_State_Empathy_centered', 'C_Social_Attract_centered', 'C_SEmp_Associative_centered', 'HCI_HHI_Substitution_centered', 'C_SEmp_Cognitive_centered', 'C_Phys_Attract_centered', 'C_Homophily_centered']

# %%
list(set(filtered_mediators) | set(filtered_moderators) | set(confounders_list))
# Out:
# ['HCI_HHI_Substitution_centered',
#  'C_Phys_Attract_centered',
#  'C_SEmp_Associative_centered',
#  'GPIUS2_centered',
#  'C_Homophily_centered',
#  'C_SEmp_Cognitive_centered',
#  'BFI_Agreeableness_centered',
#  'C_State_Empathy_centered',
#  'C_Social_Attract_centered']

# %%
predictor_vars = list(set(filtered_mediators) | set(filtered_moderators) | set(confounders_list) | set(['LSNS_Score_centered', 'BFI_Neurotic_centered','H_Social_Attract_centered', 'Frequency_Score_centered']))

# Added Neuroticism, LSNS, H Social Attract on theoretical basis
predictor_vars = predictor_vars 
print(predictor_vars)
# Out:
# ['HCI_HHI_Substitution_centered', 'C_Phys_Attract_centered', 'BFI_Neurotic_centered', 'LSNS_Score_centered', 'C_SEmp_Associative_centered', 'GPIUS2_centered', 'C_Homophily_centered', 'C_SEmp_Cognitive_centered', 'BFI_Agreeableness_centered', 'H_Social_Attract_centered', 'Frequency_Score_centered', 'C_State_Empathy_centered', 'C_Social_Attract_centered']

# %% [markdown]
# # VIF Elimination

# %%
def calculate_vif(X):
    vif_data = pd.DataFrame()
    vif_data["Variable"] = X.columns
    vif_data["VIF"] = [variance_inflation_factor(X.dropna().values, i) for i in range(X.shape[1])]
    return vif_data.sort_values('VIF', ascending=False)

vif_variables = ['ULS_8_centered', 'Session_Length_Score_centered'] + predictor_vars
X = df[vif_variables]

vif_results = calculate_vif(X)
print(vif_results)
# Out:
#                          Variable        VIF
# 13       C_State_Empathy_centered  19.797422
# 6     C_SEmp_Associative_centered   7.838153
# 9       C_SEmp_Cognitive_centered   6.680028
# 8            C_Homophily_centered   2.566072
# 7                 GPIUS2_centered   2.358618
# 14      C_Social_Attract_centered   2.151822
# 2   HCI_HHI_Substitution_centered   2.137884
# 0                  ULS_8_centered   2.015625
# 4           BFI_Neurotic_centered   1.602490
# 3         C_Phys_Attract_centered   1.515265
# 5             LSNS_Score_centered   1.427351
# 10     BFI_Agreeableness_centered   1.274478
# 12       Frequency_Score_centered   1.255535
# 1   Session_Length_Score_centered   1.249159
# 11      H_Social_Attract_centered   1.243455

# %%
# Remove state empathy subscales 
vif_variables = ['ULS_8_centered', 'Session_Length_Score_centered'] + predictor_vars
vif_variables.remove("C_SEmp_Associative_centered")
vif_variables.remove("C_SEmp_Cognitive_centered")
X = df[vif_variables]
vif_results = calculate_vif(X)
print(vif_results)
# Out:
#                          Variable       VIF
# 11       C_State_Empathy_centered  3.297755
# 7            C_Homophily_centered  2.534827
# 6                 GPIUS2_centered  2.331695
# 12      C_Social_Attract_centered  2.133006
# 2   HCI_HHI_Substitution_centered  2.118712
# 0                  ULS_8_centered  1.999560
# 4           BFI_Neurotic_centered  1.567768
# 3         C_Phys_Attract_centered  1.503098
# 5             LSNS_Score_centered  1.417987
# 8      BFI_Agreeableness_centered  1.270530
# 1   Session_Length_Score_centered  1.245037
# 10       Frequency_Score_centered  1.233999
# 9       H_Social_Attract_centered  1.200868

# %% [markdown]
# # Model Exploration

# %%
# Model variables - all variables in regression.
modelvars = vif_variables
adjusted_predictors = copy.deepcopy(modelvars)
adjusted_predictors.remove('Session_Length_Score_centered')
adjusted_predictors.remove('ULS_8_centered')
adjusted_predictors
# Out:
# ['HCI_HHI_Substitution_centered',
#  'C_Phys_Attract_centered',
#  'BFI_Neurotic_centered',
#  'LSNS_Score_centered',
#  'GPIUS2_centered',
#  'C_Homophily_centered',
#  'BFI_Agreeableness_centered',
#  'H_Social_Attract_centered',
#  'Frequency_Score_centered',
#  'C_State_Empathy_centered',
#  'C_Social_Attract_centered']

# %%
# Create interaction terms 
for term in adjusted_predictors:
    print(term)
    df[f'SLS_x_{term}'] = df['Session_Length_Score_centered'] * df[term]
# Out:
# HCI_HHI_Substitution_centered
# C_Phys_Attract_centered
# BFI_Neurotic_centered
# LSNS_Score_centered
# GPIUS2_centered
# C_Homophily_centered
# BFI_Agreeableness_centered
# H_Social_Attract_centered
# Frequency_Score_centered
# C_State_Empathy_centered
# C_Social_Attract_centered

# %%
# Add sex and age as controls 
modelvars = modelvars + ['Sex'] + ['Age_centered']
adjusted_predictors = adjusted_predictors + ['Sex'] + ['Age_centered']
adjusted_predictors
# Out:
# ['HCI_HHI_Substitution_centered',
#  'C_Phys_Attract_centered',
#  'BFI_Neurotic_centered',
#  'LSNS_Score_centered',
#  'GPIUS2_centered',
#  'C_Homophily_centered',
#  'BFI_Agreeableness_centered',
#  'H_Social_Attract_centered',
#  'Frequency_Score_centered',
#  'C_State_Empathy_centered',
#  'C_Social_Attract_centered',
#  'Sex',
#  'Age_centered']

# %%
# Function for exploring models
def explore_ols(df, modelvars, subset_predictors, interaction_terms, x='Session_Length_Score_centered', y='ULS_8_centered', cat=[]): 
    # Filter rows where Age and other variables are not NaN
    df_filtered = df.dropna(subset=modelvars)

    interaction_names = [f'SLS_x_{term}' for term in interaction_terms]

    formula = f"{y} ~ {x}" 
    for var in subset_predictors + interaction_names + cat:
        formula += f" + {var}" 

    print(formula)

    # Fit the model with centered interaction term
    model = smf.ols(formula=formula, data=df_filtered).fit()

    print(model.summary())

# %%
model_specs = [] # list of tuples (model_name, subset_predictors, interaction_terms)

# %%
subset_predictors = copy.deepcopy(adjusted_predictors) 
subset_predictors.remove('BFI_Neurotic_centered')
subset_predictors.remove('H_Social_Attract_centered')
interaction_terms = ['BFI_Agreeableness_centered']

model_specs.append(('Base Model', subset_predictors, interaction_terms))

explore_ols(df, modelvars, subset_predictors, interaction_terms)
# Out:
# ULS_8_centered ~ Session_Length_Score_centered + HCI_HHI_Substitution_centered + C_Phys_Attract_centered + LSNS_Score_centered + GPIUS2_centered + C_Homophily_centered + BFI_Agreeableness_centered + Frequency_Score_centered + C_State_Empathy_centered + C_Social_Attract_centered + Sex + Age_centered + SLS_x_BFI_Agreeableness_centered
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         ULS_8_centered   R-squared:                       0.400
# Model:                            OLS   Adj. R-squared:                  0.378
# Method:                 Least Squares   F-statistic:                     18.51
# Date:                Wed, 11 Sep 2024   Prob (F-statistic):           2.73e-35
# Time:                        09:45:23   Log-Likelihood:                -470.14
# No. Observations:                 404   AIC:                             970.3
# Df Residuals:                     389   BIC:                             1030.
# Df Model:                          14
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                            0.0354      0.063      0.559      0.577      -0.089       0.160
# Sex[T.Male]                         -0.0625      0.083     -0.756      0.450      -0.225       0.100
# Sex[T.Prefer not to say]             0.4331      0.574      0.754      0.451      -0.696       1.562
# Session_Length_Score_centered        0.0326      0.044      0.749      0.454      -0.053       0.118
# HCI_HHI_Substitution_centered       -0.0266      0.057     -0.468      0.640      -0.138       0.085
# C_Phys_Attract_centered             -0.0383      0.049     -0.790      0.430      -0.134       0.057
# LSNS_Score_centered                 -0.3988      0.043     -9.369      0.000      -0.482      -0.315
# GPIUS2_centered                      0.2952      0.058      5.086      0.000       0.181       0.409
# C_Homophily_centered                 0.0091      0.063      0.145      0.885      -0.114       0.132
# BFI_Agreeableness_centered           0.2424      0.042      5.781      0.000       0.160       0.325
# Frequency_Score_centered            -0.0361      0.044     -0.825      0.410      -0.122       0.050
# C_State_Empathy_centered            -0.0471      0.071     -0.660      0.510      -0.187       0.093
# C_Social_Attract_centered            0.0887      0.057      1.568      0.118      -0.023       0.200
# Age_centered                        -0.0309      0.040     -0.766      0.444      -0.110       0.048
# SLS_x_BFI_Agreeableness_centered     0.0160      0.039      0.412      0.681      -0.060       0.092
# ==============================================================================
# Omnibus:                        5.143   Durbin-Watson:                   2.160
# Prob(Omnibus):                  0.076   Jarque-Bera (JB):                4.757
# Skew:                          -0.209   Prob(JB):                       0.0927
# Kurtosis:                       2.671   Cond. No.                         29.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
subset_predictors = copy.deepcopy(adjusted_predictors) 
subset_predictors.remove('H_Social_Attract_centered')
interaction_terms = ['BFI_Agreeableness_centered']

model_specs.append(('+ Neuroticism', subset_predictors, interaction_terms))

explore_ols(df, modelvars, subset_predictors, interaction_terms)
# Out:
# ULS_8_centered ~ Session_Length_Score_centered + HCI_HHI_Substitution_centered + C_Phys_Attract_centered + BFI_Neurotic_centered + LSNS_Score_centered + GPIUS2_centered + C_Homophily_centered + BFI_Agreeableness_centered + Frequency_Score_centered + C_State_Empathy_centered + C_Social_Attract_centered + Sex + Age_centered + SLS_x_BFI_Agreeableness_centered
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         ULS_8_centered   R-squared:                       0.500
# Model:                            OLS   Adj. R-squared:                  0.480
# Method:                 Least Squares   F-statistic:                     25.82
# Date:                Wed, 11 Sep 2024   Prob (F-statistic):           2.41e-49
# Time:                        09:45:49   Log-Likelihood:                -433.41
# No. Observations:                 404   AIC:                             898.8
# Df Residuals:                     388   BIC:                             962.8
# Df Model:                          15
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           -0.0364      0.058     -0.623      0.533      -0.151       0.078
# Sex[T.Male]                          0.0550      0.077      0.716      0.474      -0.096       0.206
# Sex[T.Prefer not to say]             0.6918      0.526      1.316      0.189      -0.342       1.725
# Session_Length_Score_centered        0.0495      0.040      1.240      0.216      -0.029       0.128
# HCI_HHI_Substitution_centered       -0.0465      0.052     -0.894      0.372      -0.149       0.056
# C_Phys_Attract_centered             -0.0655      0.044     -1.472      0.142      -0.153       0.022
# BFI_Neurotic_centered                0.3692      0.042      8.796      0.000       0.287       0.452
# LSNS_Score_centered                 -0.3122      0.040     -7.776      0.000      -0.391      -0.233
# GPIUS2_centered                      0.2550      0.053      4.787      0.000       0.150       0.360
# C_Homophily_centered                 0.0273      0.057      0.476      0.634      -0.085       0.140
# BFI_Agreeableness_centered           0.1425      0.040      3.564      0.000       0.064       0.221
# Frequency_Score_centered            -0.0218      0.040     -0.546      0.586      -0.101       0.057
# C_State_Empathy_centered             0.0023      0.065      0.035      0.972      -0.126       0.131
# C_Social_Attract_centered            0.0899      0.052      1.737      0.083      -0.012       0.192
# Age_centered                        -0.0023      0.037     -0.063      0.949      -0.075       0.070
# SLS_x_BFI_Agreeableness_centered    -0.0147      0.036     -0.412      0.680      -0.085       0.056
# ==============================================================================
# Omnibus:                        2.549   Durbin-Watson:                   2.222
# Prob(Omnibus):                  0.280   Jarque-Bera (JB):                2.127
# Skew:                          -0.051   Prob(JB):                        0.345
# Kurtosis:                       2.660   Cond. No.                         29.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
subset_predictors = copy.deepcopy(adjusted_predictors) 
subset_predictors.remove('H_Social_Attract_centered')
subset_predictors.remove('C_State_Empathy_centered')
subset_predictors.remove('C_Homophily_centered')
interaction_terms = ['BFI_Agreeableness_centered']

model_specs.append(('- C State Empathy, C Homophily', subset_predictors, interaction_terms))

explore_ols(df, modelvars, subset_predictors, interaction_terms)
# Out:
# ULS_8_centered ~ Session_Length_Score_centered + HCI_HHI_Substitution_centered + C_Phys_Attract_centered + BFI_Neurotic_centered + LSNS_Score_centered + GPIUS2_centered + BFI_Agreeableness_centered + Frequency_Score_centered + C_Social_Attract_centered + Sex + Age_centered + SLS_x_BFI_Agreeableness_centered
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         ULS_8_centered   R-squared:                       0.499
# Model:                            OLS   Adj. R-squared:                  0.482
# Method:                 Least Squares   F-statistic:                     29.90
# Date:                Wed, 11 Sep 2024   Prob (F-statistic):           9.31e-51
# Time:                        09:46:10   Log-Likelihood:                -433.57
# No. Observations:                 404   AIC:                             895.1
# Df Residuals:                     390   BIC:                             951.2
# Df Model:                          13
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           -0.0338      0.058     -0.582      0.561      -0.148       0.080
# Sex[T.Male]                          0.0506      0.076      0.664      0.507      -0.099       0.200
# Sex[T.Prefer not to say]             0.6996      0.524      1.335      0.183      -0.331       1.730
# Session_Length_Score_centered        0.0500      0.040      1.261      0.208      -0.028       0.128
# HCI_HHI_Substitution_centered       -0.0408      0.050     -0.811      0.418      -0.140       0.058
# C_Phys_Attract_centered             -0.0637      0.044     -1.463      0.144      -0.149       0.022
# BFI_Neurotic_centered                0.3671      0.042      8.829      0.000       0.285       0.449
# LSNS_Score_centered                 -0.3107      0.040     -7.789      0.000      -0.389      -0.232
# GPIUS2_centered                      0.2602      0.052      5.004      0.000       0.158       0.362
# BFI_Agreeableness_centered           0.1416      0.040      3.555      0.000       0.063       0.220
# Frequency_Score_centered            -0.0210      0.040     -0.529      0.597      -0.099       0.057
# C_Social_Attract_centered            0.1020      0.045      2.267      0.024       0.014       0.190
# Age_centered                        -0.0015      0.037     -0.040      0.968      -0.074       0.071
# SLS_x_BFI_Agreeableness_centered    -0.0141      0.036     -0.396      0.693      -0.084       0.056
# ==============================================================================
# Omnibus:                        2.580   Durbin-Watson:                   2.214
# Prob(Omnibus):                  0.275   Jarque-Bera (JB):                2.168
# Skew:                          -0.060   Prob(JB):                        0.338
# Kurtosis:                       2.661   Cond. No.                         24.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
subset_predictors = copy.deepcopy(adjusted_predictors) 
subset_predictors.remove('H_Social_Attract_centered')
subset_predictors.remove('C_Phys_Attract_centered')
subset_predictors.remove('HCI_HHI_Substitution_centered')
subset_predictors.remove('C_State_Empathy_centered')
subset_predictors.remove('C_Homophily_centered')
interaction_terms = ['BFI_Agreeableness_centered']

model_specs.append(('- C Phys Attract, HCI/HHI Substitution', subset_predictors, interaction_terms))

explore_ols(df, modelvars, subset_predictors, interaction_terms)
# Out:
# ULS_8_centered ~ Session_Length_Score_centered + BFI_Neurotic_centered + LSNS_Score_centered + GPIUS2_centered + BFI_Agreeableness_centered + Frequency_Score_centered + C_Social_Attract_centered + Sex + Age_centered + SLS_x_BFI_Agreeableness_centered
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         ULS_8_centered   R-squared:                       0.495
# Model:                            OLS   Adj. R-squared:                  0.481
# Method:                 Least Squares   F-statistic:                     34.95
# Date:                Wed, 11 Sep 2024   Prob (F-statistic):           1.19e-51
# Time:                        09:46:34   Log-Likelihood:                -435.18
# No. Observations:                 404   AIC:                             894.4
# Df Residuals:                     392   BIC:                             942.4
# Df Model:                          11
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           -0.0213      0.058     -0.369      0.712      -0.135       0.092
# Sex[T.Male]                          0.0297      0.075      0.394      0.694      -0.118       0.178
# Sex[T.Prefer not to say]             0.6992      0.524      1.334      0.183      -0.332       1.730
# Session_Length_Score_centered        0.0409      0.039      1.049      0.295      -0.036       0.118
# BFI_Neurotic_centered                0.3633      0.042      8.738      0.000       0.282       0.445
# LSNS_Score_centered                 -0.3034      0.040     -7.639      0.000      -0.381      -0.225
# GPIUS2_centered                      0.2180      0.044      5.008      0.000       0.132       0.304
# BFI_Agreeableness_centered           0.1439      0.040      3.612      0.000       0.066       0.222
# Frequency_Score_centered            -0.0183      0.040     -0.461      0.645      -0.096       0.060
# C_Social_Attract_centered            0.0763      0.042      1.820      0.070      -0.006       0.159
# Age_centered                        -0.0041      0.037     -0.112      0.911      -0.076       0.068
# SLS_x_BFI_Agreeableness_centered    -0.0116      0.036     -0.325      0.745      -0.082       0.058
# ==============================================================================
# Omnibus:                        3.296   Durbin-Watson:                   2.193
# Prob(Omnibus):                  0.192   Jarque-Bera (JB):                2.683
# Skew:                          -0.083   Prob(JB):                        0.261
# Kurtosis:                       2.637   Cond. No.                         20.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
subset_predictors = copy.deepcopy(adjusted_predictors) 
subset_predictors.remove('H_Social_Attract_centered')
subset_predictors.remove('C_Phys_Attract_centered')
subset_predictors.remove('HCI_HHI_Substitution_centered')
subset_predictors.remove('C_State_Empathy_centered')
subset_predictors.remove('C_Homophily_centered')
interaction_terms = []

model_specs.append(('- SLSxAgreeableness', subset_predictors, interaction_terms))

explore_ols(df, modelvars, subset_predictors, interaction_terms)
# Out:
# ULS_8_centered ~ Session_Length_Score_centered + BFI_Neurotic_centered + LSNS_Score_centered + GPIUS2_centered + BFI_Agreeableness_centered + Frequency_Score_centered + C_Social_Attract_centered + Sex + Age_centered
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         ULS_8_centered   R-squared:                       0.495
# Model:                            OLS   Adj. R-squared:                  0.482
# Method:                 Least Squares   F-statistic:                     38.53
# Date:                Wed, 11 Sep 2024   Prob (F-statistic):           1.97e-52
# Time:                        09:46:48   Log-Likelihood:                -435.23
# No. Observations:                 404   AIC:                             892.5
# Df Residuals:                     393   BIC:                             936.5
# Df Model:                          10
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                        -0.0205      0.058     -0.356      0.722      -0.134       0.093
# Sex[T.Male]                       0.0286      0.075      0.381      0.704      -0.119       0.176
# Sex[T.Prefer not to say]          0.6977      0.524      1.332      0.184      -0.332       1.727
# Session_Length_Score_centered     0.0407      0.039      1.045      0.297      -0.036       0.117
# BFI_Neurotic_centered             0.3620      0.041      8.756      0.000       0.281       0.443
# LSNS_Score_centered              -0.3033      0.040     -7.645      0.000      -0.381      -0.225
# GPIUS2_centered                   0.2172      0.043      5.004      0.000       0.132       0.303
# BFI_Agreeableness_centered        0.1443      0.040      3.625      0.000       0.066       0.222
# Frequency_Score_centered         -0.0184      0.040     -0.464      0.643      -0.096       0.060
# C_Social_Attract_centered         0.0762      0.042      1.819      0.070      -0.006       0.159
# Age_centered                     -0.0038      0.037     -0.105      0.917      -0.076       0.068
# ==============================================================================
# Omnibus:                        2.863   Durbin-Watson:                   2.197
# Prob(Omnibus):                  0.239   Jarque-Bera (JB):                2.421
# Skew:                          -0.082   Prob(JB):                        0.298
# Kurtosis:                       2.658   Cond. No.                         20.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
subset_predictors = copy.deepcopy(adjusted_predictors) 
subset_predictors.remove('C_Phys_Attract_centered')
subset_predictors.remove('HCI_HHI_Substitution_centered')
subset_predictors.remove('C_State_Empathy_centered')
subset_predictors.remove('C_Homophily_centered')
interaction_terms = []

model_specs.append(('+ H Social Attract', subset_predictors, interaction_terms))

explore_ols(df, modelvars, subset_predictors, interaction_terms)
# Out:
# ULS_8_centered ~ Session_Length_Score_centered + BFI_Neurotic_centered + LSNS_Score_centered + GPIUS2_centered + BFI_Agreeableness_centered + H_Social_Attract_centered + Frequency_Score_centered + C_Social_Attract_centered + Sex + Age_centered
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         ULS_8_centered   R-squared:                       0.497
# Model:                            OLS   Adj. R-squared:                  0.483
# Method:                 Least Squares   F-statistic:                     35.27
# Date:                Wed, 11 Sep 2024   Prob (F-statistic):           5.10e-52
# Time:                        09:47:05   Log-Likelihood:                -434.28
# No. Observations:                 404   AIC:                             892.6
# Df Residuals:                     392   BIC:                             940.6
# Df Model:                          11
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                        -0.0164      0.058     -0.284      0.777      -0.130       0.097
# Sex[T.Male]                       0.0219      0.075      0.292      0.771      -0.126       0.170
# Sex[T.Prefer not to say]          0.6625      0.524      1.265      0.207      -0.367       1.692
# Session_Length_Score_centered     0.0354      0.039      0.906      0.365      -0.041       0.112
# BFI_Neurotic_centered             0.3619      0.041      8.764      0.000       0.281       0.443
# LSNS_Score_centered              -0.2974      0.040     -7.463      0.000      -0.376      -0.219
# GPIUS2_centered                   0.1977      0.046      4.330      0.000       0.108       0.288
# BFI_Agreeableness_centered        0.1421      0.040      3.572      0.000       0.064       0.220
# H_Social_Attract_centered        -0.0529      0.039     -1.360      0.175      -0.129       0.024
# Frequency_Score_centered         -0.0168      0.040     -0.425      0.671      -0.095       0.061
# C_Social_Attract_centered         0.0858      0.042      2.022      0.044       0.002       0.169
# Age_centered                     -0.0066      0.037     -0.180      0.857      -0.079       0.065
# ==============================================================================
# Omnibus:                        2.614   Durbin-Watson:                   2.192
# Prob(Omnibus):                  0.271   Jarque-Bera (JB):                2.237
# Skew:                          -0.074   Prob(JB):                        0.327
# Kurtosis:                       2.667   Cond. No.                         20.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Explore interaction terms

# %%
subset_predictors = copy.deepcopy(adjusted_predictors) 
subset_predictors.remove('C_Phys_Attract_centered')
subset_predictors.remove('HCI_HHI_Substitution_centered')
subset_predictors.remove('C_State_Empathy_centered')
subset_predictors.remove('C_Homophily_centered')
interaction_terms = ['C_Social_Attract_centered']

model_specs.append(('Explore: SLSxC Social Attract', subset_predictors, interaction_terms))

explore_ols(df, modelvars, subset_predictors, interaction_terms)
# Out:
# ULS_8_centered ~ Session_Length_Score_centered + BFI_Neurotic_centered + LSNS_Score_centered + GPIUS2_centered + BFI_Agreeableness_centered + H_Social_Attract_centered + Frequency_Score_centered + C_Social_Attract_centered + Sex + Age_centered + SLS_x_C_Social_Attract_centered
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         ULS_8_centered   R-squared:                       0.500
# Model:                            OLS   Adj. R-squared:                  0.484
# Method:                 Least Squares   F-statistic:                     32.54
# Date:                Wed, 11 Sep 2024   Prob (F-statistic):           1.33e-51
# Time:                        09:47:24   Log-Likelihood:                -433.38
# No. Observations:                 404   AIC:                             892.8
# Df Residuals:                     391   BIC:                             944.8
# Df Model:                          12
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          -0.0297      0.058     -0.509      0.611      -0.145       0.085
# Sex[T.Male]                         0.0243      0.075      0.323      0.747      -0.123       0.172
# Sex[T.Prefer not to say]            0.6684      0.523      1.277      0.202      -0.360       1.697
# Session_Length_Score_centered       0.0275      0.040      0.695      0.487      -0.050       0.105
# BFI_Neurotic_centered               0.3591      0.041      8.691      0.000       0.278       0.440
# LSNS_Score_centered                -0.2952      0.040     -7.406      0.000      -0.374      -0.217
# GPIUS2_centered                     0.1994      0.046      4.369      0.000       0.110       0.289
# BFI_Agreeableness_centered          0.1411      0.040      3.549      0.000       0.063       0.219
# H_Social_Attract_centered          -0.0563      0.039     -1.447      0.149      -0.133       0.020
# Frequency_Score_centered           -0.0161      0.040     -0.406      0.685      -0.094       0.062
# C_Social_Attract_centered           0.0876      0.042      2.065      0.040       0.004       0.171
# Age_centered                       -0.0042      0.037     -0.114      0.909      -0.076       0.068
# SLS_x_C_Social_Attract_centered     0.0492      0.037      1.323      0.187      -0.024       0.122
# ==============================================================================
# Omnibus:                        2.450   Durbin-Watson:                   2.191
# Prob(Omnibus):                  0.294   Jarque-Bera (JB):                2.169
# Skew:                          -0.084   Prob(JB):                        0.338
# Kurtosis:                       2.683   Cond. No.                         20.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
subset_predictors = copy.deepcopy(adjusted_predictors) 
subset_predictors.remove('C_Phys_Attract_centered')
subset_predictors.remove('HCI_HHI_Substitution_centered')
subset_predictors.remove('C_State_Empathy_centered')
subset_predictors.remove('C_Homophily_centered')
interaction_terms = ['H_Social_Attract_centered']

model_specs.append(('Explore: SLSxH Social Attract', subset_predictors, interaction_terms))

explore_ols(df, modelvars, subset_predictors, interaction_terms)
# Out:
# ULS_8_centered ~ Session_Length_Score_centered + BFI_Neurotic_centered + LSNS_Score_centered + GPIUS2_centered + BFI_Agreeableness_centered + H_Social_Attract_centered + Frequency_Score_centered + C_Social_Attract_centered + Sex + Age_centered + SLS_x_H_Social_Attract_centered
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         ULS_8_centered   R-squared:                       0.504
# Model:                            OLS   Adj. R-squared:                  0.489
# Method:                 Least Squares   F-statistic:                     33.08
# Date:                Wed, 11 Sep 2024   Prob (F-statistic):           2.76e-52
# Time:                        09:47:32   Log-Likelihood:                -431.71
# No. Observations:                 404   AIC:                             889.4
# Df Residuals:                     391   BIC:                             941.4
# Df Model:                          12
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          -0.0124      0.057     -0.216      0.829      -0.125       0.100
# Sex[T.Male]                         0.0293      0.075      0.391      0.696      -0.118       0.177
# Sex[T.Prefer not to say]            0.6638      0.521      1.274      0.204      -0.361       1.688
# Session_Length_Score_centered       0.0606      0.040      1.496      0.135      -0.019       0.140
# BFI_Neurotic_centered               0.3606      0.041      8.774      0.000       0.280       0.441
# LSNS_Score_centered                -0.2964      0.040     -7.475      0.000      -0.374      -0.218
# GPIUS2_centered                     0.1978      0.045      4.353      0.000       0.108       0.287
# BFI_Agreeableness_centered          0.1414      0.040      3.571      0.000       0.064       0.219
# H_Social_Attract_centered          -0.0625      0.039     -1.607      0.109      -0.139       0.014
# Frequency_Score_centered           -0.0174      0.039     -0.442      0.659      -0.095       0.060
# C_Social_Attract_centered           0.0767      0.042      1.807      0.072      -0.007       0.160
# Age_centered                       -0.0099      0.036     -0.271      0.787      -0.082       0.062
# SLS_x_H_Social_Attract_centered     0.0602      0.027      2.236      0.026       0.007       0.113
# ==============================================================================
# Omnibus:                        2.499   Durbin-Watson:                   2.181
# Prob(Omnibus):                  0.287   Jarque-Bera (JB):                2.361
# Skew:                          -0.121   Prob(JB):                        0.307
# Kurtosis:                       2.714   Cond. No.                         22.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
subset_predictors = copy.deepcopy(adjusted_predictors) 
subset_predictors.remove('C_Phys_Attract_centered')
subset_predictors.remove('HCI_HHI_Substitution_centered')
subset_predictors.remove('C_State_Empathy_centered')
subset_predictors.remove('C_Homophily_centered')
interaction_terms = ['BFI_Neurotic_centered']

model_specs.append(('Explore: SLSxNeuroticism', subset_predictors, interaction_terms))

explore_ols(df, modelvars, subset_predictors, interaction_terms)
# Out:
# ULS_8_centered ~ Session_Length_Score_centered + BFI_Neurotic_centered + LSNS_Score_centered + GPIUS2_centered + BFI_Agreeableness_centered + H_Social_Attract_centered + Frequency_Score_centered + C_Social_Attract_centered + Sex + Age_centered + SLS_x_BFI_Neurotic_centered
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         ULS_8_centered   R-squared:                       0.503
# Model:                            OLS   Adj. R-squared:                  0.487
# Method:                 Least Squares   F-statistic:                     32.94
# Date:                Wed, 11 Sep 2024   Prob (F-statistic):           4.11e-52
# Time:                        09:47:39   Log-Likelihood:                -432.14
# No. Observations:                 404   AIC:                             890.3
# Df Residuals:                     391   BIC:                             942.3
# Df Model:                          12
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                        -0.0231      0.058     -0.402      0.688      -0.136       0.090
# Sex[T.Male]                       0.0269      0.075      0.359      0.720      -0.121       0.174
# Sex[T.Prefer not to say]          0.5703      0.524      1.089      0.277      -0.459       1.600
# Session_Length_Score_centered     0.0325      0.039      0.833      0.405      -0.044       0.109
# BFI_Neurotic_centered             0.3660      0.041      8.889      0.000       0.285       0.447
# LSNS_Score_centered              -0.2996      0.040     -7.545      0.000      -0.378      -0.222
# GPIUS2_centered                   0.2067      0.046      4.523      0.000       0.117       0.296
# BFI_Agreeableness_centered        0.1490      0.040      3.747      0.000       0.071       0.227
# H_Social_Attract_centered        -0.0464      0.039     -1.195      0.233      -0.123       0.030
# Frequency_Score_centered         -0.0180      0.040     -0.454      0.650      -0.096       0.060
# C_Social_Attract_centered         0.0895      0.042      2.116      0.035       0.006       0.173
# Age_centered                     -0.0054      0.036     -0.147      0.883      -0.077       0.066
# SLS_x_BFI_Neurotic_centered      -0.0801      0.039     -2.043      0.042      -0.157      -0.003
# ==============================================================================
# Omnibus:                        2.921   Durbin-Watson:                   2.186
# Prob(Omnibus):                  0.232   Jarque-Bera (JB):                2.443
# Skew:                          -0.079   Prob(JB):                        0.295
# Kurtosis:                       2.653   Cond. No.                         20.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
subset_predictors = copy.deepcopy(adjusted_predictors) 
subset_predictors.remove('C_Phys_Attract_centered')
subset_predictors.remove('HCI_HHI_Substitution_centered')
subset_predictors.remove('C_State_Empathy_centered')
subset_predictors.remove('C_Homophily_centered')
interaction_terms = ['BFI_Agreeableness_centered']

model_specs.append(('Explore: SLSxAgreeableness', subset_predictors, interaction_terms))

explore_ols(df, modelvars, subset_predictors, interaction_terms)
# Out:
# ULS_8_centered ~ Session_Length_Score_centered + BFI_Neurotic_centered + LSNS_Score_centered + GPIUS2_centered + BFI_Agreeableness_centered + H_Social_Attract_centered + Frequency_Score_centered + C_Social_Attract_centered + Sex + Age_centered + SLS_x_BFI_Agreeableness_centered
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         ULS_8_centered   R-squared:                       0.498
# Model:                            OLS   Adj. R-squared:                  0.482
# Method:                 Least Squares   F-statistic:                     32.26
# Date:                Wed, 11 Sep 2024   Prob (F-statistic):           2.99e-51
# Time:                        09:47:45   Log-Likelihood:                -434.24
# No. Observations:                 404   AIC:                             894.5
# Df Residuals:                     391   BIC:                             946.5
# Df Model:                          12
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           -0.0171      0.058     -0.296      0.767      -0.131       0.097
# Sex[T.Male]                          0.0229      0.075      0.304      0.762      -0.125       0.171
# Sex[T.Prefer not to say]             0.6641      0.524      1.266      0.206      -0.367       1.695
# Session_Length_Score_centered        0.0356      0.039      0.910      0.363      -0.041       0.113
# BFI_Neurotic_centered                0.3630      0.042      8.740      0.000       0.281       0.445
# LSNS_Score_centered                 -0.2976      0.040     -7.458      0.000      -0.376      -0.219
# GPIUS2_centered                      0.1986      0.046      4.334      0.000       0.109       0.289
# BFI_Agreeableness_centered           0.1419      0.040      3.561      0.000       0.064       0.220
# H_Social_Attract_centered           -0.0525      0.039     -1.348      0.179      -0.129       0.024
# Frequency_Score_centered            -0.0168      0.040     -0.422      0.673      -0.095       0.061
# C_Social_Attract_centered            0.0859      0.042      2.021      0.044       0.002       0.169
# Age_centered                        -0.0068      0.037     -0.185      0.853      -0.079       0.065
# SLS_x_BFI_Agreeableness_centered    -0.0099      0.036     -0.277      0.782      -0.080       0.060
# ==============================================================================
# Omnibus:                        2.962   Durbin-Watson:                   2.189
# Prob(Omnibus):                  0.227   Jarque-Bera (JB):                2.454
# Skew:                          -0.075   Prob(JB):                        0.293
# Kurtosis:                       2.649   Cond. No.                         20.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
subset_predictors = copy.deepcopy(adjusted_predictors) 
subset_predictors.remove('C_Phys_Attract_centered')
subset_predictors.remove('HCI_HHI_Substitution_centered')
subset_predictors.remove('C_State_Empathy_centered')
subset_predictors.remove('C_Homophily_centered')
interaction_terms = ['LSNS_Score_centered']

model_specs.append(('Explore: SLSxLSNS', subset_predictors, interaction_terms))

explore_ols(df, modelvars, subset_predictors, interaction_terms)
# Out:
# ULS_8_centered ~ Session_Length_Score_centered + BFI_Neurotic_centered + LSNS_Score_centered + GPIUS2_centered + BFI_Agreeableness_centered + H_Social_Attract_centered + Frequency_Score_centered + C_Social_Attract_centered + Sex + Age_centered + SLS_x_LSNS_Score_centered
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         ULS_8_centered   R-squared:                       0.500
# Model:                            OLS   Adj. R-squared:                  0.485
# Method:                 Least Squares   F-statistic:                     32.62
# Date:                Wed, 11 Sep 2024   Prob (F-statistic):           1.04e-51
# Time:                        09:47:52   Log-Likelihood:                -433.12
# No. Observations:                 404   AIC:                             892.2
# Df Residuals:                     391   BIC:                             944.3
# Df Model:                          12
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                        -0.0173      0.058     -0.300      0.764      -0.130       0.096
# Sex[T.Male]                       0.0254      0.075      0.338      0.736      -0.122       0.173
# Sex[T.Prefer not to say]          0.6367      0.523      1.217      0.224      -0.392       1.665
# Session_Length_Score_centered     0.0290      0.039      0.740      0.460      -0.048       0.106
# BFI_Neurotic_centered             0.3638      0.041      8.819      0.000       0.283       0.445
# LSNS_Score_centered              -0.2983      0.040     -7.496      0.000      -0.377      -0.220
# GPIUS2_centered                   0.2010      0.046      4.404      0.000       0.111       0.291
# BFI_Agreeableness_centered        0.1442      0.040      3.627      0.000       0.066       0.222
# H_Social_Attract_centered        -0.0517      0.039     -1.333      0.183      -0.128       0.025
# Frequency_Score_centered         -0.0152      0.040     -0.382      0.702      -0.093       0.063
# C_Social_Attract_centered         0.0885      0.042      2.087      0.038       0.005       0.172
# Age_centered                     -0.0087      0.037     -0.238      0.812      -0.081       0.063
# SLS_x_LSNS_Score_centered         0.0513      0.034      1.502      0.134      -0.016       0.118
# ==============================================================================
# Omnibus:                        2.691   Durbin-Watson:                   2.178
# Prob(Omnibus):                  0.260   Jarque-Bera (JB):                2.305
# Skew:                          -0.080   Prob(JB):                        0.316
# Kurtosis:                       2.666   Cond. No.                         20.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
subset_predictors = copy.deepcopy(adjusted_predictors) 
subset_predictors.remove('C_Phys_Attract_centered')
subset_predictors.remove('HCI_HHI_Substitution_centered')
subset_predictors.remove('C_State_Empathy_centered')
subset_predictors.remove('C_Homophily_centered')
interaction_terms = ['GPIUS2_centered']

model_specs.append(('Explore: SLSxGPIUS', subset_predictors, interaction_terms))

explore_ols(df, modelvars, subset_predictors, interaction_terms)
# Out:
# ULS_8_centered ~ Session_Length_Score_centered + BFI_Neurotic_centered + LSNS_Score_centered + GPIUS2_centered + BFI_Agreeableness_centered + H_Social_Attract_centered + Frequency_Score_centered + C_Social_Attract_centered + Sex + Age_centered + SLS_x_GPIUS2_centered
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         ULS_8_centered   R-squared:                       0.497
# Model:                            OLS   Adj. R-squared:                  0.482
# Method:                 Least Squares   F-statistic:                     32.25
# Date:                Wed, 11 Sep 2024   Prob (F-statistic):           3.08e-51
# Time:                        09:47:59   Log-Likelihood:                -434.27
# No. Observations:                 404   AIC:                             894.5
# Df Residuals:                     391   BIC:                             946.6
# Df Model:                          12
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                        -0.0172      0.058     -0.296      0.767      -0.131       0.097
# Sex[T.Male]                       0.0214      0.075      0.283      0.777      -0.127       0.170
# Sex[T.Prefer not to say]          0.6560      0.527      1.245      0.214      -0.380       1.692
# Session_Length_Score_centered     0.0344      0.040      0.863      0.389      -0.044       0.113
# BFI_Neurotic_centered             0.3616      0.041      8.728      0.000       0.280       0.443
# LSNS_Score_centered              -0.2974      0.040     -7.451      0.000      -0.376      -0.219
# GPIUS2_centered                   0.1974      0.046      4.309      0.000       0.107       0.287
# BFI_Agreeableness_centered        0.1418      0.040      3.555      0.000       0.063       0.220
# H_Social_Attract_centered        -0.0529      0.039     -1.358      0.175      -0.129       0.024
# Frequency_Score_centered         -0.0167      0.040     -0.421      0.674      -0.095       0.061
# C_Social_Attract_centered         0.0863      0.043      2.024      0.044       0.002       0.170
# Age_centered                     -0.0061      0.037     -0.165      0.869      -0.079       0.066
# SLS_x_GPIUS2_centered             0.0049      0.037      0.132      0.895      -0.068       0.078
# ==============================================================================
# Omnibus:                        2.627   Durbin-Watson:                   2.193
# Prob(Omnibus):                  0.269   Jarque-Bera (JB):                2.238
# Skew:                          -0.072   Prob(JB):                        0.327
# Kurtosis:                       2.665   Cond. No.                         21.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
subset_predictors = copy.deepcopy(adjusted_predictors) 
subset_predictors.remove('C_Phys_Attract_centered')
subset_predictors.remove('HCI_HHI_Substitution_centered')
subset_predictors.remove('C_State_Empathy_centered')
subset_predictors.remove('C_Homophily_centered')
interaction_terms = ['Frequency_Score_centered']

model_specs.append(('Explore: SLSxFrequency', subset_predictors, interaction_terms))

explore_ols(df, modelvars, subset_predictors, interaction_terms)
# Out:
# ULS_8_centered ~ Session_Length_Score_centered + BFI_Neurotic_centered + LSNS_Score_centered + GPIUS2_centered + BFI_Agreeableness_centered + H_Social_Attract_centered + Frequency_Score_centered + C_Social_Attract_centered + Sex + Age_centered + SLS_x_Frequency_Score_centered
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         ULS_8_centered   R-squared:                       0.498
# Model:                            OLS   Adj. R-squared:                  0.483
# Method:                 Least Squares   F-statistic:                     32.34
# Date:                Wed, 11 Sep 2024   Prob (F-statistic):           2.38e-51
# Time:                        09:48:23   Log-Likelihood:                -434.00
# No. Observations:                 404   AIC:                             894.0
# Df Residuals:                     391   BIC:                             946.0
# Df Model:                          12
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         -0.0062      0.059     -0.105      0.916      -0.123       0.110
# Sex[T.Male]                        0.0213      0.075      0.283      0.778      -0.127       0.169
# Sex[T.Prefer not to say]           0.6527      0.524      1.245      0.214      -0.378       1.683
# Session_Length_Score_centered      0.0471      0.042      1.117      0.265      -0.036       0.130
# BFI_Neurotic_centered              0.3613      0.041      8.742      0.000       0.280       0.443
# LSNS_Score_centered               -0.2970      0.040     -7.446      0.000      -0.375      -0.219
# GPIUS2_centered                    0.1993      0.046      4.357      0.000       0.109       0.289
# BFI_Agreeableness_centered         0.1427      0.040      3.583      0.000       0.064       0.221
# H_Social_Attract_centered         -0.0550      0.039     -1.410      0.159      -0.132       0.022
# Frequency_Score_centered          -0.0267      0.042     -0.638      0.524      -0.109       0.056
# C_Social_Attract_centered          0.0844      0.043      1.986      0.048       0.001       0.168
# Age_centered                      -0.0077      0.037     -0.209      0.835      -0.080       0.064
# SLS_x_Frequency_Score_centered    -0.0296      0.040     -0.742      0.458      -0.108       0.049
# ==============================================================================
# Omnibus:                        2.546   Durbin-Watson:                   2.184
# Prob(Omnibus):                  0.280   Jarque-Bera (JB):                2.180
# Skew:                          -0.070   Prob(JB):                        0.336
# Kurtosis:                       2.669   Cond. No.                         20.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
subset_predictors = copy.deepcopy(adjusted_predictors) 
subset_predictors.remove('C_Phys_Attract_centered')
subset_predictors.remove('HCI_HHI_Substitution_centered')
subset_predictors.remove('C_State_Empathy_centered')
subset_predictors.remove('C_Homophily_centered')
interaction_terms = ['H_Social_Attract_centered', 'BFI_Neurotic_centered']

model_specs.append(('+ SLSxH Social Attract, SLSxNeurotic', subset_predictors, interaction_terms))

explore_ols(df, modelvars, subset_predictors, interaction_terms)
# Out:
# ULS_8_centered ~ Session_Length_Score_centered + BFI_Neurotic_centered + LSNS_Score_centered + GPIUS2_centered + BFI_Agreeableness_centered + H_Social_Attract_centered + Frequency_Score_centered + C_Social_Attract_centered + Sex + Age_centered + SLS_x_H_Social_Attract_centered + SLS_x_BFI_Neurotic_centered
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         ULS_8_centered   R-squared:                       0.509
# Model:                            OLS   Adj. R-squared:                  0.493
# Method:                 Least Squares   F-statistic:                     31.14
# Date:                Wed, 11 Sep 2024   Prob (F-statistic):           1.93e-52
# Time:                        09:49:03   Log-Likelihood:                -429.44
# No. Observations:                 404   AIC:                             886.9
# Df Residuals:                     390   BIC:                             942.9
# Df Model:                          13
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          -0.0192      0.057     -0.336      0.737      -0.132       0.093
# Sex[T.Male]                         0.0345      0.075      0.462      0.645      -0.112       0.181
# Sex[T.Prefer not to say]            0.5695      0.521      1.093      0.275      -0.454       1.593
# Session_Length_Score_centered       0.0580      0.040      1.439      0.151      -0.021       0.137
# BFI_Neurotic_centered               0.3648      0.041      8.904      0.000       0.284       0.445
# LSNS_Score_centered                -0.2986      0.039     -7.559      0.000      -0.376      -0.221
# GPIUS2_centered                     0.2069      0.045      4.553      0.000       0.118       0.296
# BFI_Agreeableness_centered          0.1484      0.040      3.752      0.000       0.071       0.226
# H_Social_Attract_centered          -0.0561      0.039     -1.444      0.149      -0.133       0.020
# Frequency_Score_centered           -0.0186      0.039     -0.473      0.636      -0.096       0.059
# C_Social_Attract_centered           0.0803      0.042      1.898      0.058      -0.003       0.163
# Age_centered                       -0.0087      0.036     -0.239      0.812      -0.080       0.063
# SLS_x_H_Social_Attract_centered     0.0614      0.027      2.287      0.023       0.009       0.114
# SLS_x_BFI_Neurotic_centered        -0.0819      0.039     -2.099      0.036      -0.159      -0.005
# ==============================================================================
# Omnibus:                        2.419   Durbin-Watson:                   2.174
# Prob(Omnibus):                  0.298   Jarque-Bera (JB):                2.278
# Skew:                          -0.115   Prob(JB):                        0.320
# Kurtosis:                       2.713   Cond. No.                         22.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Categorical Exploration

# %%
base_formula = 'ULS_8_centered ~ Session_Length_Score_centered + H_Social_Attract_centered + BFI_Agreeableness_centered + C_Social_Attract_centered + LSNS_Score_centered + BFI_Neurotic_centered + Sex + Age_centered + SLS_x_H_Social_Attract_centered'
base_model = smf.ols(formula=base_formula, data=df).fit()
print(base_model.summary())

categorical_vars = ['Area_Type', 'Education','Relationship_Marital_Status','Political_Party', 'Race','Employment_Status']
# Add categorical variables one by one
for cat_var in categorical_vars:
    new_formula = f"{base_formula} + C({cat_var})"
    new_model = smf.ols(formula=new_formula, data=df).fit()
    anova_results = anova_lm(base_model, new_model)
    print("\n*****************")
    print(f"\nAdding {cat_var}:")
    print(f"AIC change: {new_model.aic - base_model.aic}")
    print(f"BIC change: {new_model.bic - base_model.bic}")
    print(f"Adjusted R-squared change: {new_model.rsquared_adj - base_model.rsquared_adj}")
    print(anova_results)
    print(new_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         ULS_8_centered   R-squared:                       0.479
# Model:                            OLS   Adj. R-squared:                  0.466
# Method:                 Least Squares   F-statistic:                     36.16
# Date:                Sat, 07 Sep 2024   Prob (F-statistic):           7.42e-50
# Time:                        18:32:12   Log-Likelihood:                -441.46
# No. Observations:                 404   AIC:                             904.9
# Df Residuals:                     393   BIC:                             948.9
# Df Model:                          10
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                           0.0090      0.058      0.155      0.877      -0.106       0.124
# Sex[T.Male]                        -0.0076      0.076     -0.100      0.920      -0.157       0.142
# Sex[T.Prefer not to say]            0.7768      0.532      1.461      0.145      -0.268       1.822
# Session_Length_Score_centered       0.0762      0.040      1.919      0.056      -0.002       0.154
# H_Social_Attract_centered          -0.1164      0.038     -3.085      0.002      -0.191      -0.042
# BFI_Agreeableness_centered          0.1459      0.040      3.608      0.000       0.066       0.225
# C_Social_Attract_centered           0.1626      0.038      4.233      0.000       0.087       0.238
# LSNS_Score_centered                -0.3007      0.040     -7.437      0.000      -0.380      -0.221
# BFI_Neurotic_centered               0.3778      0.042      9.047      0.000       0.296       0.460
# Age_centered                       -0.0192      0.037     -0.518      0.605      -0.092       0.054
# SLS_x_H_Social_Attract_centered     0.0603      0.028      2.191      0.029       0.006       0.114
# ==============================================================================
# Omnibus:                        2.681   Durbin-Watson:                   2.210
# Prob(Omnibus):                  0.262   Jarque-Bera (JB):                2.747
# Skew:                          -0.177   Prob(JB):                        0.253
# Kurtosis:                       2.805   Cond. No.                         21.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# *****************
#
# Adding Area_Type:
# AIC change: -0.017105237933037643
# BIC change: 7.985724517989297
# Adjusted R-squared change: 0.002579171744685693
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     393.0  210.397204      0.0       NaN       NaN       NaN
# 1     391.0  208.315522      2.0  2.081682  1.953618  0.143142
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         ULS_8_centered   R-squared:                       0.484
# Model:                            OLS   Adj. R-squared:                  0.469
# Method:                 Least Squares   F-statistic:                     30.61
# Date:                Sat, 07 Sep 2024   Prob (F-statistic):           4.07e-49
# Time:                        18:32:12   Log-Likelihood:                -439.45
# No. Observations:                 404   AIC:                             904.9
# Df Residuals:                     391   BIC:                             956.9
# Df Model:                          12
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                          -0.1714      0.113     -1.519      0.130      -0.393       0.050
# Sex[T.Male]                        -0.0164      0.076     -0.215      0.830      -0.166       0.133
# Sex[T.Prefer not to say]            0.7475      0.530      1.409      0.160      -0.295       1.790
# C(Area_Type)[T.Suburban]            0.2326      0.118      1.975      0.049       0.001       0.464
# C(Area_Type)[T.Urban]               0.1820      0.124      1.472      0.142      -0.061       0.425
# Session_Length_Score_centered       0.0784      0.040      1.976      0.049       0.000       0.156
# H_Social_Attract_centered          -0.1215      0.038     -3.216      0.001      -0.196      -0.047
# BFI_Agreeableness_centered          0.1478      0.040      3.659      0.000       0.068       0.227
# C_Social_Attract_centered           0.1625      0.038      4.242      0.000       0.087       0.238
# LSNS_Score_centered                -0.3006      0.040     -7.449      0.000      -0.380      -0.221
# BFI_Neurotic_centered               0.3730      0.042      8.810      0.000       0.290       0.456
# Age_centered                       -0.0182      0.038     -0.483      0.629      -0.092       0.056
# SLS_x_H_Social_Attract_centered     0.0632      0.028      2.298      0.022       0.009       0.117
# ==============================================================================
# Omnibus:                        3.469   Durbin-Watson:                   2.216
# Prob(Omnibus):                  0.176   Jarque-Bera (JB):                3.371
# Skew:                          -0.178   Prob(JB):                        0.185
# Kurtosis:                       2.728   Cond. No.                         22.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# *****************
#
# Adding Education:
# AIC change: 2.949135193720849
# BIC change: 34.960454217410074
# Adjusted R-squared change: 0.006231793472211589
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     393.0  210.397204      0.0       NaN       NaN       NaN
# 1     385.0  203.709115      8.0  6.688089  1.580019  0.128939
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         ULS_8_centered   R-squared:                       0.496
# Model:                            OLS   Adj. R-squared:                  0.472
# Method:                 Least Squares   F-statistic:                     21.03
# Date:                Sat, 07 Sep 2024   Prob (F-statistic):           1.22e-46
# Time:                        18:32:12   Log-Likelihood:                -434.94
# No. Observations:                 404   AIC:                             907.9
# Df Residuals:                     385   BIC:                             983.9
# Df Model:                          18
# Covariance Type:            nonrobust
# ===================================================================================================================================================================
#                                                                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                          -0.0477      0.113     -0.421      0.674      -0.271       0.175
# Sex[T.Male]                                                                                        -0.0031      0.076     -0.040      0.968      -0.153       0.147
# Sex[T.Prefer not to say]                                                                            0.5506      0.742      0.742      0.458      -0.907       2.009
# C(Education)[T.Bachelor's degree (for example: BA, AB, BS)]                                         0.0763      0.123      0.621      0.535      -0.165       0.318
# C(Education)[T.Doctorate degree (for example: PhD, EdD)]                                           -0.3465      0.282     -1.230      0.219      -0.900       0.207
# C(Education)[T.High school graduate - high school diploma or the equivalent (for example: GED)]    -0.0867      0.150     -0.580      0.563      -0.381       0.207
# C(Education)[T.Less than a high school diploma]                                                    -1.2421      0.743     -1.672      0.095      -2.703       0.219
# C(Education)[T.Master's degree (for example: MA, MS, MEng, MEd, MSW, MBA)]                          0.0207      0.146      0.141      0.888      -0.267       0.309
# C(Education)[T.Prefer not to say]                                                                   0.4435      1.044      0.425      0.671      -1.609       2.496
# C(Education)[T.Professional degree (for example: MD, DDS, DVM, LLB, JD)]                            0.3904      0.297      1.314      0.190      -0.194       0.975
# C(Education)[T.Some college, but no degree]                                                         0.2064      0.139      1.490      0.137      -0.066       0.479
# Session_Length_Score_centered                                                                       0.0712      0.040      1.782      0.076      -0.007       0.150
# H_Social_Attract_centered                                                                          -0.1164      0.038     -3.057      0.002      -0.191      -0.042
# BFI_Agreeableness_centered                                                                          0.1437      0.041      3.539      0.000       0.064       0.224
# C_Social_Attract_centered                                                                           0.1711      0.039      4.429      0.000       0.095       0.247
# LSNS_Score_centered                                                                                -0.3073      0.041     -7.484      0.000      -0.388      -0.227
# BFI_Neurotic_centered                                                                               0.3790      0.042      9.066      0.000       0.297       0.461
# Age_centered                                                                                       -0.0286      0.037     -0.769      0.442      -0.102       0.045
# SLS_x_H_Social_Attract_centered                                                                     0.0607      0.028      2.193      0.029       0.006       0.115
# ==============================================================================
# Omnibus:                        2.311   Durbin-Watson:                   2.218
# Prob(Omnibus):                  0.315   Jarque-Bera (JB):                2.266
# Skew:                          -0.183   Prob(JB):                        0.322
# Kurtosis:                       2.979   Cond. No.                         49.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# *****************
#
# Adding Relationship_Marital_Status:
# AIC change: 5.218039157659177
# BIC change: 33.22794330338718
# Adjusted R-squared change: 0.002007019160537693
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     393.0  210.397204      0.0       NaN       NaN       NaN
# 1     386.0  205.873039      7.0  4.524165  1.211792  0.295007
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         ULS_8_centered   R-squared:                       0.490
# Model:                            OLS   Adj. R-squared:                  0.468
# Method:                 Least Squares   F-statistic:                     21.85
# Date:                Sat, 07 Sep 2024   Prob (F-statistic):           1.80e-46
# Time:                        18:32:12   Log-Likelihood:                -437.07
# No. Observations:                 404   AIC:                             910.1
# Df Residuals:                     386   BIC:                             982.2
# Df Model:                          17
# Covariance Type:            nonrobust
# ==================================================================================================================================
#                                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                          0.1213      0.239      0.508      0.612      -0.348       0.591
# Sex[T.Male]                                                       -0.0222      0.077     -0.289      0.773      -0.173       0.129
# Sex[T.Prefer not to say]                                           0.7017      0.532      1.318      0.188      -0.345       1.748
# C(Relationship_Marital_Status)[T.In a civil union/partnership]     0.0213      0.348      0.061      0.951      -0.664       0.706
# C(Relationship_Marital_Status)[T.In a relationship]               -0.0891      0.250     -0.356      0.722      -0.581       0.403
# C(Relationship_Marital_Status)[T.I’d Rather Not Say]               0.2305      0.817      0.282      0.778      -1.377       1.838
# C(Relationship_Marital_Status)[T.Married]                         -0.2551      0.239     -1.067      0.287      -0.725       0.215
# C(Relationship_Marital_Status)[T.Separated]                        0.0733      0.435      0.168      0.866      -0.783       0.929
# C(Relationship_Marital_Status)[T.Single]                          -0.0102      0.246     -0.042      0.967      -0.494       0.473
# C(Relationship_Marital_Status)[T.Widowed]                         -0.2440      0.776     -0.314      0.753      -1.770       1.282
# Session_Length_Score_centered                                      0.0581      0.041      1.428      0.154      -0.022       0.138
# H_Social_Attract_centered                                         -0.1256      0.038     -3.300      0.001      -0.200      -0.051
# BFI_Agreeableness_centered                                         0.1427      0.041      3.520      0.000       0.063       0.222
# C_Social_Attract_centered                                          0.1657      0.039      4.300      0.000       0.090       0.241
# LSNS_Score_centered                                               -0.2973      0.041     -7.298      0.000      -0.377      -0.217
# BFI_Neurotic_centered                                              0.3702      0.042      8.731      0.000       0.287       0.454
# Age_centered                                                       0.0051      0.042      0.122      0.903      -0.077       0.087
# SLS_x_H_Social_Attract_centered                                    0.0608      0.028      2.137      0.033       0.005       0.117
# ==============================================================================
# Omnibus:                        2.512   Durbin-Watson:                   2.232
# Prob(Omnibus):                  0.285   Jarque-Bera (JB):                2.585
# Skew:                          -0.185   Prob(JB):                        0.275
# Kurtosis:                       2.872   Cond. No.                         35.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# *****************
#
# Adding Political_Party:
# AIC change: 4.37727157531549
# BIC change: 20.382931087160046
# Adjusted R-squared change: -0.0006749779187444904
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     393.0  210.397204      0.0       NaN       NaN       NaN
# 1     389.0  208.518974      4.0  1.878229  0.875977  0.478309
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         ULS_8_centered   R-squared:                       0.484
# Model:                            OLS   Adj. R-squared:                  0.465
# Method:                 Least Squares   F-statistic:                     26.05
# Date:                Sat, 07 Sep 2024   Prob (F-statistic):           1.51e-47
# Time:                        18:32:12   Log-Likelihood:                -439.65
# No. Observations:                 404   AIC:                             909.3
# Df Residuals:                     389   BIC:                             969.3
# Df Model:                          14
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# Intercept                                   0.0842      0.073      1.151      0.250      -0.060       0.228
# Sex[T.Male]                                -0.0047      0.076     -0.062      0.951      -0.155       0.146
# Sex[T.Prefer not to say]                    0.9159      0.579      1.581      0.115      -0.223       2.055
# C(Political_Party)[T.Independent]          -0.1409      0.088     -1.599      0.111      -0.314       0.032
# C(Political_Party)[T.Prefer not to say]    -0.2295      0.239     -0.960      0.338      -0.700       0.241
# C(Political_Party)[T.Republican]           -0.0900      0.103     -0.876      0.381      -0.292       0.112
# C(Political_Party)[T.Something else]       -0.1629      0.162     -1.004      0.316      -0.482       0.156
# Session_Length_Score_centered               0.0769      0.040      1.923      0.055      -0.002       0.155
# H_Social_Attract_centered                  -0.1204      0.038     -3.141      0.002      -0.196      -0.045
# BFI_Agreeableness_centered                  0.1458      0.041      3.594      0.000       0.066       0.226
# C_Social_Attract_centered                   0.1577      0.039      4.073      0.000       0.082       0.234
# LSNS_Score_centered                        -0.3063      0.041     -7.521      0.000      -0.386      -0.226
# BFI_Neurotic_centered                       0.3778      0.042      8.978      0.000       0.295       0.461
# Age_centered                               -0.0206      0.037     -0.554      0.580      -0.094       0.052
# SLS_x_H_Social_Attract_centered             0.0620      0.028      2.242      0.026       0.008       0.116
# ==============================================================================
# Omnibus:                        2.032   Durbin-Watson:                   2.226
# Prob(Omnibus):                  0.362   Jarque-Bera (JB):                2.114
# Skew:                          -0.163   Prob(JB):                        0.348
# Kurtosis:                       2.861   Cond. No.                         24.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# *****************
#
# Adding Race:
# AIC change: 11.603738709438176
# BIC change: 51.565842852745845
# Adjusted R-squared change: -0.004394891454993499
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     393.0  210.397204      0.0       NaN       NaN       NaN
# 1     382.0  206.666722     11.0  3.730482  0.626852  0.806002
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         ULS_8_centered   R-squared:                       0.488
# Model:                            OLS   Adj. R-squared:                  0.462
# Method:                 Least Squares   F-statistic:                     18.23
# Date:                Sat, 07 Sep 2024   Prob (F-statistic):           5.05e-44
# Time:                        18:32:12   Log-Likelihood:                -437.26
# No. Observations:                 403   AIC:                             916.5
# Df Residuals:                     382   BIC:                             1001.
# Df Model:                          20
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# Intercept                                   0.3295      0.334      0.987      0.325      -0.327       0.986
# Sex[T.Male]                                 0.0109      0.078      0.139      0.889      -0.143       0.164
# Sex[T.Prefer not to say]                    0.9032      0.611      1.478      0.140      -0.298       2.105
# C(Race)[T.An ethnicity not listed here]    -0.1792      0.385     -0.466      0.642      -0.936       0.577
# C(Race)[T.Asian Indian]                    -0.4052      0.498     -0.813      0.417      -1.385       0.575
# C(Race)[T.Black or African American]       -0.3169      0.343     -0.923      0.357      -0.992       0.358
# C(Race)[T.Chinese]                         -0.5763      0.379     -1.519      0.130      -1.322       0.170
# C(Race)[T.Filipino]                        -0.4185      0.433     -0.967      0.334      -1.270       0.433
# C(Race)[T.Korean]                          -0.7529      0.497     -1.514      0.131      -1.731       0.225
# C(Race)[T.Other]                           -0.1214      0.413     -0.294      0.769      -0.934       0.692
# C(Race)[T.Prefer not to say]               -0.5384      0.691     -0.779      0.436      -1.897       0.820
# C(Race)[T.Vietnamese]                       0.0291      0.469      0.062      0.951      -0.894       0.952
# C(Race)[T.White]                           -0.3384      0.333     -1.016      0.310      -0.993       0.317
# Session_Length_Score_centered               0.0701      0.041      1.721      0.086      -0.010       0.150
# H_Social_Attract_centered                  -0.1113      0.039     -2.872      0.004      -0.187      -0.035
# BFI_Agreeableness_centered                  0.1513      0.041      3.694      0.000       0.071       0.232
# C_Social_Attract_centered                   0.1623      0.039      4.181      0.000       0.086       0.239
# LSNS_Score_centered                        -0.2967      0.041     -7.211      0.000      -0.378      -0.216
# BFI_Neurotic_centered                       0.3717      0.043      8.569      0.000       0.286       0.457
# Age_centered                               -0.0152      0.038     -0.395      0.693      -0.091       0.060
# SLS_x_H_Social_Attract_centered             0.0546      0.028      1.953      0.052      -0.000       0.110
# ==============================================================================
# Omnibus:                        2.635   Durbin-Watson:                   2.176
# Prob(Omnibus):                  0.268   Jarque-Bera (JB):                2.654
# Skew:                          -0.162   Prob(JB):                        0.265
# Kurtosis:                       2.770   Cond. No.                         47.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# *****************
#
# Adding Employment_Status:
# AIC change: 8.030937597725597
# BIC change: 36.0408417434536
# Adjusted R-squared change: -0.0017102270740027015
#    df_resid         ssr  df_diff   ss_diff         F    Pr(>F)
# 0     393.0  210.397204      0.0       NaN       NaN       NaN
# 1     386.0  207.311457      7.0  3.085747  0.820779  0.570423
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         ULS_8_centered   R-squared:                       0.487
# Model:                            OLS   Adj. R-squared:                  0.464
# Method:                 Least Squares   F-statistic:                     21.54
# Date:                Sat, 07 Sep 2024   Prob (F-statistic):           6.54e-46
# Time:                        18:32:12   Log-Likelihood:                -438.48
# No. Observations:                 404   AIC:                             913.0
# Df Residuals:                     386   BIC:                             985.0
# Df Model:                          17
# Covariance Type:            nonrobust
# ========================================================================================================================================
#                                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                0.1899      0.155      1.227      0.220      -0.114       0.494
# Sex[T.Male]                                                             -0.0021      0.077     -0.028      0.978      -0.153       0.149
# Sex[T.Prefer not to say]                                                 0.5252      0.560      0.937      0.349      -0.576       1.627
# C(Employment_Status)[T.Full-time]                                       -0.2243      0.155     -1.445      0.149      -0.529       0.081
# C(Employment_Status)[T.Not in paid work (e.g., homemaker, disabled)]    -0.1764      0.271     -0.650      0.516      -0.710       0.357
# C(Employment_Status)[T.Part-time]                                       -0.1204      0.177     -0.681      0.496      -0.468       0.227
# C(Employment_Status)[T.Prefer not to say]                                0.3398      0.348      0.975      0.330      -0.345       1.025
# C(Employment_Status)[T.Retired]                                         -0.0276      0.457     -0.060      0.952      -0.926       0.871
# C(Employment_Status)[T.Student]                                         -0.2014      0.210     -0.957      0.339      -0.615       0.212
# C(Employment_Status)[T.Unemployed]                                      -0.2463      0.216     -1.139      0.255      -0.671       0.179
# Session_Length_Score_centered                                            0.0752      0.040      1.887      0.060      -0.003       0.154
# H_Social_Attract_centered                                               -0.1210      0.039     -3.143      0.002      -0.197      -0.045
# BFI_Agreeableness_centered                                               0.1427      0.041      3.501      0.001       0.063       0.223
# C_Social_Attract_centered                                                0.1709      0.039      4.414      0.000       0.095       0.247
# LSNS_Score_centered                                                     -0.2941      0.041     -7.151      0.000      -0.375      -0.213
# BFI_Neurotic_centered                                                    0.3749      0.042      8.891      0.000       0.292       0.458
# Age_centered                                                            -0.0226      0.040     -0.572      0.567      -0.100       0.055
# SLS_x_H_Social_Attract_centered                                          0.0564      0.028      1.992      0.047       0.001       0.112
# ==============================================================================
# Omnibus:                        2.386   Durbin-Watson:                   2.195
# Prob(Omnibus):                  0.303   Jarque-Bera (JB):                2.462
# Skew:                          -0.168   Prob(JB):                        0.292
# Kurtosis:                       2.817   Cond. No.                         23.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Generate Model Table

# %%
def generate_flexible_model_comparison(data, y, x, model_specs, cat=None):
    """
    Generate a comparison table for different model specifications.
    
    :param data: pandas DataFrame containing the variables
    :param y: string, name of the dependent variable
    :param x: string, name of the main independent variable
    :param model_specs: list of tuples (model_name, subset_predictors, interaction_terms)
    :param cat: list of categorical variables (optional)
    :return: pandas DataFrame with model comparison results
    """
    results = []
    cat = cat or []
    
    def create_formula(predictors, interaction_terms):
        formula = f"{y} ~ {x}"
        for var in predictors + [f'SLS_x_{term}' for term in interaction_terms] + cat:
            formula += f" + {var}"
        return formula
    
    def add_model_results(model, name, formula):
        results.append({
            'Model': name,
            'Formula': formula,
            'R-squared': model.rsquared,
            'Adj. R-squared': model.rsquared_adj,
            'F-statistic': model.fvalue,
            'p-value (F-stat)': model.f_pvalue,
            f'{x} p-value': model.pvalues[x],
            'AIC': model.aic,
            'BIC': model.bic
        })
    
    for model_name, subset_predictors, interaction_terms in model_specs:
        # Create interaction terms in the dataset
        
        # Create formula
        formula = create_formula(subset_predictors, interaction_terms)
        
        # Filter rows where variables are not NaN
        df_filtered = data.dropna(subset=[y, x] + subset_predictors + interaction_terms + cat)
        
        # Fit the model
        model = smf.ols(formula=formula, data=df_filtered).fit()
        
        # Add results
        add_model_results(model, model_name, formula)
    
    return pd.DataFrame(results)

# %%
model_specs
# Out:
# [('Base Model',
#   ['BFI_Agreeableness_centered',
#    'C_State_Empathy_centered',
#    'HCI_HHI_Substitution_centered',
#    'C_Social_Attract_centered',
#    'LSNS_Score_centered',
#    'GPIUS2_centered',
#    'C_Homophily_centered',
#    'C_Phys_Attract_centered',
#    'Sex',
#    'Age_centered'],
#   ['BFI_Agreeableness_centered']),
#  ('+ Neuroticism',
#   ['BFI_Agreeableness_centered',
#    'C_State_Empathy_centered',
#    'HCI_HHI_Substitution_centered',
#    'C_Social_Attract_centered',
#    'LSNS_Score_centered',
#    'GPIUS2_centered',
#    'C_Homophily_centered',
#    'BFI_Neurotic_centered',
#    'C_Phys_Attract_centered',
#    'Sex',
#    'Age_centered'],
#   ['BFI_Agreeableness_centered']),
#  ('- C State Empathy, C Homophily',
#   ['BFI_Agreeableness_centered',
#    'HCI_HHI_Substitution_centered',
#    'C_Social_Attract_centered',
#    'LSNS_Score_centered',
#    'GPIUS2_centered',
#    'BFI_Neurotic_centered',
#    'C_Phys_Attract_centered',
#    'Sex',
#    'Age_centered'],
#   ['BFI_Agreeableness_centered']),
#  ('- C Phys Attract, HCI/HHI Substitution',
#   ['BFI_Agreeableness_centered',
#    'C_Social_Attract_centered',
#    'LSNS_Score_centered',
#    'GPIUS2_centered',
#    'BFI_Neurotic_centered',
#    'Sex',
#    'Age_centered'],
#   ['BFI_Agreeableness_centered']),
#  ('- SLSxAgreeableness',
#   ['BFI_Agreeableness_centered',
#    'C_Social_Attract_centered',
#    'LSNS_Score_centered',
#    'GPIUS2_centered',
#    'BFI_Neurotic_centered',
#    'Sex',
#    'Age_centered'],
#   []),
#  ('+ H Social Attract',
#   ['BFI_Agreeableness_centered',
#    'C_Social_Attract_centered',
#    'LSNS_Score_centered',
#    'H_Social_Attract_centered',
#    'GPIUS2_centered',
#    'BFI_Neurotic_centered',
#    'Sex',
#    'Age_centered'],
#   []),
#  ('Explore: SLSxC Social Attract',
#   ['BFI_Agreeableness_centered',
#    'C_Social_Attract_centered',
#    'LSNS_Score_centered',
#    'H_Social_Attract_centered',
#    'GPIUS2_centered',
#    'BFI_Neurotic_centered',
#    'Sex',
#    'Age_centered'],
#   ['C_Social_Attract_centered']),
#  ('Explore: SLSxH Social Attract',
#   ['BFI_Agreeableness_centered',
#    'C_Social_Attract_centered',
#    'LSNS_Score_centered',
#    'H_Social_Attract_centered',
#    'GPIUS2_centered',
#    'BFI_Neurotic_centered',
#    'Sex',
#    'Age_centered'],
#   ['H_Social_Attract_centered']),
#  ('Explore: SLSxNeuroticism',
#   ['BFI_Agreeableness_centered',
#    'C_Social_Attract_centered',
#    'LSNS_Score_centered',
#    'H_Social_Attract_centered',
#    'GPIUS2_centered',
#    'BFI_Neurotic_centered',
#    'Sex',
#    'Age_centered'],
#   ['BFI_Neurotic_centered']),
#  ('Explore: SLSxAgreeableness',
#   ['BFI_Agreeableness_centered',
#    'C_Social_Attract_centered',
#    'LSNS_Score_centered',
#    'H_Social_Attract_centered',
#    'GPIUS2_centered',
#    'BFI_Neurotic_centered',
#    'Sex',
#    'Age_centered'],
#   ['BFI_Agreeableness_centered']),
#  ('Explore: SLSxLSNS',
#   ['BFI_Agreeableness_centered',
#    'C_Social_Attract_centered',
#    'LSNS_Score_centered',
#    'H_Social_Attract_centered',
#    'GPIUS2_centered',
#    'BFI_Neurotic_centered',
#    'Sex',
#    'Age_centered'],
#   ['LSNS_Score_centered']),
#  ('Explore: SLSxGPIUS',
#   ['BFI_Agreeableness_centered',
#    'C_Social_Attract_centered',
#    'LSNS_Score_centered',
#    'H_Social_Attract_centered',
#    'GPIUS2_centered',
#    'BFI_Neurotic_centered',
#    'Sex',
#    'Age_centered'],
#   ['LSNS_Score_centered']),
#  ('Explore: SLSxGPIUS',
#   ['BFI_Agreeableness_centered',
#    'C_Social_Attract_centered',
#    'LSNS_Score_centered',
#    'H_Social_Attract_centered',
#    'GPIUS2_centered',
#    'BFI_Neurotic_centered',
#    'Sex',
#    'Age_centered'],
#   ['GPIUS2_centered']),
#  ('+ SLSxH Social Attract, SLSxNeuroticism',
#   ['BFI_Agreeableness_centered',
#    'C_Social_Attract_centered',
#    'LSNS_Score_centered',
#    'H_Social_Attract_centered',
#    'GPIUS2_centered',
#    'BFI_Neurotic_centered',
#    'Sex',
#    'Age_centered'],
#   ['H_Social_Attract_centered', 'BFI_Neurotic_centered'])]

# %%
comparison_table = generate_flexible_model_comparison(df, y, x, model_specs)
comparison_table
# Out:
#                                       Model  \
# 0                                Base Model
# 1                             + Neuroticism
# 2            - C State Empathy, C Homophily
# 3    - C Phys Attract, HCI/HHI Substitution
# 4                       - SLSxAgreeableness
# 5                        + H Social Attract
# 6             Explore: SLSxC Social Attract
# 7             Explore: SLSxH Social Attract
# 8                  Explore: SLSxNeuroticism
# 9                Explore: SLSxAgreeableness
# 10                        Explore: SLSxLSNS
# 11                       Explore: SLSxGPIUS
# 12                       Explore: SLSxGPIUS
# 13  + SLSxH Social Attract, SLSxNeuroticism
#
#                                               Formula  R-squared  \
# 0   ULS_8_centered ~ Session_Length_Score_centered...   0.398725
# 1   ULS_8_centered ~ Session_Length_Score_centered...   0.499181
# 2   ULS_8_centered ~ Session_Length_Score_centered...   0.498803
# 3   ULS_8_centered ~ Session_Length_Score_centered...   0.494897
# 4   ULS_8_centered ~ Session_Length_Score_centered...   0.494758
# 5   ULS_8_centered ~ Session_Length_Score_centered...   0.497176
# 6   ULS_8_centered ~ Session_Length_Score_centered...   0.499435
# 7   ULS_8_centered ~ Session_Length_Score_centered...   0.503502
# 8   ULS_8_centered ~ Session_Length_Score_centered...   0.502450
# 9   ULS_8_centered ~ Session_Length_Score_centered...   0.497276
# 10  ULS_8_centered ~ Session_Length_Score_centered...   0.500103
# 11  ULS_8_centered ~ Session_Length_Score_centered...   0.500103
# 12  ULS_8_centered ~ Session_Length_Score_centered...   0.497201
# 13  ULS_8_centered ~ Session_Length_Score_centered...   0.509014
#
#     Adj. R-squared  F-statistic  p-value (F-stat)  \
# 0         0.378682    19.893963      8.260196e-36
# 1         0.481156    27.694816      5.170891e-50
# 2         0.483421    32.427715      1.828232e-51
# 3         0.482045    38.505949      2.071938e-52
# 4         0.483217    42.869400      3.234722e-53
# 5         0.484381    38.858485      8.679185e-53
# 6         0.485388    35.555879      2.349330e-52
# 7         0.489570    36.139124      4.921663e-53
# 8         0.488489    35.987389      7.382562e-53
# 9         0.483169    35.250173      5.356398e-52
# 10        0.486075    35.651009      1.819125e-52
# 11        0.486075    35.651009      1.819125e-52
# 12        0.483092    35.239583      5.511860e-52
# 13        0.493945    33.779700      3.614067e-53
#
#     Session_Length_Score_centered p-value         AIC          BIC
# 0                                0.575530  968.986475  1025.006283
# 1                                0.254443  897.132242   957.153465
# 2                                0.244599  893.436784   945.455177
# 3                                0.336467  892.573013   936.588576
# 4                                0.339031  890.684217   930.698366
# 5                                0.410659  890.746635   934.762199
# 6                                0.542029  890.927349   938.944327
# 7                                0.152925  887.631047   935.648025
# 8                                0.459849  888.486019   936.502998
# 9                                0.407727  892.665895   940.682874
# 10                               0.508230  890.387870   938.404848
# 11                               0.508230  890.387870   938.404848
# 12                               0.435718  892.726255   940.743233
# 13                               0.173262  885.121275   937.139668

# %%
# Export to CSV
comparison_table.to_csv('/work/Output Data/' + name + '_model_comparison_users.csv')

# %% [markdown]
# # Model Visualization

# %%
base_formula = 'ULS_8_centered ~ Session_Length_Score_centered + H_Social_Attract_centered + BFI_Agreeableness_centered + C_Social_Attract_centered + LSNS_Score_centered + BFI_Neurotic_centered + Sex + Age_centered + SLS_x_H_Social_Attract_centered'
base_model = smf.ols(formula=base_formula, data=df).fit()
print(base_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         ULS_8_centered   R-squared:                       0.479
# Model:                            OLS   Adj. R-squared:                  0.466
# Method:                 Least Squares   F-statistic:                     36.16
# Date:                Sat, 07 Sep 2024   Prob (F-statistic):           7.42e-50
# Time:                        18:32:13   Log-Likelihood:                -441.46
# No. Observations:                 404   AIC:                             904.9
# Df Residuals:                     393   BIC:                             948.9
# Df Model:                          10
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                           0.0090      0.058      0.155      0.877      -0.106       0.124
# Sex[T.Male]                        -0.0076      0.076     -0.100      0.920      -0.157       0.142
# Sex[T.Prefer not to say]            0.7768      0.532      1.461      0.145      -0.268       1.822
# Session_Length_Score_centered       0.0762      0.040      1.919      0.056      -0.002       0.154
# H_Social_Attract_centered          -0.1164      0.038     -3.085      0.002      -0.191      -0.042
# BFI_Agreeableness_centered          0.1459      0.040      3.608      0.000       0.066       0.225
# C_Social_Attract_centered           0.1626      0.038      4.233      0.000       0.087       0.238
# LSNS_Score_centered                -0.3007      0.040     -7.437      0.000      -0.380      -0.221
# BFI_Neurotic_centered               0.3778      0.042      9.047      0.000       0.296       0.460
# Age_centered                       -0.0192      0.037     -0.518      0.605      -0.092       0.054
# SLS_x_H_Social_Attract_centered     0.0603      0.028      2.191      0.029       0.006       0.114
# ==============================================================================
# Omnibus:                        2.681   Durbin-Watson:                   2.210
# Prob(Omnibus):                  0.262   Jarque-Bera (JB):                2.747
# Skew:                          -0.177   Prob(JB):                        0.253
# Kurtosis:                       2.805   Cond. No.                         21.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Q-Q plot
fig, ax = plt.subplots(figsize=(8, 6))
QQ = ProbPlot(base_model.resid)
QQ.qqplot(line='45', alpha=0.5, color='#4C72B0', lw=1, ax=ax)
ax.set_title('Q-Q plot of residuals')
plt.show()

# Residuals vs Fitted plot
fig, ax = plt.subplots(figsize=(8, 6))
sns.regplot(x=base_model.fittedvalues, y=base_model.resid, lowess=True, 
            line_kws={'color': 'red'}, scatter_kws={'alpha': 0.5}, ax=ax)
ax.set_title('Residuals vs Fitted')
ax.set_xlabel('Fitted values')
ax.set_ylabel('Residuals')
plt.show()

# Influence plot
influence = OLSInfluence(base_model)
fig, ax = plt.subplots(figsize=(8, 6))
influence.plot_influence(criterion="cooks", size=50, ax=ax)
plt.show()
# Out:
# /root/venv/lib/python3.9/site-packages/statsmodels/graphics/gofplots.py:1043: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %% [markdown]
# #
