# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting statsmodels==0.14.2
#   Downloading statsmodels-0.14.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 103.6 MB/s eta 0:00:00
# Collecting statannotations==0.6.0
#   Downloading statannotations-0.6.0-py3-none-any.whl (32 kB)
# Collecting wordcloud==1.9.3
#   Downloading wordcloud-1.9.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (513 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 513.6/513.6 kB 82.7 MB/s eta 0:00:00
# Collecting factor_analyzer==0.5.1
#   Downloading factor_analyzer-0.5.1.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 13.9 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting patsy>=0.5.6
#   Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.9/232.9 kB 38.0 MB/s eta 0:00:00
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels==0.14.2->-r ./requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: numpy>=1.22.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels==0.14.2->-r ./requirements.txt (line 1)) (1.23.4)
# Requirement already satisfied: packaging>=21.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from statsmodels==0.14.2->-r ./requirements.txt (line 1)) (21.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels==0.14.2->-r ./requirements.txt (line 1)) (2.1.4)
# Collecting pandas!=2.1.0,>=1.4
#   Downloading pandas-1.5.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 122.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=2.2.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statannotations==0.6.0->-r ./requirements.txt (line 2)) (3.6.0)
# Collecting seaborn<0.12,>=0.9.0
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 kB 64.1 MB/s eta 0:00:00
# Requirement already satisfied: pillow in /shared-libs/python3.9/py/lib/python3.9/site-packages (from wordcloud==1.9.3->-r ./requirements.txt (line 3)) (9.2.0)
# Requirement already satisfied: scikit-learn in /shared-libs/python3.9/py/lib/python3.9/site-packages (from factor_analyzer==0.5.1->-r ./requirements.txt (line 5)) (1.1.2)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=2.2.2->statannotations==0.6.0->-r ./requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib>=2.2.2->statannotations==0.6.0->-r ./requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=2.2.2->statannotations==0.6.0->-r ./requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=2.2.2->statannotations==0.6.0->-r ./requirements.txt (line 2)) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=2.2.2->statannotations==0.6.0->-r ./requirements.txt (line 2)) (4.37.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib>=2.2.2->statannotations==0.6.0->-r ./requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas!=2.1.0,>=1.4->statsmodels==0.14.2->-r ./requirements.txt (line 1)) (2022.5)
# Requirement already satisfied: joblib>=1.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn->factor_analyzer==0.5.1->-r ./requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn->factor_analyzer==0.5.1->-r ./requirements.txt (line 5)) (3.1.0)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=2.2.2->statannotations==0.6.0->-r ./requirements.txt (line 2)) (1.16.0)
# Building wheels for collected packages: factor_analyzer
#   Building wheel for factor_analyzer (pyproject.toml): started
#   Building wheel for factor_analyzer (pyproject.toml): finished with status 'done'
#   Created wheel for factor_analyzer: filename=factor_analyzer-0.5.1-py2.py3-none-any.whl size=42568 sha256=fc57e2f54382dc19c035e5b5e677cffd5fe31bed56a0900b6219cbe33b88f27f
#   Stored in directory: /root/.cache/pip/wheels/a3/d4/30/f61cb58ea80c0a5fa0042d72e882d561140cbecb974b98b9b7
# Successfully built factor_analyzer
# Installing collected packages: patsy, pandas, wordcloud, statsmodels, seaborn, factor_analyzer, statannotations
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.4
#     Not uninstalling pandas at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'pandas'. No files were found to uninstall.
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.13.2
#     Not uninstalling seaborn at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'seaborn'. No files were found to uninstall.
# Successfully installed factor_analyzer-0.5.1 pandas-1.5.3 patsy-1.0.1 seaborn-0.11.2 statannotations-0.6.0 statsmodels-0.14.2 wordcloud-1.9.3
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
